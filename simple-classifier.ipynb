# %%
import numpy as np
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
def load_data(directory):
    data = []
    vehicle_ids = []

    for i, file_name in enumerate(os.listdir(directory)):

        # Limit elements in Tensor for performance purposes, remove this when ready for full scale training
        if(i % 5000 == 0):
            print(f'Loading {i}')

        # Extract vehicle IDs from the filename
        vehicle_id = int(file_name.split('_')[0])
        vehicle_ids.append(vehicle_id)

        # Load NPY files
        file_path = os.path.join(directory, file_name)
        loaded_data = np.load(file_path)

        data.append(loaded_data)
        
        # Reshape loaded data and append to a list
        #reshaped_data = loaded_data.reshape((1, 32, 64))
        # data.append(reshaped_data)

    # Converting data and labels to PyTorch Tensors
    data = np.array(data)
    data = torch.from_numpy(data)
    vehicle_ids = torch.tensor(vehicle_ids, dtype=torch.long)
    
    # Adjust labels to be in range 0 to 1361
    if(torch.min(vehicle_ids).item() == 1):
        vehicle_ids = vehicle_ids - 1
    
    return (data, vehicle_ids)

# %%
# Load train data and labels from train directory
train_directory = "vehicle-x/train"
test_directory = "vehicle-x/test"

train_data, vehicle_ids_train = load_data(train_directory)
test_data, vehicle_ids_test = load_data(test_directory)
# Out:
# Loading 0
# Loading 5000
# Loading 10000
# Loading 15000
# Loading 20000
# Loading 25000
# Loading 30000
# Loading 35000
# Loading 40000
# Loading 45000
# Loading 0
# Loading 5000
# Loading 10000
# Loading 15000

# %%
# Hyperparameters
num_epochs = 100
batch_size = 32
test_batch_size = 64
learning_rate = 0.01

class CustomDataset():
    def __init__(self, data_array, labels):
        self.data = data_array
        self.labels = labels

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

# Create custom dataset from the tensors
train_dataset = CustomDataset(train_data, vehicle_ids_train)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = CustomDataset(test_data, vehicle_ids_test)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=test_batch_size, shuffle=True)

# %%
# Define the neural network
class SimpleClassifier(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(SimpleClassifier, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim, 1024),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, output_dim),
            nn.LogSoftmax(dim=1)
        )

    def forward(self, x):
        return self.fc(x)

# Device Configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Initialise network
model = SimpleClassifier(2048, 1362).to(device)

# %%
def train():
    model.train()
    correct = 0
    for batch_idx, (batch_data, batch_labels) in enumerate(train_loader):
        batch_data = batch_data.to(device)
        batch_labels = batch_labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(batch_data)

        pred = outputs.data.max(1, keepdim=True)[1] # get the index of the max log-probability
        correct += pred.eq(batch_labels.data.view_as(pred)).long().cpu().sum()
        
        loss = criterion(outputs, batch_labels)
        loss.backward()
        optimizer.step()

        if (batch_idx + 1) % 500 == 0:
            print(f'Epoch [{epoch + 1}/{num_epochs}], step[{batch_idx + 1}], loss: {loss.item():.4f}')

    print('Train Accuracy:{}/{}'.format(correct, len(train_loader.dataset)))

# %%
def test():
    model.eval()
    correct = 0

    for batch_data, batch_labels in test_loader:
        batch_data = batch_data.to(device)
        batch_labels = batch_labels.to(device)
        
        outputs = model(batch_data)
        
        pred = outputs.data.max(1, keepdim=True)[1] # get the index of the max log-probability
        correct += pred.eq(batch_labels.data.view_as(pred)).long().cpu().sum()

    print('Test accuracy:{}/{}\n'.format(correct, len(test_loader.dataset)))

# %%
# Train the model
criterion = nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

for epoch in range(num_epochs):
    train()
    test()
# Out:
# Epoch [1/100], step[500], loss: 7.2180
# Epoch [1/100], step[1000], loss: 7.1868
# Train Accuracy:36/45438
# Test accuracy:10/15142
#
# Epoch [2/100], step[500], loss: 7.2224
# Epoch [2/100], step[1000], loss: 7.2250
# Train Accuracy:41/45438
# Test accuracy:6/15142
#
# Epoch [3/100], step[500], loss: 7.2261
# Epoch [3/100], step[1000], loss: 7.2219
# Train Accuracy:39/45438
# Test accuracy:16/15142
#
# Epoch [4/100], step[500], loss: 7.2102
# Epoch [4/100], step[1000], loss: 7.2301
# Train Accuracy:38/45438
# Test accuracy:10/15142
#
# Epoch [5/100], step[500], loss: 7.1902
# Epoch [5/100], step[1000], loss: 7.2022
# Train Accuracy:38/45438
# Test accuracy:4/15142
#
# Epoch [6/100], step[500], loss: 7.2240
# Epoch [6/100], step[1000], loss: 7.2282
# Train Accuracy:39/45438
# Test accuracy:7/15142
#
# Epoch [7/100], step[500], loss: 7.2179
# Epoch [7/100], step[1000], loss: 7.2084
# Train Accuracy:42/45438
# Test accuracy:17/15142
#
# Epoch [8/100], step[500], loss: 7.2184
# Epoch [8/100], step[1000], loss: 7.2293
# Train Accuracy:58/45438
# Test accuracy:7/15142
#
# Epoch [9/100], step[500], loss: 7.2108
# Epoch [9/100], step[1000], loss: 7.1960
# Train Accuracy:59/45438
# Test accuracy:15/15142
#
# Epoch [10/100], step[500], loss: 7.1715
# Epoch [10/100], step[1000], loss: 7.1965
# Train Accuracy:55/45438
# Test accuracy:21/15142
#
# Epoch [11/100], step[500], loss: 7.1592
# Epoch [11/100], step[1000], loss: 7.1587
# Train Accuracy:61/45438
# Test accuracy:23/15142
#
# Epoch [12/100], step[500], loss: 7.1471
# Epoch [12/100], step[1000], loss: 7.1945
# Train Accuracy:83/45438
# Test accuracy:25/15142
#
# Epoch [13/100], step[500], loss: 7.1304
# Epoch [13/100], step[1000], loss: 7.0716
# Train Accuracy:91/45438
# Test accuracy:22/15142
#
# Epoch [14/100], step[500], loss: 7.1665
# Epoch [14/100], step[1000], loss: 6.9251
# Train Accuracy:92/45438
# Test accuracy:23/15142
#
# Epoch [15/100], step[500], loss: 7.0849
# Epoch [15/100], step[1000], loss: 7.0078
# Train Accuracy:101/45438
# Test accuracy:25/15142
#
# Epoch [16/100], step[500], loss: 7.2277
# Epoch [16/100], step[1000], loss: 6.9375
# Train Accuracy:102/45438
# Test accuracy:32/15142
#
# Epoch [17/100], step[500], loss: 7.0452
# Epoch [17/100], step[1000], loss: 6.7847
# Train Accuracy:109/45438
# Test accuracy:36/15142
#
# Epoch [18/100], step[500], loss: 6.8557
# Epoch [18/100], step[1000], loss: 7.0002
# Train Accuracy:128/45438
# Test accuracy:52/15142
#
# Epoch [19/100], step[500], loss: 6.8955
# Epoch [19/100], step[1000], loss: 6.9237
# Train Accuracy:153/45438
# Test accuracy:51/15142
#
# Epoch [20/100], step[500], loss: 6.8241
# Epoch [20/100], step[1000], loss: 6.7640
# Train Accuracy:157/45438
# Test accuracy:58/15142
#
# Epoch [21/100], step[500], loss: 6.6171
# Epoch [21/100], step[1000], loss: 6.6750
# Train Accuracy:221/45438
# Test accuracy:64/15142
#
# Epoch [22/100], step[500], loss: 6.6071
# Epoch [22/100], step[1000], loss: 6.6843
# Train Accuracy:241/45438
# Test accuracy:83/15142
#
# Epoch [23/100], step[500], loss: 6.7677
# Epoch [23/100], step[1000], loss: 6.4408
# Train Accuracy:287/45438
# Test accuracy:116/15142
#
# Epoch [24/100], step[500], loss: 6.2061
# Epoch [24/100], step[1000], loss: 6.4361
# Train Accuracy:292/45438
# Test accuracy:115/15142
#
# Epoch [25/100], step[500], loss: 6.6186
# Epoch [25/100], step[1000], loss: 6.2493
# Train Accuracy:360/45438
# Test accuracy:132/15142
#
# Epoch [26/100], step[500], loss: 6.5706
# Epoch [26/100], step[1000], loss: 6.3566
# Train Accuracy:391/45438
# Test accuracy:144/15142
#
# Epoch [27/100], step[500], loss: 6.2585
# Epoch [27/100], step[1000], loss: 5.8643
# Train Accuracy:374/45438
# Test accuracy:145/15142
#
# Epoch [28/100], step[500], loss: 6.2854
# Epoch [28/100], step[1000], loss: 6.4808
# Train Accuracy:412/45438
# Test accuracy:149/15142
#
# Epoch [29/100], step[500], loss: 6.0520
# Epoch [29/100], step[1000], loss: 6.0378
# Train Accuracy:519/45438
# Test accuracy:170/15142
#
# Epoch [30/100], step[500], loss: 5.8169
# Epoch [30/100], step[1000], loss: 5.8979
# Train Accuracy:489/45438
# Test accuracy:206/15142
#
# Epoch [31/100], step[500], loss: 6.2816
# Epoch [31/100], step[1000], loss: 6.3108
# Train Accuracy:527/45438
# Test accuracy:184/15142
#
# Epoch [32/100], step[500], loss: 6.2421
# Epoch [32/100], step[1000], loss: 6.0332
# Train Accuracy:571/45438
# Test accuracy:185/15142
#
# Epoch [33/100], step[500], loss: 6.4446
# Epoch [33/100], step[1000], loss: 5.5500
# Train Accuracy:605/45438
# Test accuracy:225/15142
#
# Epoch [34/100], step[500], loss: 6.0924
# Epoch [34/100], step[1000], loss: 5.9987
# Train Accuracy:676/45438
# Test accuracy:232/15142
#
# Epoch [35/100], step[500], loss: 6.0911
# Epoch [35/100], step[1000], loss: 6.0149
# Train Accuracy:729/45438
# Test accuracy:246/15142
#
# Epoch [36/100], step[500], loss: 6.3864
# Epoch [36/100], step[1000], loss: 6.1198
# Train Accuracy:688/45438
# Test accuracy:263/15142
#
# Epoch [37/100], step[500], loss: 5.7809
# Epoch [37/100], step[1000], loss: 6.0405
# Train Accuracy:817/45438
# Test accuracy:284/15142
#
# Epoch [38/100], step[500], loss: 5.6697
# Epoch [38/100], step[1000], loss: 5.8927
# Train Accuracy:832/45438
# Test accuracy:310/15142
#
# Epoch [39/100], step[500], loss: 5.5427
# Epoch [39/100], step[1000], loss: 5.5703
# Train Accuracy:882/45438
# Test accuracy:304/15142
#
# Epoch [40/100], step[500], loss: 5.5662
# Epoch [40/100], step[1000], loss: 6.0167
# Train Accuracy:968/45438
# Test accuracy:354/15142
#
# Epoch [41/100], step[500], loss: 5.8769
# Epoch [41/100], step[1000], loss: 5.4550
# Train Accuracy:1029/45438
# Test accuracy:367/15142
#
# Epoch [42/100], step[500], loss: 5.9832
# Epoch [42/100], step[1000], loss: 5.4361
# Train Accuracy:1006/45438
# Test accuracy:345/15142
#
# Epoch [43/100], step[500], loss: 5.9054
# Epoch [43/100], step[1000], loss: 5.6002
# Train Accuracy:1148/45438
# Test accuracy:360/15142
#
# Epoch [44/100], step[500], loss: 5.7083
# Epoch [44/100], step[1000], loss: 5.6426
# Train Accuracy:1230/45438
# Test accuracy:390/15142
#
# Epoch [45/100], step[500], loss: 5.5859
# Epoch [45/100], step[1000], loss: 5.7923
# Train Accuracy:1210/45438
# Test accuracy:424/15142
#
# Epoch [46/100], step[500], loss: 5.5220
# Epoch [46/100], step[1000], loss: 5.4391
# Train Accuracy:1241/45438
# Test accuracy:446/15142
#
# Epoch [47/100], step[500], loss: 5.5164
# Epoch [47/100], step[1000], loss: 6.1065
# Train Accuracy:1361/45438
# Test accuracy:465/15142
#
# Epoch [48/100], step[500], loss: 5.5864
# Epoch [48/100], step[1000], loss: 5.6242
# Train Accuracy:1441/45438
# Test accuracy:469/15142
#
# Epoch [49/100], step[500], loss: 5.4693
# Epoch [49/100], step[1000], loss: 5.1738
# Train Accuracy:1471/45438
# Test accuracy:483/15142
#
# Epoch [50/100], step[500], loss: 5.4595
# Epoch [50/100], step[1000], loss: 5.6471
# Train Accuracy:1544/45438
# Test accuracy:514/15142
#
# Epoch [51/100], step[500], loss: 5.4753
# Epoch [51/100], step[1000], loss: 5.7756
# Train Accuracy:1579/45438
# Test accuracy:530/15142
#
# Epoch [52/100], step[500], loss: 5.2981
# Epoch [52/100], step[1000], loss: 5.2820
# Train Accuracy:1697/45438
# Test accuracy:540/15142
#
# Epoch [53/100], step[500], loss: 5.7315
# Epoch [53/100], step[1000], loss: 5.1733
# Train Accuracy:1779/45438
# Test accuracy:534/15142
#
# Epoch [54/100], step[500], loss: 4.9390
# Epoch [54/100], step[1000], loss: 5.3977
# Train Accuracy:1850/45438
# Test accuracy:576/15142
#
# Epoch [55/100], step[500], loss: 5.1819
# Epoch [55/100], step[1000], loss: 5.2507
# Train Accuracy:1971/45438
# Test accuracy:575/15142
#
# Epoch [56/100], step[500], loss: 5.6714
# Epoch [56/100], step[1000], loss: 4.9543
# Train Accuracy:2013/45438
# Test accuracy:594/15142
#
# Epoch [57/100], step[500], loss: 5.3848
# Epoch [57/100], step[1000], loss: 5.1923
# Train Accuracy:2126/45438
# Test accuracy:639/15142
#
# Epoch [58/100], step[500], loss: 5.3307
# Epoch [58/100], step[1000], loss: 5.2926
# Train Accuracy:2199/45438
# Test accuracy:650/15142
#
# Epoch [59/100], step[500], loss: 5.1120
# Epoch [59/100], step[1000], loss: 5.6135
# Train Accuracy:2275/45438
# Test accuracy:673/15142
#
# Epoch [60/100], step[500], loss: 5.1933
# Epoch [60/100], step[1000], loss: 5.5087
# Train Accuracy:2280/45438
# Test accuracy:703/15142
#
# Epoch [61/100], step[500], loss: 5.1073
# Epoch [61/100], step[1000], loss: 5.3762
# Train Accuracy:2318/45438
# Test accuracy:727/15142
#
# Epoch [62/100], step[500], loss: 5.0341
# Epoch [62/100], step[1000], loss: 5.3543
# Train Accuracy:2502/45438
# Test accuracy:743/15142
#
# Epoch [63/100], step[500], loss: 4.9777
# Epoch [63/100], step[1000], loss: 5.2546
# Train Accuracy:2542/45438
# Test accuracy:774/15142
#
# Epoch [64/100], step[500], loss: 5.4743
# Epoch [64/100], step[1000], loss: 4.8132
# Train Accuracy:2614/45438
# Test accuracy:774/15142
#
# Epoch [65/100], step[500], loss: 4.9600
# Epoch [65/100], step[1000], loss: 5.2384
# Train Accuracy:2703/45438
# Test accuracy:799/15142
#
# Epoch [66/100], step[500], loss: 4.9041
# Epoch [66/100], step[1000], loss: 5.2607
# Train Accuracy:2839/45438
# Test accuracy:819/15142
#
# Epoch [67/100], step[500], loss: 5.6412
# Epoch [67/100], step[1000], loss: 5.1209
# Train Accuracy:2943/45438
# Test accuracy:870/15142
#
# Epoch [68/100], step[500], loss: 5.1180
# Epoch [68/100], step[1000], loss: 4.9168
# Train Accuracy:3023/45438
# Test accuracy:885/15142
#
# Epoch [69/100], step[500], loss: 4.3811
# Epoch [69/100], step[1000], loss: 4.8895
# Train Accuracy:3144/45438
# Test accuracy:943/15142
#
# Epoch [70/100], step[500], loss: 5.0020
# Epoch [70/100], step[1000], loss: 4.8729
# Train Accuracy:3216/45438
# Test accuracy:961/15142
#
# Epoch [71/100], step[500], loss: 4.9169
# Epoch [71/100], step[1000], loss: 5.2891
# Train Accuracy:3348/45438
# Test accuracy:925/15142
#
# Epoch [72/100], step[500], loss: 4.6304
# Epoch [72/100], step[1000], loss: 5.3196
# Train Accuracy:3357/45438
# Test accuracy:990/15142
#
# Epoch [73/100], step[500], loss: 4.7194
# Epoch [73/100], step[1000], loss: 4.2422
# Train Accuracy:3494/45438
# Test accuracy:991/15142
#
# Epoch [74/100], step[500], loss: 4.5205
# Epoch [74/100], step[1000], loss: 4.7464
# Train Accuracy:3665/45438
# Test accuracy:1037/15142
#
# Epoch [75/100], step[500], loss: 5.0815
# Epoch [75/100], step[1000], loss: 5.0047
# Train Accuracy:3716/45438
# Test accuracy:1057/15142
#
# Epoch [76/100], step[500], loss: 4.8816
# Epoch [76/100], step[1000], loss: 4.8982
# Train Accuracy:3867/45438
# Test accuracy:1062/15142
#
# Epoch [77/100], step[500], loss: 4.6702
# Epoch [77/100], step[1000], loss: 4.8518
# Train Accuracy:3973/45438
# Test accuracy:1139/15142
#
# Epoch [78/100], step[500], loss: 4.6538
# Epoch [78/100], step[1000], loss: 5.0383
# Train Accuracy:4026/45438
# Test accuracy:1070/15142
#
# Epoch [79/100], step[500], loss: 4.5326
# Epoch [79/100], step[1000], loss: 4.4606
# Train Accuracy:4184/45438
# Test accuracy:1152/15142
#
# Epoch [80/100], step[500], loss: 4.9699
# Epoch [80/100], step[1000], loss: 4.6288
# Train Accuracy:4244/45438
# Test accuracy:1162/15142
#
# Epoch [81/100], step[500], loss: 4.6287
# Epoch [81/100], step[1000], loss: 4.6678
# Train Accuracy:4346/45438
# Test accuracy:1229/15142
#
# Epoch [82/100], step[500], loss: 4.6784
# Epoch [82/100], step[1000], loss: 4.8072
# Train Accuracy:4466/45438
# Test accuracy:1222/15142
#
# Epoch [83/100], step[500], loss: 5.4001
# Epoch [83/100], step[1000], loss: 4.4790
# Train Accuracy:4528/45438
# Test accuracy:1247/15142
#
# Epoch [84/100], step[500], loss: 4.3233
# Epoch [84/100], step[1000], loss: 4.5993
# Train Accuracy:4599/45438
# Test accuracy:1280/15142
#
# Epoch [85/100], step[500], loss: 4.4802
# Epoch [85/100], step[1000], loss: 4.6787
# Train Accuracy:4818/45438
# Test accuracy:1293/15142
#
# Epoch [86/100], step[500], loss: 4.7675
# Epoch [86/100], step[1000], loss: 4.6978
# Train Accuracy:4872/45438
# Test accuracy:1318/15142
#
# Epoch [87/100], step[500], loss: 4.6600
# Epoch [87/100], step[1000], loss: 4.8250
# Train Accuracy:4940/45438
# Test accuracy:1315/15142
#
# Epoch [88/100], step[500], loss: 4.5570
# Epoch [88/100], step[1000], loss: 4.0895
# Train Accuracy:5103/45438
# Test accuracy:1319/15142
#
# Epoch [89/100], step[500], loss: 4.2876
# Epoch [89/100], step[1000], loss: 4.4148
# Train Accuracy:5133/45438
# Test accuracy:1396/15142
#
# Epoch [90/100], step[500], loss: 4.6276
# Epoch [90/100], step[1000], loss: 5.1748
# Train Accuracy:5360/45438
# Test accuracy:1356/15142
#
# Epoch [91/100], step[500], loss: 4.5792
# Epoch [91/100], step[1000], loss: 4.1429
# Train Accuracy:5292/45438
# Test accuracy:1410/15142
#
# Epoch [92/100], step[500], loss: 4.6831
# Epoch [92/100], step[1000], loss: 4.5803
# Train Accuracy:5476/45438
# Test accuracy:1436/15142
#
# Epoch [93/100], step[500], loss: 3.9625
# Epoch [93/100], step[1000], loss: 4.5197
# Train Accuracy:5551/45438
# Test accuracy:1440/15142
#
# Epoch [94/100], step[500], loss: 4.7128
# Epoch [94/100], step[1000], loss: 3.9197
# Train Accuracy:5662/45438
# Test accuracy:1471/15142
#
# Epoch [95/100], step[500], loss: 4.3829
# Epoch [95/100], step[1000], loss: 4.3585
# Train Accuracy:5693/45438
# Test accuracy:1494/15142
#
# Epoch [96/100], step[500], loss: 4.9170
# Epoch [96/100], step[1000], loss: 4.4353
# Train Accuracy:5808/45438
# Test accuracy:1513/15142
#
# Epoch [97/100], step[500], loss: 3.9801
# Epoch [97/100], step[1000], loss: 4.2462
# Train Accuracy:5999/45438
# Test accuracy:1542/15142
#
# Epoch [98/100], step[500], loss: 4.6887
# Epoch [98/100], step[1000], loss: 4.0395
# Train Accuracy:6096/45438
# Test accuracy:1525/15142
#
# Epoch [99/100], step[500], loss: 4.2484
# Epoch [99/100], step[1000], loss: 4.7192
# Train Accuracy:6116/45438
# Test accuracy:1536/15142
#
# Epoch [100/100], step[500], loss: 4.5761
# Epoch [100/100], step[1000], loss: 4.0734
# Train Accuracy:6202/45438
# Test accuracy:1507/15142
