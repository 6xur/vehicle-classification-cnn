# %%
import numpy as np
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
def load_data(directory):
    data = []
    vehicle_ids = []

    for i, file_name in enumerate(os.listdir(directory)):

        # Limit elements in Tensor for performance purposes, remove this when ready for full scale training
        if(i % 5000 == 0):
            print(f'Loading {i}')

        # Extract vehicle IDs from the filename
        vehicle_id = int(file_name.split('_')[0])
        vehicle_ids.append(vehicle_id)

        # Load NPY files
        file_path = os.path.join(directory, file_name)
        loaded_data = np.load(file_path)

        data.append(loaded_data)
        
        # Reshape loaded data and append to a list
        #reshaped_data = loaded_data.reshape((1, 32, 64))
        # data.append(reshaped_data)

    # Converting data and labels to PyTorch Tensors
    data = np.array(data)
    data = torch.from_numpy(data)
    vehicle_ids = torch.tensor(vehicle_ids, dtype=torch.long)
    
    # Adjust labels to be in range 0 to 1361
    if(torch.min(vehicle_ids).item() == 1):
        vehicle_ids = vehicle_ids - 1
    
    return (data, vehicle_ids)

# %%
# Load train data and labels from train directory
train_directory = "vehicle-x/train"
test_directory = "vehicle-x/test"

train_data, vehicle_ids_train = load_data(train_directory)
test_data, vehicle_ids_test = load_data(test_directory)
# Out:
# Loading0
# Loading5000
# Loading10000
# Loading15000
# Loading20000
# Loading25000
# Loading30000
# Loading35000
# Loading40000
# Loading45000
# Loading0
# Loading5000
# Loading10000
# Loading15000

# %%
# Hyperparameters
num_epochs = 100
batch_size = 32
test_batch_size = 64
learning_rate = 0.01

class CustomDataset():
    def __init__(self, data_array, labels):
        self.data = data_array
        self.labels = labels

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

# Create custom dataset from the tensors
train_dataset = CustomDataset(train_data, vehicle_ids_train)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = CustomDataset(test_data, vehicle_ids_test)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=test_batch_size, shuffle=True)

# %%
# Define the neural network
class SimpleClassifier(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(SimpleClassifier, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim, 1024),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, output_dim),
            nn.LogSoftmax(dim=1)
        )

    def forward(self, x):
        return self.fc(x)

# Device Configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Initialise network
model = SimpleClassifier(2048, 1362).to(device)

# %%
def train():
    model.train()
    correct = 0
    for batch_idx, (batch_data, batch_labels) in enumerate(train_loader):
        batch_data = batch_data.to(device)
        batch_labels = batch_labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(batch_data)

        pred = outputs.data.max(1, keepdim=True)[1] # get the index of the max log-probability
        correct += pred.eq(batch_labels.data.view_as(pred)).long().cpu().sum()
        
        loss = criterion(outputs, batch_labels)
        loss.backward()
        optimizer.step()

        if (batch_idx + 1) % 500 == 0:
            print(f'Epoch [{epoch + 1}/{num_epochs}], step[{batch_idx + 1}], loss: {loss.item():.4f}')

    print('Train Accuracy:{}/{}'.format(correct, len(train_loader.dataset)))

# %%
def test():
    model.eval()
    correct = 0

    for batch_data, batch_labels in test_loader:
        batch_data = batch_data.to(device)
        batch_labels = batch_labels.to(device)
        
        outputs = model(batch_data)
        
        pred = outputs.data.max(1, keepdim=True)[1] # get the index of the max log-probability
        correct += pred.eq(batch_labels.data.view_as(pred)).long().cpu().sum()

    print('Test accuracy:{}/{}\n'.format(correct, len(test_loader.dataset)))

# %%
# Train the model
criterion = nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

for epoch in range(num_epochs):
    train()
    test()
# Out:
# Epoch [1/100], step[500], loss: 7.2379
# Epoch [1/100], step[1000], loss: 7.2320
# Train Accuracy:28/45438
# Test accuracy:14/15142
#
# Epoch [2/100], step[500], loss: 7.2304
# Epoch [2/100], step[1000], loss: 7.2221
# Train Accuracy:37/45438
# Test accuracy:16/15142
#
# Epoch [3/100], step[500], loss: 7.1871
# Epoch [3/100], step[1000], loss: 7.2177
# Train Accuracy:32/45438
# Test accuracy:18/15142
#
# Epoch [4/100], step[500], loss: 7.2104
# Epoch [4/100], step[1000], loss: 7.1996
# Train Accuracy:45/45438
# Test accuracy:11/15142
#
# Epoch [5/100], step[500], loss: 7.2378
# Epoch [5/100], step[1000], loss: 7.2072
# Train Accuracy:39/45438
# Test accuracy:11/15142
#
# Epoch [6/100], step[500], loss: 7.2073
# Epoch [6/100], step[1000], loss: 7.2004
# Train Accuracy:45/45438
# Test accuracy:14/15142
#
# Epoch [7/100], step[500], loss: 7.2504
# Epoch [7/100], step[1000], loss: 7.2211
# Train Accuracy:44/45438
# Test accuracy:15/15142
#
# Epoch [8/100], step[500], loss: 7.2189
# Epoch [8/100], step[1000], loss: 7.2116
# Train Accuracy:51/45438
# Test accuracy:13/15142
#
# Epoch [9/100], step[500], loss: 7.2396
# Epoch [9/100], step[1000], loss: 7.2189
# Train Accuracy:54/45438
# Test accuracy:19/15142
#
# Epoch [10/100], step[500], loss: 7.1806
# Epoch [10/100], step[1000], loss: 7.1889
# Train Accuracy:55/45438
# Test accuracy:21/15142
#
# Epoch [11/100], step[500], loss: 7.1917
# Epoch [11/100], step[1000], loss: 7.2218
# Train Accuracy:57/45438
# Test accuracy:26/15142
#
# Epoch [12/100], step[500], loss: 7.1527
# Epoch [12/100], step[1000], loss: 7.1692
# Train Accuracy:73/45438
# Test accuracy:25/15142
#
# Epoch [13/100], step[500], loss: 7.2121
# Epoch [13/100], step[1000], loss: 7.0877
# Train Accuracy:83/45438
# Test accuracy:19/15142
#
# Epoch [14/100], step[500], loss: 7.1057
# Epoch [14/100], step[1000], loss: 6.9963
# Train Accuracy:77/45438
# Test accuracy:17/15142
#
# Epoch [15/100], step[500], loss: 7.0119
# Epoch [15/100], step[1000], loss: 7.0725
# Train Accuracy:88/45438
# Test accuracy:26/15142
#
# Epoch [16/100], step[500], loss: 7.0883
# Epoch [16/100], step[1000], loss: 7.0537
# Train Accuracy:100/45438
# Test accuracy:29/15142
#
# Epoch [17/100], step[500], loss: 7.0015
# Epoch [17/100], step[1000], loss: 6.9011
# Train Accuracy:103/45438
# Test accuracy:29/15142
#
# Epoch [18/100], step[500], loss: 7.0296
# Epoch [18/100], step[1000], loss: 7.0181
# Train Accuracy:143/45438
# Test accuracy:47/15142
#
# Epoch [19/100], step[500], loss: 6.7078
# Epoch [19/100], step[1000], loss: 6.9146
# Train Accuracy:168/45438
# Test accuracy:52/15142
#
# Epoch [20/100], step[500], loss: 6.6847
# Epoch [20/100], step[1000], loss: 6.8595
# Train Accuracy:211/45438
# Test accuracy:71/15142
#
# Epoch [21/100], step[500], loss: 6.7318
# Epoch [21/100], step[1000], loss: 6.8346
# Train Accuracy:220/45438
# Test accuracy:76/15142
#
# Epoch [22/100], step[500], loss: 6.4523
# Epoch [22/100], step[1000], loss: 6.6940
# Train Accuracy:242/45438
# Test accuracy:86/15142
#
# Epoch [23/100], step[500], loss: 6.5449
# Epoch [23/100], step[1000], loss: 6.5929
# Train Accuracy:282/45438
# Test accuracy:112/15142
#
# Epoch [24/100], step[500], loss: 6.4682
# Epoch [24/100], step[1000], loss: 6.5682
# Train Accuracy:274/45438
# Test accuracy:107/15142
#
# Epoch [25/100], step[500], loss: 6.4379
# Epoch [25/100], step[1000], loss: 6.4622
# Train Accuracy:315/45438
# Test accuracy:113/15142
#
# Epoch [26/100], step[500], loss: 6.4858
# Epoch [26/100], step[1000], loss: 6.3423
# Train Accuracy:337/45438
# Test accuracy:123/15142
#
# Epoch [27/100], step[500], loss: 6.2980
# Epoch [27/100], step[1000], loss: 6.2778
# Train Accuracy:366/45438
# Test accuracy:115/15142
#
# Epoch [28/100], step[500], loss: 6.3120
# Epoch [28/100], step[1000], loss: 5.9520
# Train Accuracy:445/45438
# Test accuracy:155/15142
#
# Epoch [29/100], step[500], loss: 6.4196
# Epoch [29/100], step[1000], loss: 6.2261
# Train Accuracy:424/45438
# Test accuracy:161/15142
#
# Epoch [30/100], step[500], loss: 6.3912
# Epoch [30/100], step[1000], loss: 6.0539
# Train Accuracy:500/45438
# Test accuracy:169/15142
#
# Epoch [31/100], step[500], loss: 6.2767
# Epoch [31/100], step[1000], loss: 5.7398
# Train Accuracy:523/45438
# Test accuracy:188/15142
#
# Epoch [32/100], step[500], loss: 6.2136
# Epoch [32/100], step[1000], loss: 6.1770
# Train Accuracy:531/45438
# Test accuracy:200/15142
#
# Epoch [33/100], step[500], loss: 5.8875
# Epoch [33/100], step[1000], loss: 6.2783
# Train Accuracy:581/45438
# Test accuracy:213/15142
#
# Epoch [34/100], step[500], loss: 6.0692
# Epoch [34/100], step[1000], loss: 5.9469
# Train Accuracy:625/45438
# Test accuracy:209/15142
#
# Epoch [35/100], step[500], loss: 5.9795
# Epoch [35/100], step[1000], loss: 5.7540
# Train Accuracy:688/45438
# Test accuracy:257/15142
#
# Epoch [36/100], step[500], loss: 5.9267
# Epoch [36/100], step[1000], loss: 5.8685
# Train Accuracy:657/45438
# Test accuracy:255/15142
#
# Epoch [37/100], step[500], loss: 5.7937
# Epoch [37/100], step[1000], loss: 5.9429
# Train Accuracy:749/45438
# Test accuracy:269/15142
#
# Epoch [38/100], step[500], loss: 5.7335
# Epoch [38/100], step[1000], loss: 6.0855
