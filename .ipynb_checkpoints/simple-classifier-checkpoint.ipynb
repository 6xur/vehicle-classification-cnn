# %%
import numpy as np
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
def load_data(directory):
    data = []
    vehicle_ids = []

    for i, file_name in enumerate(os.listdir(directory)):

        if(i % 5000 == 0):
            print(f'Loading item {i}')

        # Extract vehicle IDs from the filename
        vehicle_id = int(file_name.split('_')[0])
        vehicle_ids.append(vehicle_id)

        # Load Numpy feature vectors
        file_path = os.path.join(directory, file_name)
        loaded_data = np.load(file_path)
        data.append(loaded_data)

    # Convert feature vectors and labels to PyTorch Tensors
    data = np.array(data)
    data = torch.from_numpy(data)
    vehicle_ids = torch.tensor(vehicle_ids, dtype=torch.long)
    
    # Adjust labels to be in range 0 to 1361
    if(torch.min(vehicle_ids).item() == 1):
        vehicle_ids = vehicle_ids - 1
    
    return (data, vehicle_ids)

# %%
# Load train and test datasets
train_directory = "vehicle-x/train"
test_directory = "vehicle-x/test"

train_data, vehicle_ids_train = load_data(train_directory)
print('Finished loading train data')
test_data, vehicle_ids_test = load_data(test_directory)
print('Finished loading test data')
# Out:
# Loading item 0
# Loading item 5000
# Loading item 10000
# Loading item 15000
# Loading item 20000
# Loading item 25000
# Loading item 30000
# Loading item 35000
# Loading item 40000
# Loading item 45000
# Finished loading train data
# Loading item 0
# Loading item 5000
# Loading item 10000
# Loading item 15000
# Finished loading test data

# %%
# Hyperparameters
num_epochs = 1000
batch_size = 32
test_batch_size = 64
learning_rate = 0.01

class CustomDataset():
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

# Create custom dataset from the tensors
train_dataset = CustomDataset(train_data, vehicle_ids_train)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = CustomDataset(test_data, vehicle_ids_test)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=test_batch_size, shuffle=True)

# %%
# Define the neural network
class SimpleClassifier(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(SimpleClassifier, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim, 1024),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, output_dim),
            nn.LogSoftmax(dim=1)
        )

    def forward(self, x):
        return self.fc(x)

# Device Configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Initialise network
model = SimpleClassifier(2048, 1362).to(device)

# %%
def train():
    model.train()
    correct = 0
    for batch_idx, (batch_data, batch_labels) in enumerate(train_loader):
        batch_data = batch_data.to(device)
        batch_labels = batch_labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(batch_data)

        pred = outputs.data.max(1, keepdim=True)[1] # get the index of the max log-probability
        correct += pred.eq(batch_labels.data.view_as(pred)).long().cpu().sum()
        
        loss = criterion(outputs, batch_labels)
        loss.backward()
        optimizer.step()

        if (batch_idx + 1) % 500 == 0:
            print(f'Epoch [{epoch + 1}/{num_epochs}], step[{batch_idx + 1}], loss: {loss.item():.4f}')

    print('Train Accuracy:{}/{}'.format(correct, len(train_loader.dataset)))

# %%
def test():
    model.eval()
    correct = 0

    for batch_data, batch_labels in test_loader:
        batch_data = batch_data.to(device)
        batch_labels = batch_labels.to(device)
        
        outputs = model(batch_data)
        
        pred = outputs.data.max(1, keepdim=True)[1] # get the index of the max log-probability
        correct += pred.eq(batch_labels.data.view_as(pred)).long().cpu().sum()

    print('Test accuracy:{}/{}\n'.format(correct, len(test_loader.dataset)))

# %%
# Train the model
criterion = nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

for epoch in range(num_epochs):
    train()
    test()
# Out:
# Epoch [1/1000], step[500], loss: 7.2296
# Epoch [1/1000], step[1000], loss: 7.2258
# Train Accuracy:25/45438
# Test accuracy:14/15142
#
# Epoch [2/1000], step[500], loss: 7.2032
# Epoch [2/1000], step[1000], loss: 7.2153
# Train Accuracy:26/45438
# Test accuracy:13/15142
#
# Epoch [3/1000], step[500], loss: 7.2044
# Epoch [3/1000], step[1000], loss: 7.2136
# Train Accuracy:40/45438
# Test accuracy:10/15142
#
# Epoch [4/1000], step[500], loss: 7.1957
# Epoch [4/1000], step[1000], loss: 7.1996
# Train Accuracy:39/45438
# Test accuracy:11/15142
#
# Epoch [5/1000], step[500], loss: 7.2111
# Epoch [5/1000], step[1000], loss: 7.2379
# Train Accuracy:35/45438
# Test accuracy:13/15142
#
# Epoch [6/1000], step[500], loss: 7.2065
# Epoch [6/1000], step[1000], loss: 7.2192
# Train Accuracy:59/45438
# Test accuracy:9/15142
#
# Epoch [7/1000], step[500], loss: 7.2090
# Epoch [7/1000], step[1000], loss: 7.1986
# Train Accuracy:54/45438
# Test accuracy:14/15142
#
# Epoch [8/1000], step[500], loss: 7.2165
# Epoch [8/1000], step[1000], loss: 7.2133
# Train Accuracy:59/45438
# Test accuracy:13/15142
#
# Epoch [9/1000], step[500], loss: 7.2086
# Epoch [9/1000], step[1000], loss: 7.2496
# Train Accuracy:54/45438
# Test accuracy:13/15142
#
# Epoch [10/1000], step[500], loss: 7.2116
# Epoch [10/1000], step[1000], loss: 7.2007
# Train Accuracy:65/45438
# Test accuracy:16/15142
#
# Epoch [11/1000], step[500], loss: 7.1531
# Epoch [11/1000], step[1000], loss: 7.1737
# Train Accuracy:66/45438
# Test accuracy:29/15142
#
# Epoch [12/1000], step[500], loss: 7.0665
# Epoch [12/1000], step[1000], loss: 7.0675
# Train Accuracy:89/45438
# Test accuracy:25/15142
#
# Epoch [13/1000], step[500], loss: 7.0923
# Epoch [13/1000], step[1000], loss: 7.1604
# Train Accuracy:72/45438
# Test accuracy:29/15142
#
# Epoch [14/1000], step[500], loss: 6.9542
# Epoch [14/1000], step[1000], loss: 6.7887
# Train Accuracy:74/45438
# Test accuracy:29/15142
#
# Epoch [15/1000], step[500], loss: 7.0295
# Epoch [15/1000], step[1000], loss: 7.1241
# Train Accuracy:88/45438
# Test accuracy:33/15142
#
# Epoch [16/1000], step[500], loss: 6.9916
# Epoch [16/1000], step[1000], loss: 7.0518
# Train Accuracy:81/45438
# Test accuracy:33/15142
#
# Epoch [17/1000], step[500], loss: 7.0837
# Epoch [17/1000], step[1000], loss: 6.9756
# Train Accuracy:106/45438
# Test accuracy:18/15142
#
# Epoch [18/1000], step[500], loss: 6.8561
# Epoch [18/1000], step[1000], loss: 6.8878
# Train Accuracy:150/45438
# Test accuracy:41/15142
#
# Epoch [19/1000], step[500], loss: 6.8836
# Epoch [19/1000], step[1000], loss: 6.8669
# Train Accuracy:172/45438
# Test accuracy:48/15142
#
# Epoch [20/1000], step[500], loss: 6.6456
# Epoch [20/1000], step[1000], loss: 6.7414
# Train Accuracy:182/45438
# Test accuracy:58/15142
#
# Epoch [21/1000], step[500], loss: 6.6749
# Epoch [21/1000], step[1000], loss: 6.9549
# Train Accuracy:232/45438
# Test accuracy:75/15142
#
# Epoch [22/1000], step[500], loss: 6.7118
# Epoch [22/1000], step[1000], loss: 6.7737
# Train Accuracy:248/45438
# Test accuracy:72/15142
#
# Epoch [23/1000], step[500], loss: 6.6079
# Epoch [23/1000], step[1000], loss: 6.3611
# Train Accuracy:249/45438
# Test accuracy:102/15142
#
# Epoch [24/1000], step[500], loss: 6.6226
# Epoch [24/1000], step[1000], loss: 6.5105
# Train Accuracy:260/45438
# Test accuracy:106/15142
#
# Epoch [25/1000], step[500], loss: 6.3978
# Epoch [25/1000], step[1000], loss: 6.6742
# Train Accuracy:311/45438
# Test accuracy:110/15142
#
# Epoch [26/1000], step[500], loss: 6.2229
# Epoch [26/1000], step[1000], loss: 6.3265
# Train Accuracy:389/45438
# Test accuracy:124/15142
#
# Epoch [27/1000], step[500], loss: 6.3379
# Epoch [27/1000], step[1000], loss: 6.3244
# Train Accuracy:400/45438
# Test accuracy:137/15142
#
# Epoch [28/1000], step[500], loss: 6.2495
# Epoch [28/1000], step[1000], loss: 5.9327
# Train Accuracy:407/45438
# Test accuracy:162/15142
#
# Epoch [29/1000], step[500], loss: 6.3804
# Epoch [29/1000], step[1000], loss: 6.2891
# Train Accuracy:471/45438
# Test accuracy:171/15142
#
# Epoch [30/1000], step[500], loss: 6.3392
# Epoch [30/1000], step[1000], loss: 6.0211
# Train Accuracy:497/45438
# Test accuracy:180/15142
#
# Epoch [31/1000], step[500], loss: 6.0115
# Epoch [31/1000], step[1000], loss: 5.8819
# Train Accuracy:579/45438
# Test accuracy:204/15142
#
# Epoch [32/1000], step[500], loss: 6.2696
# Epoch [32/1000], step[1000], loss: 6.4364
# Train Accuracy:581/45438
# Test accuracy:226/15142
#
# Epoch [33/1000], step[500], loss: 6.2753
# Epoch [33/1000], step[1000], loss: 5.7876
# Train Accuracy:616/45438
# Test accuracy:231/15142
#
# Epoch [34/1000], step[500], loss: 6.0357
# Epoch [34/1000], step[1000], loss: 5.8346
# Train Accuracy:684/45438
# Test accuracy:244/15142
#
# Epoch [35/1000], step[500], loss: 5.8170
# Epoch [35/1000], step[1000], loss: 5.7537
# Train Accuracy:765/45438
# Test accuracy:283/15142
#
# Epoch [36/1000], step[500], loss: 5.9510
# Epoch [36/1000], step[1000], loss: 5.7316
# Train Accuracy:749/45438
# Test accuracy:276/15142
#
# Epoch [37/1000], step[500], loss: 6.2030
# Epoch [37/1000], step[1000], loss: 5.7287
# Train Accuracy:826/45438
# Test accuracy:293/15142
#
# Epoch [38/1000], step[500], loss: 5.6869
# Epoch [38/1000], step[1000], loss: 5.8937
# Train Accuracy:858/45438
# Test accuracy:288/15142
#
# Epoch [39/1000], step[500], loss: 5.8686
# Epoch [39/1000], step[1000], loss: 5.7564
# Train Accuracy:893/45438
# Test accuracy:322/15142
#
# Epoch [40/1000], step[500], loss: 5.9192
# Epoch [40/1000], step[1000], loss: 5.4382
# Train Accuracy:971/45438
# Test accuracy:346/15142
#
# Epoch [41/1000], step[500], loss: 5.6106
# Epoch [41/1000], step[1000], loss: 5.8347
# Train Accuracy:1011/45438
# Test accuracy:383/15142
#
# Epoch [42/1000], step[500], loss: 5.7597
# Epoch [42/1000], step[1000], loss: 5.9199
# Train Accuracy:1124/45438
# Test accuracy:406/15142
#
# Epoch [43/1000], step[500], loss: 6.0812
# Epoch [43/1000], step[1000], loss: 5.5559
# Train Accuracy:1083/45438
# Test accuracy:406/15142
#
# Epoch [44/1000], step[500], loss: 5.5835
# Epoch [44/1000], step[1000], loss: 5.6458
# Train Accuracy:1205/45438
# Test accuracy:420/15142
#
# Epoch [45/1000], step[500], loss: 5.6983
# Epoch [45/1000], step[1000], loss: 5.6358
# Train Accuracy:1293/45438
# Test accuracy:441/15142
#
# Epoch [46/1000], step[500], loss: 5.4845
# Epoch [46/1000], step[1000], loss: 5.5058
# Train Accuracy:1340/45438
# Test accuracy:442/15142
#
# Epoch [47/1000], step[500], loss: 5.2774
# Epoch [47/1000], step[1000], loss: 5.6021
# Train Accuracy:1381/45438
# Test accuracy:423/15142
#
# Epoch [48/1000], step[500], loss: 4.9057
# Epoch [48/1000], step[1000], loss: 5.2784
# Train Accuracy:1482/45438
# Test accuracy:469/15142
#
# Epoch [49/1000], step[500], loss: 5.4865
# Epoch [49/1000], step[1000], loss: 5.2137
# Train Accuracy:1567/45438
# Test accuracy:455/15142
#
# Epoch [50/1000], step[500], loss: 5.5161
# Epoch [50/1000], step[1000], loss: 5.4277
# Train Accuracy:1576/45438
# Test accuracy:478/15142
#
# Epoch [51/1000], step[500], loss: 5.3334
# Epoch [51/1000], step[1000], loss: 5.3268
# Train Accuracy:1656/45438
# Test accuracy:510/15142
#
# Epoch [52/1000], step[500], loss: 5.5140
# Epoch [52/1000], step[1000], loss: 5.3070
# Train Accuracy:1765/45438
# Test accuracy:540/15142
#
# Epoch [53/1000], step[500], loss: 4.8758
# Epoch [53/1000], step[1000], loss: 5.6688
# Train Accuracy:1763/45438
# Test accuracy:579/15142
#
# Epoch [54/1000], step[500], loss: 5.5098
# Epoch [54/1000], step[1000], loss: 5.3243
# Train Accuracy:1811/45438
# Test accuracy:585/15142
#
# Epoch [55/1000], step[500], loss: 5.6727
# Epoch [55/1000], step[1000], loss: 5.4351
# Train Accuracy:1931/45438
# Test accuracy:612/15142
#
# Epoch [56/1000], step[500], loss: 5.5869
# Epoch [56/1000], step[1000], loss: 5.6301
# Train Accuracy:1996/45438
# Test accuracy:591/15142
#
# Epoch [57/1000], step[500], loss: 5.5793
# Epoch [57/1000], step[1000], loss: 4.7399
# Train Accuracy:2105/45438
# Test accuracy:597/15142
#
# Epoch [58/1000], step[500], loss: 4.8782
# Epoch [58/1000], step[1000], loss: 5.1619
# Train Accuracy:2104/45438
# Test accuracy:634/15142
#
# Epoch [59/1000], step[500], loss: 4.8869
# Epoch [59/1000], step[1000], loss: 5.1497
# Train Accuracy:2227/45438
# Test accuracy:677/15142
#
# Epoch [60/1000], step[500], loss: 5.5677
# Epoch [60/1000], step[1000], loss: 5.1981
# Train Accuracy:2258/45438
# Test accuracy:690/15142
#
# Epoch [61/1000], step[500], loss: 5.0051
# Epoch [61/1000], step[1000], loss: 5.6116
# Train Accuracy:2425/45438
# Test accuracy:721/15142
#
# Epoch [62/1000], step[500], loss: 5.3733
# Epoch [62/1000], step[1000], loss: 5.3512
# Train Accuracy:2485/45438
# Test accuracy:739/15142
#
# Epoch [63/1000], step[500], loss: 4.7096
# Epoch [63/1000], step[1000], loss: 5.6207
# Train Accuracy:2546/45438
# Test accuracy:731/15142
#
# Epoch [64/1000], step[500], loss: 5.0928
# Epoch [64/1000], step[1000], loss: 5.2869
# Train Accuracy:2659/45438
# Test accuracy:798/15142
#
# Epoch [65/1000], step[500], loss: 5.1087
# Epoch [65/1000], step[1000], loss: 5.3254
# Train Accuracy:2727/45438
# Test accuracy:809/15142
#
# Epoch [66/1000], step[500], loss: 5.1939
# Epoch [66/1000], step[1000], loss: 5.7729
# Train Accuracy:2779/45438
# Test accuracy:850/15142
#
# Epoch [67/1000], step[500], loss: 5.4524
# Epoch [67/1000], step[1000], loss: 5.1299
# Train Accuracy:2855/45438
# Test accuracy:819/15142
#
# Epoch [68/1000], step[500], loss: 4.8696
# Epoch [68/1000], step[1000], loss: 5.1809
# Train Accuracy:2898/45438
# Test accuracy:874/15142
#
# Epoch [69/1000], step[500], loss: 5.2789
# Epoch [69/1000], step[1000], loss: 4.4743
# Train Accuracy:3022/45438
# Test accuracy:879/15142
#
# Epoch [70/1000], step[500], loss: 4.9703
# Epoch [70/1000], step[1000], loss: 4.9177
# Train Accuracy:3145/45438
# Test accuracy:881/15142
#
# Epoch [71/1000], step[500], loss: 4.7163
# Epoch [71/1000], step[1000], loss: 4.7952
# Train Accuracy:3150/45438
# Test accuracy:929/15142
#
# Epoch [72/1000], step[500], loss: 4.8654
# Epoch [72/1000], step[1000], loss: 5.2019
# Train Accuracy:3248/45438
# Test accuracy:954/15142
#
# Epoch [73/1000], step[500], loss: 4.9098
# Epoch [73/1000], step[1000], loss: 5.4540
# Train Accuracy:3334/45438
# Test accuracy:988/15142
#
# Epoch [74/1000], step[500], loss: 4.9891
# Epoch [74/1000], step[1000], loss: 4.5207
# Train Accuracy:3516/45438
# Test accuracy:996/15142
#
# Epoch [75/1000], step[500], loss: 4.5901
# Epoch [75/1000], step[1000], loss: 4.8935
# Train Accuracy:3690/45438
# Test accuracy:1059/15142
#
# Epoch [76/1000], step[500], loss: 5.0676
# Epoch [76/1000], step[1000], loss: 4.5598
# Train Accuracy:3718/45438
# Test accuracy:1019/15142
#
# Epoch [77/1000], step[500], loss: 4.3869
# Epoch [77/1000], step[1000], loss: 5.1579
# Train Accuracy:3738/45438
# Test accuracy:1069/15142
#
# Epoch [78/1000], step[500], loss: 4.3660
# Epoch [78/1000], step[1000], loss: 5.0121
# Train Accuracy:3847/45438
# Test accuracy:1047/15142
#
# Epoch [79/1000], step[500], loss: 4.6109
# Epoch [79/1000], step[1000], loss: 5.2133
# Train Accuracy:4043/45438
# Test accuracy:1091/15142
#
# Epoch [80/1000], step[500], loss: 5.3186
# Epoch [80/1000], step[1000], loss: 4.5294
# Train Accuracy:4074/45438
# Test accuracy:1092/15142
#
# Epoch [81/1000], step[500], loss: 4.9872
# Epoch [81/1000], step[1000], loss: 4.7876
# Train Accuracy:4165/45438
# Test accuracy:1150/15142
#
# Epoch [82/1000], step[500], loss: 5.3774
# Epoch [82/1000], step[1000], loss: 5.0074
# Train Accuracy:4320/45438
# Test accuracy:1144/15142
#
# Epoch [83/1000], step[500], loss: 5.2547
# Epoch [83/1000], step[1000], loss: 4.7506
# Train Accuracy:4309/45438
# Test accuracy:1205/15142
#
# Epoch [84/1000], step[500], loss: 4.3322
# Epoch [84/1000], step[1000], loss: 4.7100
# Train Accuracy:4487/45438
# Test accuracy:1187/15142
#
# Epoch [85/1000], step[500], loss: 5.0607
# Epoch [85/1000], step[1000], loss: 4.8052
# Train Accuracy:4588/45438
# Test accuracy:1205/15142
#
# Epoch [86/1000], step[500], loss: 4.0262
# Epoch [86/1000], step[1000], loss: 4.8583
# Train Accuracy:4739/45438
# Test accuracy:1219/15142
#
# Epoch [87/1000], step[500], loss: 4.5699
# Epoch [87/1000], step[1000], loss: 4.2360
# Train Accuracy:4756/45438
# Test accuracy:1303/15142
#
# Epoch [88/1000], step[500], loss: 4.6876
# Epoch [88/1000], step[1000], loss: 4.8068
# Train Accuracy:4825/45438
# Test accuracy:1305/15142
#
# Epoch [89/1000], step[500], loss: 4.5915
# Epoch [89/1000], step[1000], loss: 4.2085
# Train Accuracy:4974/45438
# Test accuracy:1338/15142
#
# Epoch [90/1000], step[500], loss: 4.8645
# Epoch [90/1000], step[1000], loss: 4.8102
# Train Accuracy:5031/45438
# Test accuracy:1368/15142
#
# Epoch [91/1000], step[500], loss: 4.4169
# Epoch [91/1000], step[1000], loss: 4.9752
# Train Accuracy:5259/45438
# Test accuracy:1326/15142
#
# Epoch [92/1000], step[500], loss: 4.8569
# Epoch [92/1000], step[1000], loss: 4.1383
# Train Accuracy:5239/45438
# Test accuracy:1397/15142
#
# Epoch [93/1000], step[500], loss: 4.2033
# Epoch [93/1000], step[1000], loss: 4.2053
# Train Accuracy:5384/45438
# Test accuracy:1391/15142
#
# Epoch [94/1000], step[500], loss: 4.2917
# Epoch [94/1000], step[1000], loss: 4.3587
# Train Accuracy:5454/45438
# Test accuracy:1420/15142
#
# Epoch [95/1000], step[500], loss: 5.2488
# Epoch [95/1000], step[1000], loss: 4.6311
# Train Accuracy:5545/45438
# Test accuracy:1461/15142
#
# Epoch [96/1000], step[500], loss: 4.2698
# Epoch [96/1000], step[1000], loss: 4.3328
# Train Accuracy:5620/45438
# Test accuracy:1424/15142
#
# Epoch [97/1000], step[500], loss: 4.3443
# Epoch [97/1000], step[1000], loss: 4.2494
# Train Accuracy:5682/45438
# Test accuracy:1510/15142
#
# Epoch [98/1000], step[500], loss: 4.2957
# Epoch [98/1000], step[1000], loss: 4.6703
# Train Accuracy:5861/45438
# Test accuracy:1482/15142
#
# Epoch [99/1000], step[500], loss: 4.3282
# Epoch [99/1000], step[1000], loss: 4.3231
# Train Accuracy:5989/45438
# Test accuracy:1486/15142
#
# Epoch [100/1000], step[500], loss: 4.5982
# Epoch [100/1000], step[1000], loss: 4.3206
# Train Accuracy:5949/45438
# Test accuracy:1488/15142
#
# Epoch [101/1000], step[500], loss: 4.4459
# Epoch [101/1000], step[1000], loss: 4.2589
# Train Accuracy:6281/45438
# Test accuracy:1539/15142
#
# Epoch [102/1000], step[500], loss: 4.2003
# Epoch [102/1000], step[1000], loss: 4.3117
# Train Accuracy:6223/45438
# Test accuracy:1574/15142
#
# Epoch [103/1000], step[500], loss: 3.6852
# Epoch [103/1000], step[1000], loss: 3.9914
# Train Accuracy:6420/45438
# Test accuracy:1548/15142
#
# Epoch [104/1000], step[500], loss: 4.6616
# Epoch [104/1000], step[1000], loss: 4.2254
# Train Accuracy:6472/45438
# Test accuracy:1622/15142
#
# Epoch [105/1000], step[500], loss: 4.0635
# Epoch [105/1000], step[1000], loss: 4.0965
# Train Accuracy:6520/45438
# Test accuracy:1616/15142
#
# Epoch [106/1000], step[500], loss: 4.0508
# Epoch [106/1000], step[1000], loss: 4.3429
# Train Accuracy:6601/45438
# Test accuracy:1654/15142
#
# Epoch [107/1000], step[500], loss: 4.2701
# Epoch [107/1000], step[1000], loss: 3.9896
# Train Accuracy:6687/45438
# Test accuracy:1657/15142
#
# Epoch [108/1000], step[500], loss: 4.7368
# Epoch [108/1000], step[1000], loss: 4.5145
# Train Accuracy:6815/45438
# Test accuracy:1688/15142
#
# Epoch [109/1000], step[500], loss: 4.2190
# Epoch [109/1000], step[1000], loss: 3.6787
# Train Accuracy:6996/45438
# Test accuracy:1670/15142
#
# Epoch [110/1000], step[500], loss: 3.7946
# Epoch [110/1000], step[1000], loss: 4.7071
# Train Accuracy:6948/45438
# Test accuracy:1727/15142
#
# Epoch [111/1000], step[500], loss: 4.0613
# Epoch [111/1000], step[1000], loss: 3.8753
# Train Accuracy:7087/45438
# Test accuracy:1723/15142
#
# Epoch [112/1000], step[500], loss: 4.2526
# Epoch [112/1000], step[1000], loss: 4.8642
# Train Accuracy:7264/45438
# Test accuracy:1745/15142
#
# Epoch [113/1000], step[500], loss: 4.1341
# Epoch [113/1000], step[1000], loss: 4.0795
# Train Accuracy:7206/45438
# Test accuracy:1763/15142
#
# Epoch [114/1000], step[500], loss: 3.6335
# Epoch [114/1000], step[1000], loss: 4.3929
# Train Accuracy:7388/45438
# Test accuracy:1700/15142
#
# Epoch [115/1000], step[500], loss: 4.4013
# Epoch [115/1000], step[1000], loss: 4.0740
# Train Accuracy:7457/45438
# Test accuracy:1780/15142
#
# Epoch [116/1000], step[500], loss: 3.6590
# Epoch [116/1000], step[1000], loss: 3.4871
# Train Accuracy:7546/45438
# Test accuracy:1768/15142
#
# Epoch [117/1000], step[500], loss: 3.9404
# Epoch [117/1000], step[1000], loss: 3.9081
# Train Accuracy:7598/45438
# Test accuracy:1803/15142
#
# Epoch [118/1000], step[500], loss: 4.0800
# Epoch [118/1000], step[1000], loss: 3.6058
# Train Accuracy:7778/45438
# Test accuracy:1818/15142
#
# Epoch [119/1000], step[500], loss: 3.8356
# Epoch [119/1000], step[1000], loss: 4.3508
# Train Accuracy:7747/45438
# Test accuracy:1797/15142
#
# Epoch [120/1000], step[500], loss: 4.2991
# Epoch [120/1000], step[1000], loss: 3.6466
# Train Accuracy:7818/45438
# Test accuracy:1873/15142
#
# Epoch [121/1000], step[500], loss: 4.1126
# Epoch [121/1000], step[1000], loss: 4.4660
# Train Accuracy:8104/45438
# Test accuracy:1867/15142
#
# Epoch [122/1000], step[500], loss: 3.4657
# Epoch [122/1000], step[1000], loss: 3.3005
# Train Accuracy:8110/45438
# Test accuracy:1847/15142
#
# Epoch [123/1000], step[500], loss: 3.7202
# Epoch [123/1000], step[1000], loss: 3.7164
# Train Accuracy:8197/45438
# Test accuracy:1899/15142
#
# Epoch [124/1000], step[500], loss: 4.2291
# Epoch [124/1000], step[1000], loss: 3.8001
# Train Accuracy:8371/45438
# Test accuracy:1933/15142
#
# Epoch [125/1000], step[500], loss: 3.7008
# Epoch [125/1000], step[1000], loss: 4.4434
# Train Accuracy:8342/45438
# Test accuracy:1914/15142
#
# Epoch [126/1000], step[500], loss: 4.2896
# Epoch [126/1000], step[1000], loss: 4.3071
# Train Accuracy:8412/45438
# Test accuracy:1893/15142
#
# Epoch [127/1000], step[500], loss: 3.7663
# Epoch [127/1000], step[1000], loss: 4.1101
# Train Accuracy:8432/45438
# Test accuracy:1926/15142
#
# Epoch [128/1000], step[500], loss: 4.1165
# Epoch [128/1000], step[1000], loss: 3.6099
# Train Accuracy:8595/45438
# Test accuracy:1878/15142
#
# Epoch [129/1000], step[500], loss: 4.1028
# Epoch [129/1000], step[1000], loss: 3.9403
# Train Accuracy:8848/45438
# Test accuracy:1918/15142
#
# Epoch [130/1000], step[500], loss: 3.6528
# Epoch [130/1000], step[1000], loss: 3.5698
# Train Accuracy:8675/45438
# Test accuracy:1882/15142
#
# Epoch [131/1000], step[500], loss: 3.9895
# Epoch [131/1000], step[1000], loss: 3.5306
# Train Accuracy:8971/45438
# Test accuracy:1939/15142
#
# Epoch [132/1000], step[500], loss: 4.2565
# Epoch [132/1000], step[1000], loss: 4.1070
# Train Accuracy:8913/45438
# Test accuracy:1935/15142
#
# Epoch [133/1000], step[500], loss: 4.2294
# Epoch [133/1000], step[1000], loss: 3.6773
# Train Accuracy:9014/45438
# Test accuracy:1935/15142
#
# Epoch [134/1000], step[500], loss: 3.9484
# Epoch [134/1000], step[1000], loss: 3.4278
# Train Accuracy:9047/45438
# Test accuracy:1983/15142
#
# Epoch [135/1000], step[500], loss: 3.3261
# Epoch [135/1000], step[1000], loss: 3.8141
# Train Accuracy:9218/45438
# Test accuracy:2036/15142
#
# Epoch [136/1000], step[500], loss: 3.5743
# Epoch [136/1000], step[1000], loss: 4.5087
# Train Accuracy:9250/45438
# Test accuracy:2040/15142
#
# Epoch [137/1000], step[500], loss: 3.8882
# Epoch [137/1000], step[1000], loss: 3.2038
# Train Accuracy:9305/45438
# Test accuracy:2029/15142
#
# Epoch [138/1000], step[500], loss: 3.4886
# Epoch [138/1000], step[1000], loss: 3.8424
# Train Accuracy:9442/45438
# Test accuracy:2029/15142
#
# Epoch [139/1000], step[500], loss: 3.9940
# Epoch [139/1000], step[1000], loss: 3.4326
# Train Accuracy:9484/45438
# Test accuracy:2074/15142
#
# Epoch [140/1000], step[500], loss: 4.1112
# Epoch [140/1000], step[1000], loss: 3.8089
# Train Accuracy:9595/45438
# Test accuracy:2021/15142
#
# Epoch [141/1000], step[500], loss: 3.8248
# Epoch [141/1000], step[1000], loss: 3.1641
# Train Accuracy:9632/45438
# Test accuracy:2076/15142
#
# Epoch [142/1000], step[500], loss: 3.7666
# Epoch [142/1000], step[1000], loss: 3.8684
# Train Accuracy:9735/45438
# Test accuracy:2063/15142
#
# Epoch [143/1000], step[500], loss: 3.6591
# Epoch [143/1000], step[1000], loss: 3.5957
# Train Accuracy:9753/45438
# Test accuracy:2062/15142
#
# Epoch [144/1000], step[500], loss: 3.3428
# Epoch [144/1000], step[1000], loss: 3.5952
# Train Accuracy:9916/45438
# Test accuracy:1999/15142
#
# Epoch [145/1000], step[500], loss: 3.3591
# Epoch [145/1000], step[1000], loss: 3.6469
# Train Accuracy:10102/45438
# Test accuracy:2076/15142
#
# Epoch [146/1000], step[500], loss: 3.6229
# Epoch [146/1000], step[1000], loss: 3.7881
# Train Accuracy:10203/45438
# Test accuracy:2105/15142
#
# Epoch [147/1000], step[500], loss: 3.9457
# Epoch [147/1000], step[1000], loss: 4.0171
# Train Accuracy:10259/45438
# Test accuracy:2082/15142
#
# Epoch [148/1000], step[500], loss: 3.3710
# Epoch [148/1000], step[1000], loss: 3.6505
# Train Accuracy:10246/45438
# Test accuracy:2096/15142
#
# Epoch [149/1000], step[500], loss: 3.8354
# Epoch [149/1000], step[1000], loss: 3.9659
# Train Accuracy:10421/45438
# Test accuracy:2138/15142
#
# Epoch [150/1000], step[500], loss: 2.7659
# Epoch [150/1000], step[1000], loss: 4.0605
# Train Accuracy:10462/45438
# Test accuracy:2161/15142
#
# Epoch [151/1000], step[500], loss: 3.4398
# Epoch [151/1000], step[1000], loss: 3.6150
# Train Accuracy:10489/45438
# Test accuracy:2141/15142
#
# Epoch [152/1000], step[500], loss: 3.3957
# Epoch [152/1000], step[1000], loss: 3.1228
# Train Accuracy:10536/45438
# Test accuracy:2160/15142
#
# Epoch [153/1000], step[500], loss: 3.4541
# Epoch [153/1000], step[1000], loss: 3.8021
# Train Accuracy:10573/45438
# Test accuracy:2186/15142
#
# Epoch [154/1000], step[500], loss: 3.2911
# Epoch [154/1000], step[1000], loss: 3.8947
# Train Accuracy:10722/45438
# Test accuracy:2118/15142
#
# Epoch [155/1000], step[500], loss: 3.0532
# Epoch [155/1000], step[1000], loss: 3.6872
# Train Accuracy:10671/45438
# Test accuracy:2183/15142
#
# Epoch [156/1000], step[500], loss: 3.0268
# Epoch [156/1000], step[1000], loss: 3.1301
# Train Accuracy:10846/45438
# Test accuracy:2158/15142
#
# Epoch [157/1000], step[500], loss: 3.1758
# Epoch [157/1000], step[1000], loss: 2.9610
# Train Accuracy:10939/45438
# Test accuracy:2152/15142
#
# Epoch [158/1000], step[500], loss: 3.8382
# Epoch [158/1000], step[1000], loss: 3.6982
# Train Accuracy:11072/45438
# Test accuracy:2188/15142
#
# Epoch [159/1000], step[500], loss: 3.8071
# Epoch [159/1000], step[1000], loss: 3.2696
# Train Accuracy:11216/45438
# Test accuracy:2233/15142
#
# Epoch [160/1000], step[500], loss: 3.5733
# Epoch [160/1000], step[1000], loss: 3.0107
# Train Accuracy:11311/45438
# Test accuracy:2199/15142
#
# Epoch [161/1000], step[500], loss: 3.4698
# Epoch [161/1000], step[1000], loss: 3.8503
# Train Accuracy:11296/45438
# Test accuracy:2220/15142
#
# Epoch [162/1000], step[500], loss: 3.3245
# Epoch [162/1000], step[1000], loss: 2.9104
# Train Accuracy:11379/45438
# Test accuracy:2255/15142
#
# Epoch [163/1000], step[500], loss: 2.9966
# Epoch [163/1000], step[1000], loss: 3.3176
# Train Accuracy:11455/45438
# Test accuracy:2202/15142
#
# Epoch [164/1000], step[500], loss: 2.8381
# Epoch [164/1000], step[1000], loss: 3.5043
# Train Accuracy:11578/45438
# Test accuracy:2231/15142
#
# Epoch [165/1000], step[500], loss: 3.7421
# Epoch [165/1000], step[1000], loss: 3.4891
# Train Accuracy:11571/45438
# Test accuracy:2222/15142
#
# Epoch [166/1000], step[500], loss: 3.7079
# Epoch [166/1000], step[1000], loss: 3.6920
# Train Accuracy:11667/45438
# Test accuracy:2223/15142
#
# Epoch [167/1000], step[500], loss: 3.5813
# Epoch [167/1000], step[1000], loss: 3.7527
# Train Accuracy:11601/45438
# Test accuracy:2314/15142
#
# Epoch [168/1000], step[500], loss: 2.9941
# Epoch [168/1000], step[1000], loss: 3.5001
# Train Accuracy:11762/45438
# Test accuracy:2232/15142
#
# Epoch [169/1000], step[500], loss: 3.4515
# Epoch [169/1000], step[1000], loss: 3.4157
# Train Accuracy:11976/45438
# Test accuracy:2254/15142
#
# Epoch [170/1000], step[500], loss: 3.1066
# Epoch [170/1000], step[1000], loss: 3.5988
# Train Accuracy:11933/45438
# Test accuracy:2251/15142
#
# Epoch [171/1000], step[500], loss: 3.4301
# Epoch [171/1000], step[1000], loss: 3.7230
# Train Accuracy:12130/45438
# Test accuracy:2293/15142
#
# Epoch [172/1000], step[500], loss: 3.6678
# Epoch [172/1000], step[1000], loss: 3.3062
# Train Accuracy:12060/45438
# Test accuracy:2337/15142
#
# Epoch [173/1000], step[500], loss: 3.2384
# Epoch [173/1000], step[1000], loss: 3.5660
# Train Accuracy:12331/45438
# Test accuracy:2279/15142
#
# Epoch [174/1000], step[500], loss: 2.7936
# Epoch [174/1000], step[1000], loss: 3.2168
# Train Accuracy:12359/45438
# Test accuracy:2322/15142
#
# Epoch [175/1000], step[500], loss: 3.4356
# Epoch [175/1000], step[1000], loss: 3.6376
# Train Accuracy:12364/45438
# Test accuracy:2299/15142
#
# Epoch [176/1000], step[500], loss: 2.9523
# Epoch [176/1000], step[1000], loss: 3.7027
# Train Accuracy:12405/45438
# Test accuracy:2256/15142
#
# Epoch [177/1000], step[500], loss: 2.9941
# Epoch [177/1000], step[1000], loss: 2.5333
# Train Accuracy:12407/45438
# Test accuracy:2338/15142
#
# Epoch [178/1000], step[500], loss: 3.2238
# Epoch [178/1000], step[1000], loss: 3.6991
# Train Accuracy:12537/45438
# Test accuracy:2320/15142
#
# Epoch [179/1000], step[500], loss: 2.8604
# Epoch [179/1000], step[1000], loss: 3.3437
# Train Accuracy:12641/45438
# Test accuracy:2315/15142
#
# Epoch [180/1000], step[500], loss: 3.4896
# Epoch [180/1000], step[1000], loss: 3.5866
# Train Accuracy:12810/45438
# Test accuracy:2344/15142
#
# Epoch [181/1000], step[500], loss: 3.1724
# Epoch [181/1000], step[1000], loss: 2.4972
# Train Accuracy:12721/45438
# Test accuracy:2304/15142
#
# Epoch [182/1000], step[500], loss: 2.7717
# Epoch [182/1000], step[1000], loss: 3.2571
# Train Accuracy:12889/45438
# Test accuracy:2372/15142
#
# Epoch [183/1000], step[500], loss: 3.3003
# Epoch [183/1000], step[1000], loss: 3.7615
# Train Accuracy:12985/45438
# Test accuracy:2320/15142
#
# Epoch [184/1000], step[500], loss: 2.7788
# Epoch [184/1000], step[1000], loss: 3.4835
# Train Accuracy:12811/45438
# Test accuracy:2328/15142
#
# Epoch [185/1000], step[500], loss: 2.2223
# Epoch [185/1000], step[1000], loss: 3.3335
# Train Accuracy:13022/45438
# Test accuracy:2361/15142
#
# Epoch [186/1000], step[500], loss: 2.9715
# Epoch [186/1000], step[1000], loss: 3.3326
# Train Accuracy:13072/45438
# Test accuracy:2349/15142
#
# Epoch [187/1000], step[500], loss: 3.0097
# Epoch [187/1000], step[1000], loss: 2.3631
# Train Accuracy:13242/45438
# Test accuracy:2325/15142
#
# Epoch [188/1000], step[500], loss: 3.2222
# Epoch [188/1000], step[1000], loss: 3.3714
# Train Accuracy:13232/45438
# Test accuracy:2324/15142
#
# Epoch [189/1000], step[500], loss: 3.5414
# Epoch [189/1000], step[1000], loss: 2.6926
# Train Accuracy:13219/45438
# Test accuracy:2346/15142
#
# Epoch [190/1000], step[500], loss: 3.7818
# Epoch [190/1000], step[1000], loss: 3.2964
# Train Accuracy:13313/45438
# Test accuracy:2338/15142
#
# Epoch [191/1000], step[500], loss: 3.0132
# Epoch [191/1000], step[1000], loss: 3.7171
# Train Accuracy:13473/45438
# Test accuracy:2374/15142
#
# Epoch [192/1000], step[500], loss: 3.2673
# Epoch [192/1000], step[1000], loss: 3.0510
# Train Accuracy:13584/45438
# Test accuracy:2356/15142
#
# Epoch [193/1000], step[500], loss: 3.1259
# Epoch [193/1000], step[1000], loss: 2.7103
# Train Accuracy:13530/45438
# Test accuracy:2397/15142
#
# Epoch [194/1000], step[500], loss: 2.8735
# Epoch [194/1000], step[1000], loss: 2.2614
# Train Accuracy:13707/45438
# Test accuracy:2362/15142
#
# Epoch [195/1000], step[500], loss: 2.7823
# Epoch [195/1000], step[1000], loss: 2.4689
# Train Accuracy:13675/45438
# Test accuracy:2364/15142
#
# Epoch [196/1000], step[500], loss: 3.7483
# Epoch [196/1000], step[1000], loss: 2.7123
# Train Accuracy:13862/45438
# Test accuracy:2384/15142
#
# Epoch [197/1000], step[500], loss: 3.0919
# Epoch [197/1000], step[1000], loss: 3.1138
# Train Accuracy:13838/45438
# Test accuracy:2377/15142
#
# Epoch [198/1000], step[500], loss: 3.3576
# Epoch [198/1000], step[1000], loss: 3.7257
# Train Accuracy:13827/45438
# Test accuracy:2403/15142
#
# Epoch [199/1000], step[500], loss: 3.1256
# Epoch [199/1000], step[1000], loss: 2.8060
# Train Accuracy:14005/45438
# Test accuracy:2408/15142
#
# Epoch [200/1000], step[500], loss: 2.9183
# Epoch [200/1000], step[1000], loss: 3.0877
# Train Accuracy:14092/45438
# Test accuracy:2436/15142
#
# Epoch [201/1000], step[500], loss: 2.3450
# Epoch [201/1000], step[1000], loss: 3.6450
# Train Accuracy:14183/45438
# Test accuracy:2407/15142
#
# Epoch [202/1000], step[500], loss: 3.0901
# Epoch [202/1000], step[1000], loss: 2.5387
# Train Accuracy:14176/45438
# Test accuracy:2438/15142
#
# Epoch [203/1000], step[500], loss: 2.8336
# Epoch [203/1000], step[1000], loss: 2.4181
# Train Accuracy:14156/45438
# Test accuracy:2390/15142
#
# Epoch [204/1000], step[500], loss: 2.9397
# Epoch [204/1000], step[1000], loss: 3.0097
# Train Accuracy:14171/45438
# Test accuracy:2394/15142
#
# Epoch [205/1000], step[500], loss: 3.4419
# Epoch [205/1000], step[1000], loss: 3.2314
# Train Accuracy:14312/45438
# Test accuracy:2390/15142
#
# Epoch [206/1000], step[500], loss: 3.1472
# Epoch [206/1000], step[1000], loss: 2.7619
# Train Accuracy:14666/45438
# Test accuracy:2434/15142
#
# Epoch [207/1000], step[500], loss: 2.8933
# Epoch [207/1000], step[1000], loss: 3.3168
# Train Accuracy:14500/45438
# Test accuracy:2410/15142
#
# Epoch [208/1000], step[500], loss: 2.9056
# Epoch [208/1000], step[1000], loss: 2.8816
# Train Accuracy:14478/45438
# Test accuracy:2447/15142
#
# Epoch [209/1000], step[500], loss: 3.0218
# Epoch [209/1000], step[1000], loss: 3.0263
# Train Accuracy:14599/45438
# Test accuracy:2470/15142
#
# Epoch [210/1000], step[500], loss: 3.7158
# Epoch [210/1000], step[1000], loss: 2.8252
# Train Accuracy:14784/45438
# Test accuracy:2455/15142
#
# Epoch [211/1000], step[500], loss: 2.8858
# Epoch [211/1000], step[1000], loss: 3.4955
# Train Accuracy:14869/45438
# Test accuracy:2482/15142
#
# Epoch [212/1000], step[500], loss: 3.2517
# Epoch [212/1000], step[1000], loss: 2.5497
# Train Accuracy:14824/45438
# Test accuracy:2405/15142
#
# Epoch [213/1000], step[500], loss: 2.4773
# Epoch [213/1000], step[1000], loss: 3.1295
# Train Accuracy:14896/45438
# Test accuracy:2451/15142
#
# Epoch [214/1000], step[500], loss: 2.6139
# Epoch [214/1000], step[1000], loss: 2.7478
# Train Accuracy:14923/45438
# Test accuracy:2456/15142
#
# Epoch [215/1000], step[500], loss: 2.9513
# Epoch [215/1000], step[1000], loss: 2.8344
# Train Accuracy:15064/45438
# Test accuracy:2413/15142
#
# Epoch [216/1000], step[500], loss: 2.9423
# Epoch [216/1000], step[1000], loss: 2.9336
# Train Accuracy:15047/45438
# Test accuracy:2457/15142
#
# Epoch [217/1000], step[500], loss: 3.0410
# Epoch [217/1000], step[1000], loss: 2.4868
# Train Accuracy:15137/45438
# Test accuracy:2447/15142
#
# Epoch [218/1000], step[500], loss: 2.2507
# Epoch [218/1000], step[1000], loss: 3.1632
# Train Accuracy:15257/45438
# Test accuracy:2472/15142
#
# Epoch [219/1000], step[500], loss: 3.0395
# Epoch [219/1000], step[1000], loss: 3.5972
# Train Accuracy:15268/45438
# Test accuracy:2414/15142
#
# Epoch [220/1000], step[500], loss: 2.6456
# Epoch [220/1000], step[1000], loss: 2.6399
# Train Accuracy:15292/45438
# Test accuracy:2445/15142
#
# Epoch [221/1000], step[500], loss: 2.7769
# Epoch [221/1000], step[1000], loss: 3.2361
# Train Accuracy:15547/45438
# Test accuracy:2464/15142
#
# Epoch [222/1000], step[500], loss: 2.7396
# Epoch [222/1000], step[1000], loss: 3.5013
# Train Accuracy:15476/45438
# Test accuracy:2489/15142
#
# Epoch [223/1000], step[500], loss: 2.9266
# Epoch [223/1000], step[1000], loss: 2.6189
# Train Accuracy:15598/45438
# Test accuracy:2478/15142
#
# Epoch [224/1000], step[500], loss: 2.8508
# Epoch [224/1000], step[1000], loss: 3.0380
# Train Accuracy:15626/45438
# Test accuracy:2484/15142
#
# Epoch [225/1000], step[500], loss: 2.9578
# Epoch [225/1000], step[1000], loss: 2.4171
# Train Accuracy:15546/45438
# Test accuracy:2462/15142
#
# Epoch [226/1000], step[500], loss: 2.8217
# Epoch [226/1000], step[1000], loss: 2.7605
# Train Accuracy:15826/45438
# Test accuracy:2440/15142
#
# Epoch [227/1000], step[500], loss: 2.8445
# Epoch [227/1000], step[1000], loss: 2.7516
# Train Accuracy:15934/45438
# Test accuracy:2464/15142
#
# Epoch [228/1000], step[500], loss: 2.7129
# Epoch [228/1000], step[1000], loss: 2.8972
# Train Accuracy:15877/45438
# Test accuracy:2493/15142
#
# Epoch [229/1000], step[500], loss: 3.4925
# Epoch [229/1000], step[1000], loss: 2.8361
# Train Accuracy:15896/45438
# Test accuracy:2536/15142
#
# Epoch [230/1000], step[500], loss: 2.6420
# Epoch [230/1000], step[1000], loss: 2.4498
# Train Accuracy:16037/45438
# Test accuracy:2466/15142
#
# Epoch [231/1000], step[500], loss: 3.2782
# Epoch [231/1000], step[1000], loss: 2.9974
# Train Accuracy:16054/45438
# Test accuracy:2497/15142
#
# Epoch [232/1000], step[500], loss: 2.7092
# Epoch [232/1000], step[1000], loss: 2.4759
# Train Accuracy:15970/45438
# Test accuracy:2474/15142
#
# Epoch [233/1000], step[500], loss: 2.7779
# Epoch [233/1000], step[1000], loss: 2.2291
# Train Accuracy:16077/45438
# Test accuracy:2370/15142
#
# Epoch [234/1000], step[500], loss: 2.6951
# Epoch [234/1000], step[1000], loss: 3.2128
# Train Accuracy:16068/45438
# Test accuracy:2480/15142
#
# Epoch [235/1000], step[500], loss: 2.2753
# Epoch [235/1000], step[1000], loss: 2.8724
# Train Accuracy:16208/45438
# Test accuracy:2467/15142
#
# Epoch [236/1000], step[500], loss: 2.7431
# Epoch [236/1000], step[1000], loss: 3.0623
# Train Accuracy:16314/45438
# Test accuracy:2472/15142
#
# Epoch [237/1000], step[500], loss: 2.3395
# Epoch [237/1000], step[1000], loss: 3.0982
# Train Accuracy:16390/45438
# Test accuracy:2447/15142
#
# Epoch [238/1000], step[500], loss: 2.5193
# Epoch [238/1000], step[1000], loss: 2.7849
# Train Accuracy:16476/45438
# Test accuracy:2465/15142
#
# Epoch [239/1000], step[500], loss: 2.9324
# Epoch [239/1000], step[1000], loss: 2.2817
# Train Accuracy:16405/45438
# Test accuracy:2461/15142
#
# Epoch [240/1000], step[500], loss: 3.2676
# Epoch [240/1000], step[1000], loss: 3.2262
# Train Accuracy:16426/45438
# Test accuracy:2476/15142
#
# Epoch [241/1000], step[500], loss: 2.7967
# Epoch [241/1000], step[1000], loss: 2.9128
# Train Accuracy:16478/45438
# Test accuracy:2447/15142
#
# Epoch [242/1000], step[500], loss: 2.4497
# Epoch [242/1000], step[1000], loss: 2.7566
# Train Accuracy:16514/45438
# Test accuracy:2430/15142
#
# Epoch [243/1000], step[500], loss: 3.0736
# Epoch [243/1000], step[1000], loss: 2.3285
# Train Accuracy:16631/45438
# Test accuracy:2459/15142
#
# Epoch [244/1000], step[500], loss: 2.9965
# Epoch [244/1000], step[1000], loss: 2.9921
# Train Accuracy:17006/45438
# Test accuracy:2497/15142
#
# Epoch [245/1000], step[500], loss: 2.7331
# Epoch [245/1000], step[1000], loss: 3.0564
# Train Accuracy:16868/45438
# Test accuracy:2501/15142
#
# Epoch [246/1000], step[500], loss: 2.6336
# Epoch [246/1000], step[1000], loss: 2.3119
# Train Accuracy:16853/45438
# Test accuracy:2502/15142
#
# Epoch [247/1000], step[500], loss: 2.6012
# Epoch [247/1000], step[1000], loss: 3.1706
# Train Accuracy:16878/45438
# Test accuracy:2534/15142
#
# Epoch [248/1000], step[500], loss: 2.5925
# Epoch [248/1000], step[1000], loss: 2.7157
# Train Accuracy:16903/45438
# Test accuracy:2445/15142
#
# Epoch [249/1000], step[500], loss: 2.9630
# Epoch [249/1000], step[1000], loss: 2.2976
# Train Accuracy:17048/45438
# Test accuracy:2493/15142
#
# Epoch [250/1000], step[500], loss: 2.7019
# Epoch [250/1000], step[1000], loss: 3.3816
# Train Accuracy:17002/45438
# Test accuracy:2551/15142
#
# Epoch [251/1000], step[500], loss: 2.7582
# Epoch [251/1000], step[1000], loss: 2.3703
# Train Accuracy:17266/45438
# Test accuracy:2547/15142
#
# Epoch [252/1000], step[500], loss: 2.3688
# Epoch [252/1000], step[1000], loss: 2.5765
# Train Accuracy:17139/45438
# Test accuracy:2532/15142
#
# Epoch [253/1000], step[500], loss: 3.9495
# Epoch [253/1000], step[1000], loss: 2.6530
# Train Accuracy:17152/45438
# Test accuracy:2563/15142
#
# Epoch [254/1000], step[500], loss: 3.0124
# Epoch [254/1000], step[1000], loss: 2.6534
# Train Accuracy:17335/45438
# Test accuracy:2547/15142
#
# Epoch [255/1000], step[500], loss: 2.4359
# Epoch [255/1000], step[1000], loss: 2.7067
# Train Accuracy:17242/45438
# Test accuracy:2524/15142
#
# Epoch [256/1000], step[500], loss: 2.0835
# Epoch [256/1000], step[1000], loss: 2.7669
# Train Accuracy:17550/45438
# Test accuracy:2519/15142
#
# Epoch [257/1000], step[500], loss: 2.1602
# Epoch [257/1000], step[1000], loss: 3.2644
# Train Accuracy:17448/45438
# Test accuracy:2460/15142
#
# Epoch [258/1000], step[500], loss: 2.9237
# Epoch [258/1000], step[1000], loss: 2.8022
# Train Accuracy:17425/45438
# Test accuracy:2506/15142
#
# Epoch [259/1000], step[500], loss: 2.1508
# Epoch [259/1000], step[1000], loss: 2.8036
# Train Accuracy:17437/45438
# Test accuracy:2516/15142
#
# Epoch [260/1000], step[500], loss: 3.2814
# Epoch [260/1000], step[1000], loss: 2.3949
# Train Accuracy:17664/45438
# Test accuracy:2526/15142
#
# Epoch [261/1000], step[500], loss: 2.8639
# Epoch [261/1000], step[1000], loss: 2.0502
# Train Accuracy:17733/45438
# Test accuracy:2516/15142
#
# Epoch [262/1000], step[500], loss: 3.0613
# Epoch [262/1000], step[1000], loss: 2.6521
# Train Accuracy:17675/45438
# Test accuracy:2564/15142
#
# Epoch [263/1000], step[500], loss: 1.8387
# Epoch [263/1000], step[1000], loss: 2.3856
# Train Accuracy:17764/45438
# Test accuracy:2540/15142
#
# Epoch [264/1000], step[500], loss: 1.9076
# Epoch [264/1000], step[1000], loss: 2.7694
# Train Accuracy:17804/45438
# Test accuracy:2527/15142
#
# Epoch [265/1000], step[500], loss: 2.2336
# Epoch [265/1000], step[1000], loss: 2.7847
# Train Accuracy:17801/45438
# Test accuracy:2518/15142
#
# Epoch [266/1000], step[500], loss: 2.4442
# Epoch [266/1000], step[1000], loss: 2.0018
# Train Accuracy:17834/45438
# Test accuracy:2525/15142
#
# Epoch [267/1000], step[500], loss: 2.1847
# Epoch [267/1000], step[1000], loss: 2.9063
# Train Accuracy:18029/45438
# Test accuracy:2506/15142
#
# Epoch [268/1000], step[500], loss: 2.7332
# Epoch [268/1000], step[1000], loss: 2.6378
# Train Accuracy:17967/45438
# Test accuracy:2580/15142
#
# Epoch [269/1000], step[500], loss: 2.4670
# Epoch [269/1000], step[1000], loss: 2.2334
# Train Accuracy:18037/45438
# Test accuracy:2540/15142
#
# Epoch [270/1000], step[500], loss: 3.0861
# Epoch [270/1000], step[1000], loss: 3.0295
# Train Accuracy:18095/45438
# Test accuracy:2535/15142
#
# Epoch [271/1000], step[500], loss: 2.5560
# Epoch [271/1000], step[1000], loss: 2.8045
# Train Accuracy:18073/45438
# Test accuracy:2516/15142
#
# Epoch [272/1000], step[500], loss: 2.7042
# Epoch [272/1000], step[1000], loss: 2.3745
# Train Accuracy:18381/45438
# Test accuracy:2553/15142
#
# Epoch [273/1000], step[500], loss: 2.6282
# Epoch [273/1000], step[1000], loss: 3.1607
# Train Accuracy:18223/45438
# Test accuracy:2574/15142
#
# Epoch [274/1000], step[500], loss: 2.3395
# Epoch [274/1000], step[1000], loss: 1.9078
# Train Accuracy:18179/45438
# Test accuracy:2521/15142
#
# Epoch [275/1000], step[500], loss: 2.1775
# Epoch [275/1000], step[1000], loss: 2.0491
# Train Accuracy:18440/45438
# Test accuracy:2589/15142
#
# Epoch [276/1000], step[500], loss: 2.4557
# Epoch [276/1000], step[1000], loss: 2.7076
# Train Accuracy:18254/45438
# Test accuracy:2614/15142
#
# Epoch [277/1000], step[500], loss: 2.0824
# Epoch [277/1000], step[1000], loss: 3.1163
# Train Accuracy:18619/45438
# Test accuracy:2569/15142
#
# Epoch [278/1000], step[500], loss: 2.3301
# Epoch [278/1000], step[1000], loss: 2.4250
# Train Accuracy:18620/45438
# Test accuracy:2533/15142
#
# Epoch [279/1000], step[500], loss: 2.4471
# Epoch [279/1000], step[1000], loss: 2.6169
# Train Accuracy:18688/45438
# Test accuracy:2539/15142
#
# Epoch [280/1000], step[500], loss: 2.6866
# Epoch [280/1000], step[1000], loss: 2.4395
# Train Accuracy:18585/45438
# Test accuracy:2564/15142
#
# Epoch [281/1000], step[500], loss: 2.1841
# Epoch [281/1000], step[1000], loss: 2.3808
# Train Accuracy:18697/45438
# Test accuracy:2559/15142
#
# Epoch [282/1000], step[500], loss: 1.9643
# Epoch [282/1000], step[1000], loss: 2.2592
# Train Accuracy:18855/45438
# Test accuracy:2561/15142
#
# Epoch [283/1000], step[500], loss: 2.2973
# Epoch [283/1000], step[1000], loss: 2.3677
# Train Accuracy:18861/45438
# Test accuracy:2537/15142
#
# Epoch [284/1000], step[500], loss: 2.9988
# Epoch [284/1000], step[1000], loss: 2.6964
# Train Accuracy:18803/45438
# Test accuracy:2559/15142
#
# Epoch [285/1000], step[500], loss: 2.7597
# Epoch [285/1000], step[1000], loss: 2.3711
# Train Accuracy:18873/45438
# Test accuracy:2476/15142
#
# Epoch [286/1000], step[500], loss: 2.2244
# Epoch [286/1000], step[1000], loss: 2.1732
# Train Accuracy:18880/45438
# Test accuracy:2568/15142
#
# Epoch [287/1000], step[500], loss: 2.5951
# Epoch [287/1000], step[1000], loss: 2.3370
# Train Accuracy:18857/45438
# Test accuracy:2552/15142
#
# Epoch [288/1000], step[500], loss: 2.2475
# Epoch [288/1000], step[1000], loss: 2.5336
# Train Accuracy:18907/45438
# Test accuracy:2534/15142
#
# Epoch [289/1000], step[500], loss: 2.2180
# Epoch [289/1000], step[1000], loss: 2.0389
# Train Accuracy:19026/45438
# Test accuracy:2514/15142
#
# Epoch [290/1000], step[500], loss: 2.0966
# Epoch [290/1000], step[1000], loss: 2.5392
# Train Accuracy:19047/45438
# Test accuracy:2571/15142
#
# Epoch [291/1000], step[500], loss: 2.2617
# Epoch [291/1000], step[1000], loss: 2.3247
# Train Accuracy:19181/45438
# Test accuracy:2513/15142
#
# Epoch [292/1000], step[500], loss: 2.2091
# Epoch [292/1000], step[1000], loss: 2.2539
# Train Accuracy:19296/45438
# Test accuracy:2580/15142
#
# Epoch [293/1000], step[500], loss: 2.7574
# Epoch [293/1000], step[1000], loss: 2.2760
# Train Accuracy:19184/45438
# Test accuracy:2588/15142
#
# Epoch [294/1000], step[500], loss: 2.7107
# Epoch [294/1000], step[1000], loss: 2.3435
# Train Accuracy:19182/45438
# Test accuracy:2609/15142
#
# Epoch [295/1000], step[500], loss: 2.3167
# Epoch [295/1000], step[1000], loss: 2.0020
# Train Accuracy:19268/45438
# Test accuracy:2543/15142
#
# Epoch [296/1000], step[500], loss: 1.7172
# Epoch [296/1000], step[1000], loss: 2.2352
# Train Accuracy:19356/45438
# Test accuracy:2606/15142
#
# Epoch [297/1000], step[500], loss: 2.5475
# Epoch [297/1000], step[1000], loss: 2.4440
# Train Accuracy:19507/45438
# Test accuracy:2563/15142
#
# Epoch [298/1000], step[500], loss: 2.9712
# Epoch [298/1000], step[1000], loss: 2.5072
# Train Accuracy:19421/45438
# Test accuracy:2572/15142
#
# Epoch [299/1000], step[500], loss: 2.6215
# Epoch [299/1000], step[1000], loss: 2.4660
# Train Accuracy:19588/45438
# Test accuracy:2650/15142
#
# Epoch [300/1000], step[500], loss: 2.0749
# Epoch [300/1000], step[1000], loss: 2.1212
# Train Accuracy:19570/45438
# Test accuracy:2567/15142
#
# Epoch [301/1000], step[500], loss: 2.6113
# Epoch [301/1000], step[1000], loss: 2.5528
# Train Accuracy:19545/45438
# Test accuracy:2535/15142
#
# Epoch [302/1000], step[500], loss: 2.7716
# Epoch [302/1000], step[1000], loss: 1.7970
# Train Accuracy:19653/45438
# Test accuracy:2618/15142
#
# Epoch [303/1000], step[500], loss: 2.0934
# Epoch [303/1000], step[1000], loss: 2.4271
# Train Accuracy:19719/45438
# Test accuracy:2558/15142
#
# Epoch [304/1000], step[500], loss: 2.3568
# Epoch [304/1000], step[1000], loss: 2.4279
# Train Accuracy:19527/45438
# Test accuracy:2603/15142
#
# Epoch [305/1000], step[500], loss: 2.3035
# Epoch [305/1000], step[1000], loss: 2.0818
# Train Accuracy:19814/45438
# Test accuracy:2539/15142
#
# Epoch [306/1000], step[500], loss: 1.9218
# Epoch [306/1000], step[1000], loss: 2.1202
# Train Accuracy:19907/45438
# Test accuracy:2564/15142
#
# Epoch [307/1000], step[500], loss: 2.4429
# Epoch [307/1000], step[1000], loss: 2.2281
# Train Accuracy:19875/45438
# Test accuracy:2567/15142
#
# Epoch [308/1000], step[500], loss: 2.1543
# Epoch [308/1000], step[1000], loss: 1.9826
# Train Accuracy:19754/45438
# Test accuracy:2611/15142
#
# Epoch [309/1000], step[500], loss: 2.0811
# Epoch [309/1000], step[1000], loss: 2.3490
# Train Accuracy:19902/45438
# Test accuracy:2592/15142
#
# Epoch [310/1000], step[500], loss: 2.3938
# Epoch [310/1000], step[1000], loss: 2.2318
# Train Accuracy:19956/45438
# Test accuracy:2531/15142
#
# Epoch [311/1000], step[500], loss: 2.5274
# Epoch [311/1000], step[1000], loss: 1.9416
# Train Accuracy:19994/45438
# Test accuracy:2582/15142
#
# Epoch [312/1000], step[500], loss: 2.9907
# Epoch [312/1000], step[1000], loss: 1.9950
# Train Accuracy:20009/45438
# Test accuracy:2606/15142
#
# Epoch [313/1000], step[500], loss: 2.4210
# Epoch [313/1000], step[1000], loss: 2.0230
# Train Accuracy:20033/45438
# Test accuracy:2572/15142
#
# Epoch [314/1000], step[500], loss: 1.8321
# Epoch [314/1000], step[1000], loss: 3.1362
# Train Accuracy:20068/45438
# Test accuracy:2580/15142
#
# Epoch [315/1000], step[500], loss: 2.0342
# Epoch [315/1000], step[1000], loss: 2.0725
# Train Accuracy:20140/45438
# Test accuracy:2586/15142
#
# Epoch [316/1000], step[500], loss: 1.8569
# Epoch [316/1000], step[1000], loss: 2.5488
# Train Accuracy:20250/45438
# Test accuracy:2626/15142
#
# Epoch [317/1000], step[500], loss: 1.6393
# Epoch [317/1000], step[1000], loss: 1.8773
# Train Accuracy:20334/45438
# Test accuracy:2562/15142
#
# Epoch [318/1000], step[500], loss: 1.9193
# Epoch [318/1000], step[1000], loss: 2.8205
# Train Accuracy:20381/45438
# Test accuracy:2533/15142
#
# Epoch [319/1000], step[500], loss: 2.1445
# Epoch [319/1000], step[1000], loss: 2.4962
# Train Accuracy:20262/45438
# Test accuracy:2589/15142
#
# Epoch [320/1000], step[500], loss: 2.6958
# Epoch [320/1000], step[1000], loss: 1.8412
# Train Accuracy:20323/45438
# Test accuracy:2588/15142
#
# Epoch [321/1000], step[500], loss: 2.4007
# Epoch [321/1000], step[1000], loss: 1.6053
# Train Accuracy:20365/45438
# Test accuracy:2587/15142
#
# Epoch [322/1000], step[500], loss: 2.0331
# Epoch [322/1000], step[1000], loss: 1.9548
# Train Accuracy:20322/45438
# Test accuracy:2610/15142
#
# Epoch [323/1000], step[500], loss: 2.4362
# Epoch [323/1000], step[1000], loss: 2.3795
# Train Accuracy:20342/45438
# Test accuracy:2581/15142
#
# Epoch [324/1000], step[500], loss: 1.5903
# Epoch [324/1000], step[1000], loss: 2.3393
# Train Accuracy:20483/45438
# Test accuracy:2599/15142
#
# Epoch [325/1000], step[500], loss: 2.4708
# Epoch [325/1000], step[1000], loss: 1.9288
# Train Accuracy:20789/45438
# Test accuracy:2590/15142
#
# Epoch [326/1000], step[500], loss: 1.9746
# Epoch [326/1000], step[1000], loss: 1.8555
# Train Accuracy:20557/45438
# Test accuracy:2592/15142
#
# Epoch [327/1000], step[500], loss: 1.1809
# Epoch [327/1000], step[1000], loss: 2.3482
# Train Accuracy:20732/45438
# Test accuracy:2595/15142
#
# Epoch [328/1000], step[500], loss: 2.0380
# Epoch [328/1000], step[1000], loss: 2.8018
# Train Accuracy:20842/45438
# Test accuracy:2628/15142
#
# Epoch [329/1000], step[500], loss: 2.1520
# Epoch [329/1000], step[1000], loss: 2.4402
# Train Accuracy:20736/45438
# Test accuracy:2602/15142
#
# Epoch [330/1000], step[500], loss: 2.4805
# Epoch [330/1000], step[1000], loss: 2.3718
# Train Accuracy:20770/45438
# Test accuracy:2532/15142
#
# Epoch [331/1000], step[500], loss: 1.4584
# Epoch [331/1000], step[1000], loss: 2.1167
# Train Accuracy:20923/45438
# Test accuracy:2581/15142
#
# Epoch [332/1000], step[500], loss: 2.0771
# Epoch [332/1000], step[1000], loss: 2.0369
# Train Accuracy:20940/45438
# Test accuracy:2643/15142
#
# Epoch [333/1000], step[500], loss: 2.2485
# Epoch [333/1000], step[1000], loss: 2.2618
# Train Accuracy:20968/45438
# Test accuracy:2574/15142
#
# Epoch [334/1000], step[500], loss: 1.9252
# Epoch [334/1000], step[1000], loss: 2.5501
# Train Accuracy:20863/45438
# Test accuracy:2620/15142
#
# Epoch [335/1000], step[500], loss: 2.2892
# Epoch [335/1000], step[1000], loss: 1.8994
# Train Accuracy:20928/45438
# Test accuracy:2601/15142
#
# Epoch [336/1000], step[500], loss: 2.7049
# Epoch [336/1000], step[1000], loss: 3.0499
# Train Accuracy:20895/45438
# Test accuracy:2618/15142
#
# Epoch [337/1000], step[500], loss: 2.4948
# Epoch [337/1000], step[1000], loss: 2.2393
# Train Accuracy:21134/45438
# Test accuracy:2604/15142
#
# Epoch [338/1000], step[500], loss: 2.1995
# Epoch [338/1000], step[1000], loss: 1.9345
# Train Accuracy:21067/45438
# Test accuracy:2636/15142
#
# Epoch [339/1000], step[500], loss: 2.3133
# Epoch [339/1000], step[1000], loss: 2.1753
# Train Accuracy:21115/45438
# Test accuracy:2623/15142
#
# Epoch [340/1000], step[500], loss: 2.6754
# Epoch [340/1000], step[1000], loss: 1.9392
# Train Accuracy:21185/45438
# Test accuracy:2618/15142
#
# Epoch [341/1000], step[500], loss: 1.9500
# Epoch [341/1000], step[1000], loss: 2.0600
# Train Accuracy:21012/45438
# Test accuracy:2627/15142
#
# Epoch [342/1000], step[500], loss: 2.3718
# Epoch [342/1000], step[1000], loss: 1.6031
# Train Accuracy:21235/45438
# Test accuracy:2621/15142
#
# Epoch [343/1000], step[500], loss: 2.0417
# Epoch [343/1000], step[1000], loss: 2.1285
# Train Accuracy:21388/45438
# Test accuracy:2595/15142
#
# Epoch [344/1000], step[500], loss: 2.5437
# Epoch [344/1000], step[1000], loss: 2.4560
# Train Accuracy:21235/45438
# Test accuracy:2576/15142
#
# Epoch [345/1000], step[500], loss: 2.2060
# Epoch [345/1000], step[1000], loss: 1.9105
# Train Accuracy:21413/45438
# Test accuracy:2619/15142
#
# Epoch [346/1000], step[500], loss: 2.0824
# Epoch [346/1000], step[1000], loss: 1.4073
# Train Accuracy:21441/45438
# Test accuracy:2624/15142
#
# Epoch [347/1000], step[500], loss: 1.9894
# Epoch [347/1000], step[1000], loss: 2.7491
# Train Accuracy:21512/45438
# Test accuracy:2608/15142
#
# Epoch [348/1000], step[500], loss: 1.9526
# Epoch [348/1000], step[1000], loss: 2.3195
# Train Accuracy:21439/45438
# Test accuracy:2584/15142
#
# Epoch [349/1000], step[500], loss: 2.1498
# Epoch [349/1000], step[1000], loss: 1.7073
# Train Accuracy:21539/45438
# Test accuracy:2621/15142
#
# Epoch [350/1000], step[500], loss: 2.4026
# Epoch [350/1000], step[1000], loss: 1.5500
# Train Accuracy:21534/45438
# Test accuracy:2645/15142
#
# Epoch [351/1000], step[500], loss: 1.9477
# Epoch [351/1000], step[1000], loss: 2.7331
# Train Accuracy:21657/45438
# Test accuracy:2590/15142
#
# Epoch [352/1000], step[500], loss: 1.5937
# ...
# Epoch [885/1000], step[1000], loss: 1.4895
# Train Accuracy:31597/45438
# Test accuracy:2813/15142
#
# Epoch [886/1000], step[500], loss: 0.6566
# Epoch [886/1000], step[1000], loss: 0.7572
# Train Accuracy:31778/45438
# Test accuracy:2811/15142
#
# Epoch [887/1000], step[500], loss: 1.0330
# Epoch [887/1000], step[1000], loss: 0.7340
# Train Accuracy:31715/45438
# Test accuracy:2775/15142
#
# Epoch [888/1000], step[500], loss: 1.6368
# Epoch [888/1000], step[1000], loss: 1.2943
# Train Accuracy:31776/45438
# Test accuracy:2754/15142
#
# Epoch [889/1000], step[500], loss: 1.4878
# Epoch [889/1000], step[1000], loss: 1.1306
# Train Accuracy:31590/45438
# Test accuracy:2733/15142
#
# Epoch [890/1000], step[500], loss: 1.0497
# Epoch [890/1000], step[1000], loss: 1.0749
# Train Accuracy:31930/45438
# Test accuracy:2812/15142
#
# Epoch [891/1000], step[500], loss: 0.7281
# Epoch [891/1000], step[1000], loss: 0.7624
# Train Accuracy:31741/45438
# Test accuracy:2826/15142
#
# Epoch [892/1000], step[500], loss: 1.3101
# Epoch [892/1000], step[1000], loss: 0.6775
# Train Accuracy:31888/45438
# Test accuracy:2821/15142
#
# Epoch [893/1000], step[500], loss: 0.7615
# Epoch [893/1000], step[1000], loss: 0.7309
# Train Accuracy:31764/45438
# Test accuracy:2749/15142
#
# Epoch [894/1000], step[500], loss: 1.2908
# Epoch [894/1000], step[1000], loss: 1.0811
# Train Accuracy:31758/45438
# Test accuracy:2778/15142
#
# Epoch [895/1000], step[500], loss: 1.4603
# Epoch [895/1000], step[1000], loss: 0.8078
# Train Accuracy:31649/45438
# Test accuracy:2815/15142
#
# Epoch [896/1000], step[500], loss: 1.1801
# Epoch [896/1000], step[1000], loss: 1.1850
# Train Accuracy:31790/45438
# Test accuracy:2814/15142
#
# Epoch [897/1000], step[500], loss: 0.9127
# Epoch [897/1000], step[1000], loss: 0.9391
# Train Accuracy:32101/45438
# Test accuracy:2762/15142
#
# Epoch [898/1000], step[500], loss: 0.7697
# Epoch [898/1000], step[1000], loss: 1.0087
# Train Accuracy:31766/45438
# Test accuracy:2806/15142
#
# Epoch [899/1000], step[500], loss: 1.1782
# Epoch [899/1000], step[1000], loss: 1.1941
# Train Accuracy:31897/45438
# Test accuracy:2820/15142
#
# Epoch [900/1000], step[500], loss: 1.2107
# Epoch [900/1000], step[1000], loss: 1.2819
# Train Accuracy:31900/45438
# Test accuracy:2748/15142
#
# Epoch [901/1000], step[500], loss: 0.9110
# Epoch [901/1000], step[1000], loss: 0.7090
# Train Accuracy:31976/45438
# Test accuracy:2793/15142
#
# Epoch [902/1000], step[500], loss: 1.4884
# Epoch [902/1000], step[1000], loss: 0.8210
# Train Accuracy:31820/45438
# Test accuracy:2847/15142
#
# Epoch [903/1000], step[500], loss: 1.0357
# Epoch [903/1000], step[1000], loss: 1.3291
# Train Accuracy:31934/45438
# Test accuracy:2806/15142
#
# Epoch [904/1000], step[500], loss: 0.8659
# Epoch [904/1000], step[1000], loss: 0.8116
# Train Accuracy:31752/45438
# Test accuracy:2834/15142
#
# Epoch [905/1000], step[500], loss: 1.4081
# Epoch [905/1000], step[1000], loss: 0.7659
# Train Accuracy:31739/45438
# Test accuracy:2811/15142
#
# Epoch [906/1000], step[500], loss: 1.1020
# Epoch [906/1000], step[1000], loss: 1.2320
# Train Accuracy:31823/45438
# Test accuracy:2797/15142
#
# Epoch [907/1000], step[500], loss: 0.9130
# Epoch [907/1000], step[1000], loss: 1.1985
# Train Accuracy:31820/45438
# Test accuracy:2823/15142
#
# Epoch [908/1000], step[500], loss: 0.8575
# Epoch [908/1000], step[1000], loss: 1.4294
# Train Accuracy:31802/45438
# Test accuracy:2794/15142
#
# Epoch [909/1000], step[500], loss: 0.9239
# Epoch [909/1000], step[1000], loss: 0.9529
# Train Accuracy:32056/45438
# Test accuracy:2800/15142
#
# Epoch [910/1000], step[500], loss: 0.7661
# Epoch [910/1000], step[1000], loss: 1.1079
# Train Accuracy:31736/45438
# Test accuracy:2802/15142
#
# Epoch [911/1000], step[500], loss: 0.9824
# Epoch [911/1000], step[1000], loss: 0.7929
# Train Accuracy:32007/45438
# Test accuracy:2810/15142
#
# Epoch [912/1000], step[500], loss: 0.7687
# Epoch [912/1000], step[1000], loss: 1.1366
# Train Accuracy:31969/45438
# Test accuracy:2780/15142
#
# Epoch [913/1000], step[500], loss: 1.5442
# Epoch [913/1000], step[1000], loss: 0.9102
# Train Accuracy:32057/45438
# Test accuracy:2799/15142
#
# Epoch [914/1000], step[500], loss: 1.1555
# Epoch [914/1000], step[1000], loss: 1.0104
# Train Accuracy:32006/45438
# Test accuracy:2820/15142
#
# Epoch [915/1000], step[500], loss: 1.1758
# Epoch [915/1000], step[1000], loss: 1.2083
# Train Accuracy:31923/45438
# Test accuracy:2808/15142
#
# Epoch [916/1000], step[500], loss: 1.0606
# Epoch [916/1000], step[1000], loss: 1.3914
# Train Accuracy:31974/45438
# Test accuracy:2832/15142
#
# Epoch [917/1000], step[500], loss: 1.0515
# Epoch [917/1000], step[1000], loss: 0.7839
# Train Accuracy:31928/45438
# Test accuracy:2789/15142
#
# Epoch [918/1000], step[500], loss: 0.9825
# Epoch [918/1000], step[1000], loss: 0.8420
# Train Accuracy:31793/45438
# Test accuracy:2775/15142
#
# Epoch [919/1000], step[500], loss: 1.2479
# Epoch [919/1000], step[1000], loss: 0.7611
# Train Accuracy:32026/45438
# Test accuracy:2769/15142
#
# Epoch [920/1000], step[500], loss: 0.8013
# Epoch [920/1000], step[1000], loss: 1.0438
# Train Accuracy:32013/45438
# Test accuracy:2798/15142
#
# Epoch [921/1000], step[500], loss: 0.9746
# Epoch [921/1000], step[1000], loss: 1.7473
# Train Accuracy:32006/45438
# Test accuracy:2817/15142
#
# Epoch [922/1000], step[500], loss: 0.8510
# Epoch [922/1000], step[1000], loss: 0.8136
# Train Accuracy:32048/45438
# Test accuracy:2828/15142
#
# Epoch [923/1000], step[500], loss: 1.0565
# Epoch [923/1000], step[1000], loss: 1.0615
# Train Accuracy:32145/45438
# Test accuracy:2768/15142
#
# Epoch [924/1000], step[500], loss: 0.7405
# Epoch [924/1000], step[1000], loss: 1.1859
# Train Accuracy:32046/45438
# Test accuracy:2825/15142
#
# Epoch [925/1000], step[500], loss: 1.4426
# Epoch [925/1000], step[1000], loss: 1.4060
# Train Accuracy:31996/45438
# Test accuracy:2802/15142
#
# Epoch [926/1000], step[500], loss: 1.5414
# Epoch [926/1000], step[1000], loss: 0.9387
# Train Accuracy:32065/45438
# Test accuracy:2806/15142
#
# Epoch [927/1000], step[500], loss: 1.3073
# Epoch [927/1000], step[1000], loss: 0.7309
# Train Accuracy:32051/45438
# Test accuracy:2793/15142
#
# Epoch [928/1000], step[500], loss: 0.7818
# Epoch [928/1000], step[1000], loss: 0.8435
# Train Accuracy:31984/45438
# Test accuracy:2847/15142
#
# Epoch [929/1000], step[500], loss: 0.4650
# Epoch [929/1000], step[1000], loss: 0.7358
# Train Accuracy:31963/45438
# Test accuracy:2820/15142
#
# Epoch [930/1000], step[500], loss: 0.7784
# Epoch [930/1000], step[1000], loss: 1.0971
# Train Accuracy:31922/45438
# Test accuracy:2838/15142
#
# Epoch [931/1000], step[500], loss: 0.9754
# Epoch [931/1000], step[1000], loss: 1.6244
# Train Accuracy:31976/45438
# Test accuracy:2801/15142
#
# Epoch [932/1000], step[500], loss: 1.1908
# Epoch [932/1000], step[1000], loss: 0.8927
# Train Accuracy:32184/45438
# Test accuracy:2783/15142
#
# Epoch [933/1000], step[500], loss: 0.8350
# Epoch [933/1000], step[1000], loss: 1.0128
# Train Accuracy:32044/45438
# Test accuracy:2829/15142
#
# Epoch [934/1000], step[500], loss: 0.8238
# Epoch [934/1000], step[1000], loss: 0.6776
# Train Accuracy:32117/45438
# Test accuracy:2852/15142
#
# Epoch [935/1000], step[500], loss: 1.0838
# Epoch [935/1000], step[1000], loss: 1.0927
# Train Accuracy:32350/45438
# Test accuracy:2852/15142
#
# Epoch [936/1000], step[500], loss: 0.9866
# Epoch [936/1000], step[1000], loss: 0.9585
# Train Accuracy:32095/45438
# Test accuracy:2790/15142
#
# Epoch [937/1000], step[500], loss: 0.8466
# Epoch [937/1000], step[1000], loss: 1.2272
# Train Accuracy:32036/45438
# Test accuracy:2833/15142
#
# Epoch [938/1000], step[500], loss: 1.3406
# Epoch [938/1000], step[1000], loss: 1.3936
# Train Accuracy:32058/45438
# Test accuracy:2801/15142
#
# Epoch [939/1000], step[500], loss: 0.8821
# Epoch [939/1000], step[1000], loss: 1.5871
# Train Accuracy:32161/45438
# Test accuracy:2851/15142
#
# Epoch [940/1000], step[500], loss: 1.2038
# Epoch [940/1000], step[1000], loss: 0.9398
# Train Accuracy:32112/45438
# Test accuracy:2870/15142
#
# Epoch [941/1000], step[500], loss: 0.9166
# Epoch [941/1000], step[1000], loss: 1.3368
# Train Accuracy:32396/45438
# Test accuracy:2850/15142
#
# Epoch [942/1000], step[500], loss: 1.3995
# Epoch [942/1000], step[1000], loss: 1.0534
# Train Accuracy:32096/45438
# Test accuracy:2813/15142
#
# Epoch [943/1000], step[500], loss: 0.7907
# Epoch [943/1000], step[1000], loss: 0.7877
# Train Accuracy:32318/45438
# Test accuracy:2811/15142
#
# Epoch [944/1000], step[500], loss: 0.9451
# Epoch [944/1000], step[1000], loss: 1.0344
# Train Accuracy:32098/45438
# Test accuracy:2804/15142
#
# Epoch [945/1000], step[500], loss: 0.9634
# Epoch [945/1000], step[1000], loss: 0.8896
# Train Accuracy:32102/45438
# Test accuracy:2855/15142
#
# Epoch [946/1000], step[500], loss: 1.3287
# Epoch [946/1000], step[1000], loss: 0.8753
# Train Accuracy:32286/45438
# Test accuracy:2894/15142
#
# Epoch [947/1000], step[500], loss: 0.8357
# Epoch [947/1000], step[1000], loss: 0.8604
# Train Accuracy:32286/45438
# Test accuracy:2849/15142
#
# Epoch [948/1000], step[500], loss: 1.1675
# Epoch [948/1000], step[1000], loss: 0.9465
# Train Accuracy:32112/45438
# Test accuracy:2859/15142
#
# Epoch [949/1000], step[500], loss: 0.6977
# Epoch [949/1000], step[1000], loss: 0.6641
# Train Accuracy:32268/45438
# Test accuracy:2838/15142
#
# Epoch [950/1000], step[500], loss: 0.8792
# Epoch [950/1000], step[1000], loss: 1.2207
# Train Accuracy:32255/45438
# Test accuracy:2862/15142
#
# Epoch [951/1000], step[500], loss: 0.9630
# Epoch [951/1000], step[1000], loss: 1.1501
# Train Accuracy:32124/45438
# Test accuracy:2883/15142
#
# Epoch [952/1000], step[500], loss: 1.2577
# Epoch [952/1000], step[1000], loss: 1.1947
# Train Accuracy:32325/45438
# Test accuracy:2807/15142
#
# Epoch [953/1000], step[500], loss: 0.7496
# Epoch [953/1000], step[1000], loss: 0.8880
# Train Accuracy:32043/45438
# Test accuracy:2828/15142
#
# Epoch [954/1000], step[500], loss: 1.0261
# Epoch [954/1000], step[1000], loss: 0.8393
# Train Accuracy:32465/45438
# Test accuracy:2835/15142
#
# Epoch [955/1000], step[500], loss: 0.7841
# Epoch [955/1000], step[1000], loss: 1.3427
# Train Accuracy:32196/45438
# Test accuracy:2855/15142
#
# Epoch [956/1000], step[500], loss: 1.3924
# Epoch [956/1000], step[1000], loss: 0.8373
# Train Accuracy:32597/45438
# Test accuracy:2811/15142
#
# Epoch [957/1000], step[500], loss: 0.8253
# Epoch [957/1000], step[1000], loss: 0.6910
# Train Accuracy:32166/45438
# Test accuracy:2824/15142
#
# Epoch [958/1000], step[500], loss: 1.2776
# Epoch [958/1000], step[1000], loss: 0.8807
# Train Accuracy:32052/45438
# Test accuracy:2733/15142
#
# Epoch [959/1000], step[500], loss: 0.6145
# Epoch [959/1000], step[1000], loss: 0.6095
# Train Accuracy:32278/45438
# Test accuracy:2811/15142
#
# Epoch [960/1000], step[500], loss: 0.7937
# Epoch [960/1000], step[1000], loss: 0.9369
# Train Accuracy:32212/45438
# Test accuracy:2790/15142
#
# Epoch [961/1000], step[500], loss: 1.3256
# Epoch [961/1000], step[1000], loss: 1.4790
# Train Accuracy:32237/45438
# Test accuracy:2907/15142
#
# Epoch [962/1000], step[500], loss: 0.9013
# Epoch [962/1000], step[1000], loss: 1.0353
# Train Accuracy:32304/45438
# Test accuracy:2782/15142
#
# Epoch [963/1000], step[500], loss: 1.0398
# Epoch [963/1000], step[1000], loss: 1.0884
# Train Accuracy:32468/45438
# Test accuracy:2815/15142
#
# Epoch [964/1000], step[500], loss: 1.3805
# Epoch [964/1000], step[1000], loss: 0.9841
# Train Accuracy:32243/45438
# Test accuracy:2855/15142
#
# Epoch [965/1000], step[500], loss: 1.2342
# Epoch [965/1000], step[1000], loss: 1.1735
# Train Accuracy:32209/45438
# Test accuracy:2806/15142
#
# Epoch [966/1000], step[500], loss: 1.2071
# Epoch [966/1000], step[1000], loss: 1.1200
# Train Accuracy:32447/45438
# Test accuracy:2817/15142
#
# Epoch [967/1000], step[500], loss: 0.9460
# Epoch [967/1000], step[1000], loss: 0.5622
# Train Accuracy:32476/45438
# Test accuracy:2827/15142
#
# Epoch [968/1000], step[500], loss: 1.1236
# Epoch [968/1000], step[1000], loss: 0.7671
# Train Accuracy:32403/45438
# Test accuracy:2845/15142
#
# Epoch [969/1000], step[500], loss: 0.7849
# Epoch [969/1000], step[1000], loss: 1.3288
# Train Accuracy:32485/45438
# Test accuracy:2793/15142
#
# Epoch [970/1000], step[500], loss: 0.9743
# Epoch [970/1000], step[1000], loss: 1.1431
# Train Accuracy:32349/45438
# Test accuracy:2815/15142
#
# Epoch [971/1000], step[500], loss: 1.2466
# Epoch [971/1000], step[1000], loss: 0.8295
# Train Accuracy:32189/45438
# Test accuracy:2773/15142
#
# Epoch [972/1000], step[500], loss: 1.3177
# Epoch [972/1000], step[1000], loss: 0.5343
# Train Accuracy:32228/45438
# Test accuracy:2820/15142
#
# Epoch [973/1000], step[500], loss: 1.0301
# Epoch [973/1000], step[1000], loss: 1.1052
# Train Accuracy:32435/45438
# Test accuracy:2828/15142
#
# Epoch [974/1000], step[500], loss: 0.9136
# Epoch [974/1000], step[1000], loss: 0.9150
# Train Accuracy:32460/45438
# Test accuracy:2843/15142
#
# Epoch [975/1000], step[500], loss: 0.8910
# Epoch [975/1000], step[1000], loss: 1.0067
# Train Accuracy:32486/45438
# Test accuracy:2817/15142
#
# Epoch [976/1000], step[500], loss: 0.9420
# Epoch [976/1000], step[1000], loss: 0.9931
# Train Accuracy:32360/45438
# Test accuracy:2842/15142
#
# Epoch [977/1000], step[500], loss: 0.9518
# Epoch [977/1000], step[1000], loss: 1.0892
# Train Accuracy:32361/45438
# Test accuracy:2813/15142
#
# Epoch [978/1000], step[500], loss: 1.2732
# Epoch [978/1000], step[1000], loss: 0.9008
# Train Accuracy:32419/45438
# Test accuracy:2842/15142
#
# Epoch [979/1000], step[500], loss: 1.3274
# Epoch [979/1000], step[1000], loss: 1.1435
# Train Accuracy:32367/45438
# Test accuracy:2806/15142
#
# Epoch [980/1000], step[500], loss: 0.9155
# Epoch [980/1000], step[1000], loss: 0.5809
# Train Accuracy:32648/45438
# Test accuracy:2847/15142
#
# Epoch [981/1000], step[500], loss: 0.7506
# Epoch [981/1000], step[1000], loss: 1.2468
# Train Accuracy:32587/45438
# Test accuracy:2802/15142
#
# Epoch [982/1000], step[500], loss: 0.9225
# Epoch [982/1000], step[1000], loss: 0.8459
# Train Accuracy:32548/45438
# Test accuracy:2869/15142
#
# Epoch [983/1000], step[500], loss: 0.8517
# Epoch [983/1000], step[1000], loss: 1.3688
# Train Accuracy:32450/45438
# Test accuracy:2803/15142
#
# Epoch [984/1000], step[500], loss: 1.3266
# Epoch [984/1000], step[1000], loss: 1.1209
# Train Accuracy:32285/45438
# Test accuracy:2808/15142
#
# Epoch [985/1000], step[500], loss: 1.6977
# Epoch [985/1000], step[1000], loss: 1.0518
# Train Accuracy:32538/45438
# Test accuracy:2813/15142
#
# Epoch [986/1000], step[500], loss: 0.7617
# Epoch [986/1000], step[1000], loss: 0.8848
# Train Accuracy:32479/45438
# Test accuracy:2837/15142
#
# Epoch [987/1000], step[500], loss: 1.0645
# Epoch [987/1000], step[1000], loss: 0.8654
# Train Accuracy:32633/45438
# Test accuracy:2829/15142
#
# Epoch [988/1000], step[500], loss: 0.8843
# Epoch [988/1000], step[1000], loss: 0.5575
# Train Accuracy:32544/45438
# Test accuracy:2810/15142
#
# Epoch [989/1000], step[500], loss: 1.6222
# Epoch [989/1000], step[1000], loss: 1.1904
# Train Accuracy:32516/45438
# Test accuracy:2836/15142
#
# Epoch [990/1000], step[500], loss: 0.8316
# Epoch [990/1000], step[1000], loss: 1.0429
# Train Accuracy:32507/45438
# Test accuracy:2864/15142
#
# Epoch [991/1000], step[500], loss: 1.0000
# Epoch [991/1000], step[1000], loss: 1.2698
# Train Accuracy:32346/45438
# Test accuracy:2865/15142
#
# Epoch [992/1000], step[500], loss: 0.7480
# Epoch [992/1000], step[1000], loss: 0.9946
# Train Accuracy:32563/45438
# Test accuracy:2835/15142
#
# Epoch [993/1000], step[500], loss: 0.7259
# Epoch [993/1000], step[1000], loss: 1.0990
# Train Accuracy:32507/45438
# Test accuracy:2857/15142
#
# Epoch [994/1000], step[500], loss: 1.3534
# Epoch [994/1000], step[1000], loss: 1.3523
# Train Accuracy:32666/45438
# Test accuracy:2846/15142
#
# Epoch [995/1000], step[500], loss: 1.0872
# Epoch [995/1000], step[1000], loss: 1.1390
# Train Accuracy:32489/45438
# Test accuracy:2851/15142
#
# Epoch [996/1000], step[500], loss: 0.9925
# Epoch [996/1000], step[1000], loss: 1.2158
# Train Accuracy:32570/45438
# Test accuracy:2863/15142
#
# Epoch [997/1000], step[500], loss: 1.4278
# Epoch [997/1000], step[1000], loss: 1.1649
# Train Accuracy:32489/45438
# Test accuracy:2819/15142
#
# Epoch [998/1000], step[500], loss: 1.0125
# Epoch [998/1000], step[1000], loss: 1.2317
# Train Accuracy:32567/45438
# Test accuracy:2871/15142
#
# Epoch [999/1000], step[500], loss: 1.1519
# Epoch [999/1000], step[1000], loss: 1.1858
# Train Accuracy:32572/45438
# Test accuracy:2800/15142
#
# Epoch [1000/1000], step[500], loss: 0.6726
# Epoch [1000/1000], step[1000], loss: 1.0933
# Train Accuracy:32675/45438
# Test accuracy:2895/15142
