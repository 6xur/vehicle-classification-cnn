# %%
import numpy as np
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
def load_data(directory):
    data = []
    vehicle_ids = []

    for i, file_name in enumerate(os.listdir(directory)):

        # Limit elements in Tensor for performance purposes, remove this when ready for full scale training
        if(i % 5000 == 0):
            print(f'Loading {i}')

        # Extract vehicle IDs from the filename
        vehicle_id = int(file_name.split('_')[0])
        vehicle_ids.append(vehicle_id)

        # Load NPY files
        file_path = os.path.join(directory, file_name)
        loaded_data = np.load(file_path)

        data.append(loaded_data)
        
        # Reshape loaded data and append to a list
        #reshaped_data = loaded_data.reshape((1, 32, 64))
        # data.append(reshaped_data)

    # Converting data and labels to PyTorch Tensors
    data = np.array(data)
    data = torch.from_numpy(data)
    vehicle_ids = torch.tensor(vehicle_ids, dtype=torch.long)
    
    # Adjust labels to be in range 0 to 1361
    if(torch.min(vehicle_ids).item() == 1):
        vehicle_ids = vehicle_ids - 1
    
    return (data, vehicle_ids)

# %%
# Load train data and labels from train directory
train_directory = "vehicle-x/train"
test_directory = "vehicle-x/test"

train_data, vehicle_ids_train = load_data(train_directory)
test_data, vehicle_ids_test = load_data(test_directory)
# Out:
# Loading 0
# Loading 5000
# Loading 10000
# Loading 15000
# Loading 20000
# Loading 25000
# Loading 30000
# Loading 35000
# Loading 40000
# Loading 45000
# Loading 0
# Loading 5000
# Loading 10000
# Loading 15000

# %%
# Hyperparameters
num_epochs = 1000
batch_size = 32
test_batch_size = 64
learning_rate = 0.01

class CustomDataset():
    def __init__(self, data_array, labels):
        self.data = data_array
        self.labels = labels

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

# Create custom dataset from the tensors
train_dataset = CustomDataset(train_data, vehicle_ids_train)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = CustomDataset(test_data, vehicle_ids_test)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=test_batch_size, shuffle=True)

# %%
# Define the neural network
class SimpleClassifier(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(SimpleClassifier, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim, 1024),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, output_dim),
            nn.LogSoftmax(dim=1)
        )

    def forward(self, x):
        return self.fc(x)

# Device Configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Initialise network
model = SimpleClassifier(2048, 1362).to(device)

# %%
def train():
    model.train()
    correct = 0
    for batch_idx, (batch_data, batch_labels) in enumerate(train_loader):
        batch_data = batch_data.to(device)
        batch_labels = batch_labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(batch_data)

        pred = outputs.data.max(1, keepdim=True)[1] # get the index of the max log-probability
        correct += pred.eq(batch_labels.data.view_as(pred)).long().cpu().sum()
        
        loss = criterion(outputs, batch_labels)
        loss.backward()
        optimizer.step()

        if (batch_idx + 1) % 500 == 0:
            print(f'Epoch [{epoch + 1}/{num_epochs}], step[{batch_idx + 1}], loss: {loss.item():.4f}')

    print('Train Accuracy:{}/{}'.format(correct, len(train_loader.dataset)))

# %%
def test():
    model.eval()
    correct = 0

    for batch_data, batch_labels in test_loader:
        batch_data = batch_data.to(device)
        batch_labels = batch_labels.to(device)
        
        outputs = model(batch_data)
        
        pred = outputs.data.max(1, keepdim=True)[1] # get the index of the max log-probability
        correct += pred.eq(batch_labels.data.view_as(pred)).long().cpu().sum()

    print('Test accuracy:{}/{}\n'.format(correct, len(test_loader.dataset)))

# %%
# Train the model
criterion = nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

for epoch in range(num_epochs):
    train()
    test()
# Out:
# Epoch [1/1000], step[500], loss: 7.2224
# Epoch [1/1000], step[1000], loss: 7.2373
# Train Accuracy:31/45438
# Test accuracy:8/15142
#
# Epoch [2/1000], step[500], loss: 7.2198
# Epoch [2/1000], step[1000], loss: 7.2234
# Train Accuracy:33/45438
# Test accuracy:14/15142
#
# Epoch [3/1000], step[500], loss: 7.2204
# Epoch [3/1000], step[1000], loss: 7.2274
# Train Accuracy:30/45438
# Test accuracy:19/15142
#
# Epoch [4/1000], step[500], loss: 7.2128
# Epoch [4/1000], step[1000], loss: 7.2083
# Train Accuracy:33/45438
# Test accuracy:12/15142
#
# Epoch [5/1000], step[500], loss: 7.2181
# Epoch [5/1000], step[1000], loss: 7.2173
# Train Accuracy:40/45438
# Test accuracy:17/15142
#
# Epoch [6/1000], step[500], loss: 7.2238
# Epoch [6/1000], step[1000], loss: 7.2228
# Train Accuracy:50/45438
# Test accuracy:18/15142
#
# Epoch [7/1000], step[500], loss: 7.2186
# Epoch [7/1000], step[1000], loss: 7.1817
# Train Accuracy:46/45438
# Test accuracy:18/15142
#
# Epoch [8/1000], step[500], loss: 7.1799
# Epoch [8/1000], step[1000], loss: 7.2269
# Train Accuracy:62/45438
# Test accuracy:15/15142
#
# Epoch [9/1000], step[500], loss: 7.2142
# Epoch [9/1000], step[1000], loss: 7.2191
# Train Accuracy:50/45438
# Test accuracy:16/15142
#
# Epoch [10/1000], step[500], loss: 7.1925
# Epoch [10/1000], step[1000], loss: 7.1944
# Train Accuracy:67/45438
# Test accuracy:18/15142
#
# Epoch [11/1000], step[500], loss: 7.2083
# Epoch [11/1000], step[1000], loss: 7.1865
# Train Accuracy:58/45438
# Test accuracy:19/15142
#
# Epoch [12/1000], step[500], loss: 7.1673
# Epoch [12/1000], step[1000], loss: 7.2142
# Train Accuracy:71/45438
# Test accuracy:23/15142
#
# Epoch [13/1000], step[500], loss: 7.2145
# Epoch [13/1000], step[1000], loss: 7.2238
# Train Accuracy:82/45438
# Test accuracy:20/15142
#
# Epoch [14/1000], step[500], loss: 7.1553
# Epoch [14/1000], step[1000], loss: 7.1309
# Train Accuracy:102/45438
# Test accuracy:18/15142
#
# Epoch [15/1000], step[500], loss: 7.0800
# Epoch [15/1000], step[1000], loss: 7.1077
# Train Accuracy:84/45438
# Test accuracy:20/15142
#
# Epoch [16/1000], step[500], loss: 7.0065
# Epoch [16/1000], step[1000], loss: 7.0913
# Train Accuracy:87/45438
# Test accuracy:32/15142
#
# Epoch [17/1000], step[500], loss: 6.9812
# Epoch [17/1000], step[1000], loss: 7.0502
# Train Accuracy:123/45438
# Test accuracy:41/15142
#
# Epoch [18/1000], step[500], loss: 6.9370
# Epoch [18/1000], step[1000], loss: 6.6759
# Train Accuracy:130/45438
# Test accuracy:34/15142
#
# Epoch [19/1000], step[500], loss: 6.8941
# Epoch [19/1000], step[1000], loss: 6.8118
# Train Accuracy:151/45438
# Test accuracy:66/15142
#
# Epoch [20/1000], step[500], loss: 6.9757
# Epoch [20/1000], step[1000], loss: 6.9267
# Train Accuracy:197/45438
# Test accuracy:58/15142
#
# Epoch [21/1000], step[500], loss: 6.8805
# Epoch [21/1000], step[1000], loss: 6.9765
# Train Accuracy:233/45438
# Test accuracy:82/15142
#
# Epoch [22/1000], step[500], loss: 6.7290
# Epoch [22/1000], step[1000], loss: 6.4583
# Train Accuracy:224/45438
# Test accuracy:80/15142
#
# Epoch [23/1000], step[500], loss: 6.5479
# Epoch [23/1000], step[1000], loss: 6.5761
# Train Accuracy:238/45438
# Test accuracy:87/15142
#
# Epoch [24/1000], step[500], loss: 6.2152
# Epoch [24/1000], step[1000], loss: 6.8127
# Train Accuracy:279/45438
# Test accuracy:107/15142
#
# Epoch [25/1000], step[500], loss: 6.4101
# Epoch [25/1000], step[1000], loss: 6.3565
# Train Accuracy:360/45438
# Test accuracy:127/15142
#
# Epoch [26/1000], step[500], loss: 6.4051
# Epoch [26/1000], step[1000], loss: 6.4683
# Train Accuracy:342/45438
# Test accuracy:125/15142
#
# Epoch [27/1000], step[500], loss: 6.1627
# Epoch [27/1000], step[1000], loss: 6.6862
# Train Accuracy:371/45438
# Test accuracy:142/15142
#
# Epoch [28/1000], step[500], loss: 6.2607
# Epoch [28/1000], step[1000], loss: 6.3798
# Train Accuracy:432/45438
# Test accuracy:155/15142
#
# Epoch [29/1000], step[500], loss: 6.1977
# Epoch [29/1000], step[1000], loss: 6.2869
# Train Accuracy:399/45438
# Test accuracy:159/15142
#
# Epoch [30/1000], step[500], loss: 5.8954
# Epoch [30/1000], step[1000], loss: 6.3383
# Train Accuracy:490/45438
# Test accuracy:179/15142
#
# Epoch [31/1000], step[500], loss: 6.4479
# Epoch [31/1000], step[1000], loss: 6.3343
# Train Accuracy:551/45438
# Test accuracy:177/15142
#
# Epoch [32/1000], step[500], loss: 6.0211
# Epoch [32/1000], step[1000], loss: 6.5168
# Train Accuracy:548/45438
# Test accuracy:197/15142
#
# Epoch [33/1000], step[500], loss: 5.9958
# Epoch [33/1000], step[1000], loss: 6.0297
# Train Accuracy:556/45438
# Test accuracy:209/15142
#
# Epoch [34/1000], step[500], loss: 5.6765
# Epoch [34/1000], step[1000], loss: 6.2195
# Train Accuracy:664/45438
# Test accuracy:210/15142
#
# Epoch [35/1000], step[500], loss: 6.5708
# Epoch [35/1000], step[1000], loss: 6.0463
# Train Accuracy:620/45438
# Test accuracy:244/15142
#
# Epoch [36/1000], step[500], loss: 6.1996
# Epoch [36/1000], step[1000], loss: 5.8116
# Train Accuracy:732/45438
# Test accuracy:256/15142
#
# Epoch [37/1000], step[500], loss: 5.8329
# Epoch [37/1000], step[1000], loss: 6.1125
# Train Accuracy:740/45438
# Test accuracy:270/15142
#
# Epoch [38/1000], step[500], loss: 5.8163
# Epoch [38/1000], step[1000], loss: 5.9913
# Train Accuracy:835/45438
# Test accuracy:287/15142
#
# Epoch [39/1000], step[500], loss: 5.9036
# Epoch [39/1000], step[1000], loss: 5.7405
# Train Accuracy:870/45438
# Test accuracy:314/15142
#
# Epoch [40/1000], step[500], loss: 5.8294
# Epoch [40/1000], step[1000], loss: 5.7441
# Train Accuracy:959/45438
# Test accuracy:319/15142
#
# Epoch [41/1000], step[500], loss: 5.4743
# Epoch [41/1000], step[1000], loss: 5.8240
# Train Accuracy:978/45438
# Test accuracy:303/15142
#
# Epoch [42/1000], step[500], loss: 5.4869
# Epoch [42/1000], step[1000], loss: 5.8900
# Train Accuracy:1034/45438
# Test accuracy:355/15142
#
# Epoch [43/1000], step[500], loss: 5.8522
# Epoch [43/1000], step[1000], loss: 5.5990
# Train Accuracy:1098/45438
# Test accuracy:360/15142
#
# Epoch [44/1000], step[500], loss: 5.3231
# Epoch [44/1000], step[1000], loss: 5.7869
# Train Accuracy:1202/45438
# Test accuracy:388/15142
#
# Epoch [45/1000], step[500], loss: 5.2071
# Epoch [45/1000], step[1000], loss: 5.8166
# Train Accuracy:1206/45438
# Test accuracy:389/15142
#
# Epoch [46/1000], step[500], loss: 5.7583
# Epoch [46/1000], step[1000], loss: 6.1003
# Train Accuracy:1260/45438
# Test accuracy:456/15142
#
# Epoch [47/1000], step[500], loss: 5.6041
# Epoch [47/1000], step[1000], loss: 5.1963
# Train Accuracy:1322/45438
# Test accuracy:466/15142
#
# Epoch [48/1000], step[500], loss: 5.7181
# Epoch [48/1000], step[1000], loss: 5.4606
# Train Accuracy:1402/45438
# Test accuracy:463/15142
#
# Epoch [49/1000], step[500], loss: 5.6861
# Epoch [49/1000], step[1000], loss: 5.2702
# Train Accuracy:1433/45438
# Test accuracy:499/15142
#
# Epoch [50/1000], step[500], loss: 5.5405
# Epoch [50/1000], step[1000], loss: 5.5860
# Train Accuracy:1563/45438
# Test accuracy:518/15142
#
# Epoch [51/1000], step[500], loss: 5.2830
# Epoch [51/1000], step[1000], loss: 5.4292
# Train Accuracy:1602/45438
# Test accuracy:508/15142
#
# Epoch [52/1000], step[500], loss: 5.6795
# Epoch [52/1000], step[1000], loss: 5.6327
# Train Accuracy:1651/45438
# Test accuracy:525/15142
#
# Epoch [53/1000], step[500], loss: 5.0550
# Epoch [53/1000], step[1000], loss: 5.9644
# Train Accuracy:1769/45438
# Test accuracy:553/15142
#
# Epoch [54/1000], step[500], loss: 5.5206
# Epoch [54/1000], step[1000], loss: 5.5545
# Train Accuracy:1806/45438
# Test accuracy:547/15142
#
# Epoch [55/1000], step[500], loss: 5.2674
# Epoch [55/1000], step[1000], loss: 5.4984
# Train Accuracy:1942/45438
# Test accuracy:594/15142
#
# Epoch [56/1000], step[500], loss: 5.7324
# Epoch [56/1000], step[1000], loss: 5.3685
# Train Accuracy:1973/45438
# Test accuracy:605/15142
#
# Epoch [57/1000], step[500], loss: 5.4250
# Epoch [57/1000], step[1000], loss: 5.0955
# Train Accuracy:2027/45438
# Test accuracy:618/15142
#
# Epoch [58/1000], step[500], loss: 5.3397
# Epoch [58/1000], step[1000], loss: 5.6275
# Train Accuracy:2157/45438
# Test accuracy:661/15142
#
# Epoch [59/1000], step[500], loss: 5.6782
# Epoch [59/1000], step[1000], loss: 5.5166
# Train Accuracy:2178/45438
# Test accuracy:677/15142
#
# Epoch [60/1000], step[500], loss: 5.0955
# Epoch [60/1000], step[1000], loss: 5.3705
# Train Accuracy:2344/45438
# Test accuracy:656/15142
#
# Epoch [61/1000], step[500], loss: 5.1924
# Epoch [61/1000], step[1000], loss: 5.1583
# Train Accuracy:2425/45438
# Test accuracy:688/15142
#
# Epoch [62/1000], step[500], loss: 4.6730
# Epoch [62/1000], step[1000], loss: 4.7766
# Train Accuracy:2448/45438
# Test accuracy:752/15142
#
# Epoch [63/1000], step[500], loss: 4.6690
# Epoch [63/1000], step[1000], loss: 4.8756
# Train Accuracy:2616/45438
# Test accuracy:737/15142
#
# Epoch [64/1000], step[500], loss: 5.0291
# Epoch [64/1000], step[1000], loss: 5.8581
# Train Accuracy:2633/45438
# Test accuracy:785/15142
#
# Epoch [65/1000], step[500], loss: 4.9286
# Epoch [65/1000], step[1000], loss: 5.3790
# Train Accuracy:2784/45438
# Test accuracy:758/15142
#
# Epoch [66/1000], step[500], loss: 5.0287
# Epoch [66/1000], step[1000], loss: 5.0345
# Train Accuracy:2855/45438
# Test accuracy:835/15142
#
# Epoch [67/1000], step[500], loss: 5.1786
# Epoch [67/1000], step[1000], loss: 4.7207
# Train Accuracy:2945/45438
# Test accuracy:867/15142
#
# Epoch [68/1000], step[500], loss: 4.9390
# Epoch [68/1000], step[1000], loss: 5.0862
# Train Accuracy:3029/45438
# Test accuracy:845/15142
#
# Epoch [69/1000], step[500], loss: 4.7663
# Epoch [69/1000], step[1000], loss: 4.9819
# Train Accuracy:3117/45438
# Test accuracy:928/15142
#
# Epoch [70/1000], step[500], loss: 4.5734
# Epoch [70/1000], step[1000], loss: 4.5077
# Train Accuracy:3181/45438
# Test accuracy:875/15142
#
# Epoch [71/1000], step[500], loss: 4.9380
# Epoch [71/1000], step[1000], loss: 4.9980
# Train Accuracy:3267/45438
# Test accuracy:935/15142
#
# Epoch [72/1000], step[500], loss: 5.4160
# Epoch [72/1000], step[1000], loss: 5.1042
# Train Accuracy:3311/45438
# Test accuracy:961/15142
#
# Epoch [73/1000], step[500], loss: 4.8877
# Epoch [73/1000], step[1000], loss: 4.9554
# Train Accuracy:3566/45438
# Test accuracy:974/15142
#
# Epoch [74/1000], step[500], loss: 5.0371
# Epoch [74/1000], step[1000], loss: 4.9759
# Train Accuracy:3514/45438
# Test accuracy:984/15142
#
# Epoch [75/1000], step[500], loss: 4.6045
# Epoch [75/1000], step[1000], loss: 5.0552
# Train Accuracy:3604/45438
# Test accuracy:1009/15142
#
# Epoch [76/1000], step[500], loss: 4.4357
# Epoch [76/1000], step[1000], loss: 4.8129
# Train Accuracy:3864/45438
# Test accuracy:1018/15142
#
# Epoch [77/1000], step[500], loss: 5.2613
# Epoch [77/1000], step[1000], loss: 4.7315
# Train Accuracy:3864/45438
# Test accuracy:1067/15142
#
# Epoch [78/1000], step[500], loss: 3.9441
# Epoch [78/1000], step[1000], loss: 4.4257
# Train Accuracy:4021/45438
# Test accuracy:1103/15142
#
# Epoch [79/1000], step[500], loss: 4.6099
# Epoch [79/1000], step[1000], loss: 5.0829
# Train Accuracy:4137/45438
# Test accuracy:1113/15142
#
# Epoch [80/1000], step[500], loss: 4.5273
# Epoch [80/1000], step[1000], loss: 4.8245
# Train Accuracy:4081/45438
# Test accuracy:1134/15142
#
# Epoch [81/1000], step[500], loss: 4.8573
# Epoch [81/1000], step[1000], loss: 5.1087
# Train Accuracy:4319/45438
# Test accuracy:1169/15142
#
# Epoch [82/1000], step[500], loss: 4.5718
# Epoch [82/1000], step[1000], loss: 4.6036
# Train Accuracy:4304/45438
# Test accuracy:1223/15142
#
# Epoch [83/1000], step[500], loss: 5.0774
# Epoch [83/1000], step[1000], loss: 4.9096
# Train Accuracy:4422/45438
# Test accuracy:1186/15142
#
# Epoch [84/1000], step[500], loss: 4.3918
# Epoch [84/1000], step[1000], loss: 4.8025
# Train Accuracy:4485/45438
# Test accuracy:1232/15142
#
# Epoch [85/1000], step[500], loss: 4.7634
# Epoch [85/1000], step[1000], loss: 4.3957
# Train Accuracy:4650/45438
# Test accuracy:1230/15142
#
# Epoch [86/1000], step[500], loss: 4.6384
# Epoch [86/1000], step[1000], loss: 4.3766
# Train Accuracy:4771/45438
# Test accuracy:1267/15142
#
# Epoch [87/1000], step[500], loss: 4.4922
# Epoch [87/1000], step[1000], loss: 4.8350
# Train Accuracy:4908/45438
# Test accuracy:1239/15142
#
# Epoch [88/1000], step[500], loss: 4.6111
# Epoch [88/1000], step[1000], loss: 4.2823
# Train Accuracy:4906/45438
# Test accuracy:1282/15142
#
# Epoch [89/1000], step[500], loss: 4.8903
# Epoch [89/1000], step[1000], loss: 4.6417
# Train Accuracy:4961/45438
# Test accuracy:1331/15142
#
# Epoch [90/1000], step[500], loss: 4.8166
# Epoch [90/1000], step[1000], loss: 4.7779
# Train Accuracy:5200/45438
# Test accuracy:1345/15142
#
# Epoch [91/1000], step[500], loss: 4.3178
# Epoch [91/1000], step[1000], loss: 4.4631
# Train Accuracy:5219/45438
# Test accuracy:1380/15142
#
# Epoch [92/1000], step[500], loss: 4.7633
# Epoch [92/1000], step[1000], loss: 4.3972
# Train Accuracy:5326/45438
# Test accuracy:1343/15142
#
# Epoch [93/1000], step[500], loss: 3.7703
# Epoch [93/1000], step[1000], loss: 3.7865
# Train Accuracy:5366/45438
# Test accuracy:1379/15142
#
# Epoch [94/1000], step[500], loss: 5.0030
# Epoch [94/1000], step[1000], loss: 4.5480
# Train Accuracy:5511/45438
# Test accuracy:1420/15142
#
# Epoch [95/1000], step[500], loss: 4.2993
# Epoch [95/1000], step[1000], loss: 4.9514
# Train Accuracy:5584/45438
# Test accuracy:1448/15142
#
# Epoch [96/1000], step[500], loss: 4.3501
# Epoch [96/1000], step[1000], loss: 4.1713
# Train Accuracy:5750/45438
# Test accuracy:1463/15142
#
# Epoch [97/1000], step[500], loss: 4.3373
# Epoch [97/1000], step[1000], loss: 4.2303
# Train Accuracy:5772/45438
# Test accuracy:1493/15142
#
# Epoch [98/1000], step[500], loss: 5.3495
# Epoch [98/1000], step[1000], loss: 4.4200
# Train Accuracy:5814/45438
# Test accuracy:1454/15142
#
# Epoch [99/1000], step[500], loss: 4.6544
# Epoch [99/1000], step[1000], loss: 3.7571
# Train Accuracy:5993/45438
# Test accuracy:1537/15142
#
# Epoch [100/1000], step[500], loss: 4.5132
# Epoch [100/1000], step[1000], loss: 4.7302
# Train Accuracy:6092/45438
# Test accuracy:1500/15142
#
# Epoch [101/1000], step[500], loss: 3.8834
# Epoch [101/1000], step[1000], loss: 4.4947
# Train Accuracy:6233/45438
# Test accuracy:1558/15142
#
# Epoch [102/1000], step[500], loss: 4.0384
# Epoch [102/1000], step[1000], loss: 4.3988
# Train Accuracy:6361/45438
# Test accuracy:1544/15142
#
# Epoch [103/1000], step[500], loss: 3.6332
# Epoch [103/1000], step[1000], loss: 3.5809
# Train Accuracy:6372/45438
# Test accuracy:1542/15142
#
# Epoch [104/1000], step[500], loss: 4.5000
# Epoch [104/1000], step[1000], loss: 4.5502
# Train Accuracy:6475/45438
# Test accuracy:1555/15142
#
# Epoch [105/1000], step[500], loss: 4.2971
# Epoch [105/1000], step[1000], loss: 4.0102
# Train Accuracy:6590/45438
# Test accuracy:1612/15142
#
# Epoch [106/1000], step[500], loss: 4.2900
# Epoch [106/1000], step[1000], loss: 3.9726
# Train Accuracy:6713/45438
# Test accuracy:1603/15142
#
# Epoch [107/1000], step[500], loss: 4.1471
# Epoch [107/1000], step[1000], loss: 4.2340
# Train Accuracy:6718/45438
# Test accuracy:1622/15142
#
# Epoch [108/1000], step[500], loss: 4.2981
# Epoch [108/1000], step[1000], loss: 4.5457
# Train Accuracy:6852/45438
# Test accuracy:1699/15142
#
# Epoch [109/1000], step[500], loss: 4.6767
# Epoch [109/1000], step[1000], loss: 4.2779
# Train Accuracy:6991/45438
# Test accuracy:1602/15142
#
# Epoch [110/1000], step[500], loss: 3.8099
# Epoch [110/1000], step[1000], loss: 4.3971
# Train Accuracy:7047/45438
# Test accuracy:1694/15142
#
# Epoch [111/1000], step[500], loss: 4.0585
# Epoch [111/1000], step[1000], loss: 3.3437
# Train Accuracy:7099/45438
# Test accuracy:1670/15142
#
# Epoch [112/1000], step[500], loss: 4.1060
# Epoch [112/1000], step[1000], loss: 4.1638
# Train Accuracy:7279/45438
# Test accuracy:1770/15142
#
# Epoch [113/1000], step[500], loss: 3.9826
# Epoch [113/1000], step[1000], loss: 4.5608
# Train Accuracy:7258/45438
# Test accuracy:1817/15142
#
# Epoch [114/1000], step[500], loss: 3.5689
# Epoch [114/1000], step[1000], loss: 4.2635
# Train Accuracy:7246/45438
# Test accuracy:1716/15142
#
# Epoch [115/1000], step[500], loss: 4.4827
# Epoch [115/1000], step[1000], loss: 4.3415
# Train Accuracy:7451/45438
# Test accuracy:1738/15142
#
# Epoch [116/1000], step[500], loss: 3.9156
# Epoch [116/1000], step[1000], loss: 4.4629
# Train Accuracy:7740/45438
# Test accuracy:1800/15142
#
# Epoch [117/1000], step[500], loss: 4.2436
# Epoch [117/1000], step[1000], loss: 3.9327
# Train Accuracy:7704/45438
# Test accuracy:1792/15142
#
# Epoch [118/1000], step[500], loss: 3.7313
# Epoch [118/1000], step[1000], loss: 3.7548
# Train Accuracy:7625/45438
# Test accuracy:1829/15142
#
# Epoch [119/1000], step[500], loss: 4.2837
# Epoch [119/1000], step[1000], loss: 3.6062
# Train Accuracy:7844/45438
# Test accuracy:1751/15142
#
# Epoch [120/1000], step[500], loss: 3.9739
# Epoch [120/1000], step[1000], loss: 3.4675
# Train Accuracy:7901/45438
# Test accuracy:1849/15142
#
# Epoch [121/1000], step[500], loss: 4.3445
# Epoch [121/1000], step[1000], loss: 3.9664
# Train Accuracy:8000/45438
# Test accuracy:1853/15142
#
# Epoch [122/1000], step[500], loss: 4.1460
# Epoch [122/1000], step[1000], loss: 3.8423
# Train Accuracy:8056/45438
# Test accuracy:1898/15142
#
# Epoch [123/1000], step[500], loss: 4.4086
# Epoch [123/1000], step[1000], loss: 4.2785
# Train Accuracy:8138/45438
# Test accuracy:1826/15142
#
# Epoch [124/1000], step[500], loss: 3.9195
# Epoch [124/1000], step[1000], loss: 4.1404
# Train Accuracy:8323/45438
# Test accuracy:1926/15142
#
# Epoch [125/1000], step[500], loss: 3.5493
# Epoch [125/1000], step[1000], loss: 3.8276
# Train Accuracy:8313/45438
# Test accuracy:1906/15142
#
# Epoch [126/1000], step[500], loss: 3.5495
# Epoch [126/1000], step[1000], loss: 3.6618
# Train Accuracy:8522/45438
# Test accuracy:1951/15142
#
# Epoch [127/1000], step[500], loss: 3.6285
# Epoch [127/1000], step[1000], loss: 4.1055
# Train Accuracy:8597/45438
# Test accuracy:1951/15142
#
# Epoch [128/1000], step[500], loss: 4.2337
# Epoch [128/1000], step[1000], loss: 3.6025
# Train Accuracy:8596/45438
# Test accuracy:1899/15142
#
# Epoch [129/1000], step[500], loss: 3.9098
# Epoch [129/1000], step[1000], loss: 4.1402
# Train Accuracy:8718/45438
# Test accuracy:1915/15142
#
# Epoch [130/1000], step[500], loss: 3.6224
# Epoch [130/1000], step[1000], loss: 3.9212
# Train Accuracy:8895/45438
# Test accuracy:1949/15142
#
# Epoch [131/1000], step[500], loss: 4.0690
# Epoch [131/1000], step[1000], loss: 3.2072
# Train Accuracy:8916/45438
# Test accuracy:1933/15142
#
# Epoch [132/1000], step[500], loss: 3.8620
# Epoch [132/1000], step[1000], loss: 4.0425
# Train Accuracy:8933/45438
# Test accuracy:2015/15142
#
# Epoch [133/1000], step[500], loss: 3.6699
# Epoch [133/1000], step[1000], loss: 3.8045
# Train Accuracy:8997/45438
# Test accuracy:2025/15142
#
# Epoch [134/1000], step[500], loss: 3.8001
# Epoch [134/1000], step[1000], loss: 3.6068
# Train Accuracy:9148/45438
# Test accuracy:1995/15142
#
# Epoch [135/1000], step[500], loss: 4.3811
# Epoch [135/1000], step[1000], loss: 3.5949
# Train Accuracy:9252/45438
# Test accuracy:1999/15142
#
# Epoch [136/1000], step[500], loss: 3.9275
# Epoch [136/1000], step[1000], loss: 3.6589
# Train Accuracy:9209/45438
# Test accuracy:2019/15142
#
# Epoch [137/1000], step[500], loss: 3.3859
# Epoch [137/1000], step[1000], loss: 3.4794
# Train Accuracy:9407/45438
# Test accuracy:2083/15142
#
# Epoch [138/1000], step[500], loss: 3.6775
# Epoch [138/1000], step[1000], loss: 3.6200
# Train Accuracy:9390/45438
# Test accuracy:2024/15142
#
# Epoch [139/1000], step[500], loss: 3.9616
# Epoch [139/1000], step[1000], loss: 4.1863
# Train Accuracy:9507/45438
# Test accuracy:2013/15142
#
# Epoch [140/1000], step[500], loss: 3.9843
# Epoch [140/1000], step[1000], loss: 3.6025
# Train Accuracy:9751/45438
# Test accuracy:2077/15142
#
# Epoch [141/1000], step[500], loss: 3.5726
# Epoch [141/1000], step[1000], loss: 3.7897
# Train Accuracy:9784/45438
# Test accuracy:2015/15142
#
# Epoch [142/1000], step[500], loss: 4.1074
# Epoch [142/1000], step[1000], loss: 3.6602
# Train Accuracy:9850/45438
# Test accuracy:2103/15142
#
# Epoch [143/1000], step[500], loss: 4.3126
# Epoch [143/1000], step[1000], loss: 3.5809
# Train Accuracy:9813/45438
# Test accuracy:2042/15142
#
# Epoch [144/1000], step[500], loss: 3.4433
# Epoch [144/1000], step[1000], loss: 3.8286
# Train Accuracy:9908/45438
# Test accuracy:2102/15142
#
# Epoch [145/1000], step[500], loss: 3.2898
# Epoch [145/1000], step[1000], loss: 3.7122
# Train Accuracy:10051/45438
# Test accuracy:2092/15142
#
# Epoch [146/1000], step[500], loss: 3.5071
# Epoch [146/1000], step[1000], loss: 4.2077
# Train Accuracy:10015/45438
# Test accuracy:2164/15142
#
# Epoch [147/1000], step[500], loss: 3.7297
# Epoch [147/1000], step[1000], loss: 4.3929
# Train Accuracy:10177/45438
# Test accuracy:2125/15142
#
# Epoch [148/1000], step[500], loss: 3.5948
# Epoch [148/1000], step[1000], loss: 3.6375
# Train Accuracy:10275/45438
# Test accuracy:2101/15142
#
# Epoch [149/1000], step[500], loss: 3.5587
# Epoch [149/1000], step[1000], loss: 3.3146
# Train Accuracy:10258/45438
# Test accuracy:2152/15142
#
# Epoch [150/1000], step[500], loss: 3.0854
# Epoch [150/1000], step[1000], loss: 3.4942
# Train Accuracy:10512/45438
# Test accuracy:2175/15142
#
# Epoch [151/1000], step[500], loss: 3.0450
# Epoch [151/1000], step[1000], loss: 4.1937
# Train Accuracy:10558/45438
# Test accuracy:2212/15142
#
# Epoch [152/1000], step[500], loss: 4.4818
# Epoch [152/1000], step[1000], loss: 3.7508
# Train Accuracy:10624/45438
# Test accuracy:2152/15142
#
# Epoch [153/1000], step[500], loss: 3.4628
# Epoch [153/1000], step[1000], loss: 3.4433
# Train Accuracy:10669/45438
# Test accuracy:2154/15142
#
# Epoch [154/1000], step[500], loss: 2.8641
# Epoch [154/1000], step[1000], loss: 3.7366
# Train Accuracy:10833/45438
# Test accuracy:2126/15142
#
# Epoch [155/1000], step[500], loss: 3.2288
# Epoch [155/1000], step[1000], loss: 3.6987
# Train Accuracy:10862/45438
# Test accuracy:2151/15142
#
# Epoch [156/1000], step[500], loss: 3.3488
# Epoch [156/1000], step[1000], loss: 3.2901
# Train Accuracy:10981/45438
# Test accuracy:2195/15142
#
# Epoch [157/1000], step[500], loss: 3.0840
# Epoch [157/1000], step[1000], loss: 3.1817
# Train Accuracy:10974/45438
# Test accuracy:2226/15142
#
# Epoch [158/1000], step[500], loss: 3.6290
# Epoch [158/1000], step[1000], loss: 3.8669
# Train Accuracy:11180/45438
# Test accuracy:2162/15142
#
# Epoch [159/1000], step[500], loss: 3.4824
# Epoch [159/1000], step[1000], loss: 3.7490
# Train Accuracy:11147/45438
# Test accuracy:2203/15142
#
# Epoch [160/1000], step[500], loss: 3.1269
# Epoch [160/1000], step[1000], loss: 3.3354
# Train Accuracy:11189/45438
# Test accuracy:2229/15142
#
# Epoch [161/1000], step[500], loss: 3.5479
# Epoch [161/1000], step[1000], loss: 3.2657
# Train Accuracy:11300/45438
# Test accuracy:2241/15142
#
# Epoch [162/1000], step[500], loss: 3.4289
# Epoch [162/1000], step[1000], loss: 2.7638
# Train Accuracy:11519/45438
# Test accuracy:2243/15142
#
# Epoch [163/1000], step[500], loss: 3.3584
# Epoch [163/1000], step[1000], loss: 4.1323
# Train Accuracy:11448/45438
# Test accuracy:2273/15142
#
# Epoch [164/1000], step[500], loss: 3.0649
# Epoch [164/1000], step[1000], loss: 3.4845
# Train Accuracy:11603/45438
# Test accuracy:2237/15142
#
# Epoch [165/1000], step[500], loss: 3.4996
# Epoch [165/1000], step[1000], loss: 3.5793
# Train Accuracy:11502/45438
# Test accuracy:2219/15142
#
# Epoch [166/1000], step[500], loss: 3.8045
# Epoch [166/1000], step[1000], loss: 2.8597
# Train Accuracy:11629/45438
# Test accuracy:2233/15142
#
# Epoch [167/1000], step[500], loss: 3.0144
# Epoch [167/1000], step[1000], loss: 2.8539
# Train Accuracy:11907/45438
# Test accuracy:2247/15142
#
# Epoch [168/1000], step[500], loss: 2.7924
# Epoch [168/1000], step[1000], loss: 3.1843
# Train Accuracy:11901/45438
# Test accuracy:2295/15142
#
# Epoch [169/1000], step[500], loss: 2.9399
# Epoch [169/1000], step[1000], loss: 3.3325
# Train Accuracy:11919/45438
# Test accuracy:2238/15142
#
# Epoch [170/1000], step[500], loss: 3.7439
# Epoch [170/1000], step[1000], loss: 3.3516
# Train Accuracy:12001/45438
# Test accuracy:2319/15142
#
# Epoch [171/1000], step[500], loss: 3.1411
# Epoch [171/1000], step[1000], loss: 3.3881
# Train Accuracy:12058/45438
# Test accuracy:2273/15142
#
# Epoch [172/1000], step[500], loss: 2.6835
# Epoch [172/1000], step[1000], loss: 3.2222
# Train Accuracy:12169/45438
# Test accuracy:2305/15142
#
# Epoch [173/1000], step[500], loss: 3.6630
# Epoch [173/1000], step[1000], loss: 3.6891
# Train Accuracy:12154/45438
# Test accuracy:2335/15142
#
# Epoch [174/1000], step[500], loss: 3.4908
# Epoch [174/1000], step[1000], loss: 3.0040
# Train Accuracy:12307/45438
# Test accuracy:2300/15142
#
# Epoch [175/1000], step[500], loss: 3.2191
# Epoch [175/1000], step[1000], loss: 2.7497
# Train Accuracy:12463/45438
# Test accuracy:2318/15142
#
# Epoch [176/1000], step[500], loss: 3.3627
# Epoch [176/1000], step[1000], loss: 3.2815
# Train Accuracy:12519/45438
# Test accuracy:2277/15142
#
# Epoch [177/1000], step[500], loss: 3.5018
# Epoch [177/1000], step[1000], loss: 4.2167
# Train Accuracy:12530/45438
# Test accuracy:2349/15142
#
# Epoch [178/1000], step[500], loss: 2.5256
# Epoch [178/1000], step[1000], loss: 3.8351
# Train Accuracy:12657/45438
# Test accuracy:2381/15142
#
# Epoch [179/1000], step[500], loss: 3.0498
# Epoch [179/1000], step[1000], loss: 2.9626
# Train Accuracy:12789/45438
# Test accuracy:2336/15142
#
# Epoch [180/1000], step[500], loss: 3.0822
# Epoch [180/1000], step[1000], loss: 3.4763
# Train Accuracy:12743/45438
# Test accuracy:2355/15142
#
# Epoch [181/1000], step[500], loss: 3.1741
# Epoch [181/1000], step[1000], loss: 3.4144
# Train Accuracy:12715/45438
# Test accuracy:2321/15142
#
# Epoch [182/1000], step[500], loss: 3.9025
# Epoch [182/1000], step[1000], loss: 3.6426
# Train Accuracy:12820/45438
# Test accuracy:2367/15142
#
# Epoch [183/1000], step[500], loss: 3.2282
# Epoch [183/1000], step[1000], loss: 3.3430
# Train Accuracy:13014/45438
# Test accuracy:2329/15142
#
# Epoch [184/1000], step[500], loss: 2.9991
# Epoch [184/1000], step[1000], loss: 3.7060
# Train Accuracy:12946/45438
# Test accuracy:2391/15142
#
# Epoch [185/1000], step[500], loss: 2.8523
# Epoch [185/1000], step[1000], loss: 2.5523
# Train Accuracy:13092/45438
# Test accuracy:2378/15142
#
# Epoch [186/1000], step[500], loss: 3.0520
# Epoch [186/1000], step[1000], loss: 3.0501
# Train Accuracy:13093/45438
# Test accuracy:2351/15142
#
# Epoch [187/1000], step[500], loss: 2.9078
# Epoch [187/1000], step[1000], loss: 3.6238
# Train Accuracy:13305/45438
# Test accuracy:2383/15142
#
# Epoch [188/1000], step[500], loss: 2.9926
# Epoch [188/1000], step[1000], loss: 3.5522
# Train Accuracy:13281/45438
# Test accuracy:2370/15142
#
# Epoch [189/1000], step[500], loss: 3.1159
# Epoch [189/1000], step[1000], loss: 3.2911
# Train Accuracy:13299/45438
# Test accuracy:2352/15142
#
# Epoch [190/1000], step[500], loss: 3.4467
# Epoch [190/1000], step[1000], loss: 3.2576
# Train Accuracy:13542/45438
# Test accuracy:2392/15142
#
# Epoch [191/1000], step[500], loss: 2.7879
# Epoch [191/1000], step[1000], loss: 2.9229
# Train Accuracy:13527/45438
# Test accuracy:2370/15142
#
# Epoch [192/1000], step[500], loss: 2.4739
# Epoch [192/1000], step[1000], loss: 3.3383
# Train Accuracy:13584/45438
# Test accuracy:2403/15142
#
# Epoch [193/1000], step[500], loss: 3.0466
# Epoch [193/1000], step[1000], loss: 3.6794
# Train Accuracy:13628/45438
# Test accuracy:2390/15142
#
# Epoch [194/1000], step[500], loss: 2.8301
# Epoch [194/1000], step[1000], loss: 2.5395
# Train Accuracy:13856/45438
# Test accuracy:2410/15142
#
# Epoch [195/1000], step[500], loss: 2.4717
# Epoch [195/1000], step[1000], loss: 3.9248
# Train Accuracy:13844/45438
# Test accuracy:2443/15142
#
# Epoch [196/1000], step[500], loss: 2.9165
# Epoch [196/1000], step[1000], loss: 3.0644
# Train Accuracy:13869/45438
# Test accuracy:2391/15142
#
# Epoch [197/1000], step[500], loss: 3.3056
# Epoch [197/1000], step[1000], loss: 3.1921
# Train Accuracy:13797/45438
# Test accuracy:2390/15142
#
# Epoch [198/1000], step[500], loss: 3.4514
# Epoch [198/1000], step[1000], loss: 3.0346
# Train Accuracy:14110/45438
# Test accuracy:2390/15142
#
# Epoch [199/1000], step[500], loss: 3.3310
# Epoch [199/1000], step[1000], loss: 2.8193
# Train Accuracy:14185/45438
# Test accuracy:2421/15142
#
# Epoch [200/1000], step[500], loss: 2.9424
# Epoch [200/1000], step[1000], loss: 2.7415
# Train Accuracy:14265/45438
# Test accuracy:2390/15142
#
# Epoch [201/1000], step[500], loss: 2.6761
# Epoch [201/1000], step[1000], loss: 3.4279
# Train Accuracy:14208/45438
# Test accuracy:2406/15142
#
# Epoch [202/1000], step[500], loss: 2.7084
# Epoch [202/1000], step[1000], loss: 2.7390
# Train Accuracy:14135/45438
# Test accuracy:2453/15142
#
# Epoch [203/1000], step[500], loss: 3.4296
# Epoch [203/1000], step[1000], loss: 3.3111
# Train Accuracy:14451/45438
# Test accuracy:2441/15142
#
# Epoch [204/1000], step[500], loss: 2.7051
# Epoch [204/1000], step[1000], loss: 2.4670
# Train Accuracy:14370/45438
# Test accuracy:2426/15142
#
# Epoch [205/1000], step[500], loss: 3.5732
# Epoch [205/1000], step[1000], loss: 3.1499
# Train Accuracy:14397/45438
# Test accuracy:2430/15142
#
# Epoch [206/1000], step[500], loss: 2.9323
# Epoch [206/1000], step[1000], loss: 2.5306
# Train Accuracy:14511/45438
# Test accuracy:2451/15142
#
# Epoch [207/1000], step[500], loss: 3.1705
# Epoch [207/1000], step[1000], loss: 3.0095
# Train Accuracy:14540/45438
# Test accuracy:2456/15142
#
# Epoch [208/1000], step[500], loss: 3.0596
# Epoch [208/1000], step[1000], loss: 2.8963
# Train Accuracy:14690/45438
# Test accuracy:2398/15142
#
# Epoch [209/1000], step[500], loss: 2.4572
# Epoch [209/1000], step[1000], loss: 3.4225
# Train Accuracy:14849/45438
# Test accuracy:2441/15142
#
# Epoch [210/1000], step[500], loss: 2.6977
# Epoch [210/1000], step[1000], loss: 2.8718
# Train Accuracy:14758/45438
# Test accuracy:2480/15142
#
# Epoch [211/1000], step[500], loss: 3.0948
# Epoch [211/1000], step[1000], loss: 3.2188
# Train Accuracy:14771/45438
# Test accuracy:2423/15142
#
# Epoch [212/1000], step[500], loss: 3.2552
# Epoch [212/1000], step[1000], loss: 2.3642
# Train Accuracy:14777/45438
# Test accuracy:2473/15142
#
# Epoch [213/1000], step[500], loss: 3.0789
# Epoch [213/1000], step[1000], loss: 2.4840
# Train Accuracy:14998/45438
# Test accuracy:2455/15142
#
# Epoch [214/1000], step[500], loss: 2.7563
# Epoch [214/1000], step[1000], loss: 2.8571
# Train Accuracy:14913/45438
# Test accuracy:2420/15142
#
# Epoch [215/1000], step[500], loss: 2.9315
# Epoch [215/1000], step[1000], loss: 3.3944
# Train Accuracy:15206/45438
# Test accuracy:2460/15142
#
# Epoch [216/1000], step[500], loss: 2.7962
# Epoch [216/1000], step[1000], loss: 2.3631
# Train Accuracy:15160/45438
# Test accuracy:2467/15142
#
# Epoch [217/1000], step[500], loss: 2.7689
# Epoch [217/1000], step[1000], loss: 3.0739
# Train Accuracy:15245/45438
# Test accuracy:2490/15142
#
# Epoch [218/1000], step[500], loss: 2.9722
# Epoch [218/1000], step[1000], loss: 3.0364
# Train Accuracy:15156/45438
# Test accuracy:2499/15142
#
# Epoch [219/1000], step[500], loss: 3.1761
# Epoch [219/1000], step[1000], loss: 2.4621
# Train Accuracy:15349/45438
# Test accuracy:2508/15142
#
# Epoch [220/1000], step[500], loss: 2.5579
# Epoch [220/1000], step[1000], loss: 3.4549
# Train Accuracy:15324/45438
# Test accuracy:2469/15142
#
# Epoch [221/1000], step[500], loss: 2.8930
# Epoch [221/1000], step[1000], loss: 3.0366
# Train Accuracy:15541/45438
# Test accuracy:2519/15142
#
# Epoch [222/1000], step[500], loss: 2.7601
# Epoch [222/1000], step[1000], loss: 2.6388
# Train Accuracy:15625/45438
# Test accuracy:2504/15142
#
# Epoch [223/1000], step[500], loss: 2.8407
# Epoch [223/1000], step[1000], loss: 2.6338
# Train Accuracy:15832/45438
# Test accuracy:2473/15142
#
# Epoch [224/1000], step[500], loss: 3.1220
# Epoch [224/1000], step[1000], loss: 2.2508
# Train Accuracy:15615/45438
# Test accuracy:2502/15142
#
# Epoch [225/1000], step[500], loss: 2.8380
# Epoch [225/1000], step[1000], loss: 2.2740
# Train Accuracy:15784/45438
# Test accuracy:2504/15142
#
# Epoch [226/1000], step[500], loss: 3.4255
# Epoch [226/1000], step[1000], loss: 3.1742
# Train Accuracy:15687/45438
# Test accuracy:2524/15142
#
# Epoch [227/1000], step[500], loss: 2.6828
# Epoch [227/1000], step[1000], loss: 2.4314
# Train Accuracy:15827/45438
# Test accuracy:2504/15142
#
# Epoch [228/1000], step[500], loss: 3.0766
# Epoch [228/1000], step[1000], loss: 2.7249
# Train Accuracy:15921/45438
# Test accuracy:2497/15142
#
# Epoch [229/1000], step[500], loss: 2.4751
# Epoch [229/1000], step[1000], loss: 2.9692
# Train Accuracy:15835/45438
# Test accuracy:2504/15142
#
# Epoch [230/1000], step[500], loss: 2.7101
# Epoch [230/1000], step[1000], loss: 3.1056
# Train Accuracy:15962/45438
# Test accuracy:2486/15142
#
# Epoch [231/1000], step[500], loss: 2.7431
# Epoch [231/1000], step[1000], loss: 2.0711
# Train Accuracy:16069/45438
# Test accuracy:2517/15142
#
# Epoch [232/1000], step[500], loss: 3.2189
# Epoch [232/1000], step[1000], loss: 2.7011
# Train Accuracy:16164/45438
# Test accuracy:2541/15142
#
# Epoch [233/1000], step[500], loss: 2.3094
# Epoch [233/1000], step[1000], loss: 3.0214
# Train Accuracy:16052/45438
# Test accuracy:2476/15142
#
# Epoch [234/1000], step[500], loss: 3.2182
# Epoch [234/1000], step[1000], loss: 2.3390
# Train Accuracy:16393/45438
# Test accuracy:2577/15142
#
# Epoch [235/1000], step[500], loss: 2.6156
# Epoch [235/1000], step[1000], loss: 2.5119
# Train Accuracy:16344/45438
# Test accuracy:2575/15142
#
# Epoch [236/1000], step[500], loss: 2.7278
# Epoch [236/1000], step[1000], loss: 2.9949
# Train Accuracy:16403/45438
# Test accuracy:2544/15142
#
# Epoch [237/1000], step[500], loss: 2.8976
# Epoch [237/1000], step[1000], loss: 3.2908
# Train Accuracy:16383/45438
# Test accuracy:2530/15142
#
# Epoch [238/1000], step[500], loss: 2.2148
# Epoch [238/1000], step[1000], loss: 2.8338
# Train Accuracy:16599/45438
# Test accuracy:2552/15142
#
# Epoch [239/1000], step[500], loss: 2.5156
# Epoch [239/1000], step[1000], loss: 3.0412
# Train Accuracy:16447/45438
# Test accuracy:2532/15142
#
# Epoch [240/1000], step[500], loss: 3.1676
# Epoch [240/1000], step[1000], loss: 2.5621
# Train Accuracy:16675/45438
# Test accuracy:2567/15142
#
# Epoch [241/1000], step[500], loss: 3.2729
# Epoch [241/1000], step[1000], loss: 2.1700
# Train Accuracy:16651/45438
# Test accuracy:2558/15142
#
# Epoch [242/1000], step[500], loss: 3.0188
# Epoch [242/1000], step[1000], loss: 2.5593
# Train Accuracy:16634/45438
# Test accuracy:2554/15142
#
# Epoch [243/1000], step[500], loss: 3.2754
# Epoch [243/1000], step[1000], loss: 2.5665
# Train Accuracy:16803/45438
# Test accuracy:2528/15142
#
# Epoch [244/1000], step[500], loss: 2.6144
# Epoch [244/1000], step[1000], loss: 2.6391
# Train Accuracy:16763/45438
# Test accuracy:2555/15142
#
# Epoch [245/1000], step[500], loss: 3.3729
# Epoch [245/1000], step[1000], loss: 2.3146
# Train Accuracy:16806/45438
# Test accuracy:2550/15142
#
# Epoch [246/1000], step[500], loss: 2.5169
# Epoch [246/1000], step[1000], loss: 2.4020
# Train Accuracy:16889/45438
# Test accuracy:2565/15142
#
# Epoch [247/1000], step[500], loss: 3.3352
# Epoch [247/1000], step[1000], loss: 2.6369
# Train Accuracy:16770/45438
# Test accuracy:2553/15142
#
# Epoch [248/1000], step[500], loss: 2.7305
# Epoch [248/1000], step[1000], loss: 2.9574
# Train Accuracy:17035/45438
# Test accuracy:2551/15142
#
# Epoch [249/1000], step[500], loss: 2.2048
# Epoch [249/1000], step[1000], loss: 2.6877
# Train Accuracy:16958/45438
# Test accuracy:2542/15142
#
# Epoch [250/1000], step[500], loss: 3.0473
# Epoch [250/1000], step[1000], loss: 3.1904
# Train Accuracy:17238/45438
# Test accuracy:2550/15142
#
# Epoch [251/1000], step[500], loss: 3.0056
# Epoch [251/1000], step[1000], loss: 3.1985
# Train Accuracy:17164/45438
# Test accuracy:2536/15142
#
# Epoch [252/1000], step[500], loss: 3.1807
# Epoch [252/1000], step[1000], loss: 2.8629
# Train Accuracy:17250/45438
# Test accuracy:2547/15142
#
# Epoch [253/1000], step[500], loss: 2.4802
# Epoch [253/1000], step[1000], loss: 2.5590
# Train Accuracy:17333/45438
# Test accuracy:2551/15142
#
# Epoch [254/1000], step[500], loss: 2.0699
# Epoch [254/1000], step[1000], loss: 2.2719
# Train Accuracy:17344/45438
# Test accuracy:2563/15142
#
# Epoch [255/1000], step[500], loss: 2.8191
# Epoch [255/1000], step[1000], loss: 2.5075
# Train Accuracy:17378/45438
# Test accuracy:2558/15142
#
# Epoch [256/1000], step[500], loss: 2.2741
# Epoch [256/1000], step[1000], loss: 2.4333
# Train Accuracy:17434/45438
# Test accuracy:2538/15142
#
# Epoch [257/1000], step[500], loss: 2.9620
# Epoch [257/1000], step[1000], loss: 2.7464
# Train Accuracy:17452/45438
# Test accuracy:2527/15142
#
# Epoch [258/1000], step[500], loss: 2.5482
# Epoch [258/1000], step[1000], loss: 2.7669
# Train Accuracy:17430/45438
# Test accuracy:2550/15142
#
# Epoch [259/1000], step[500], loss: 2.1444
# Epoch [259/1000], step[1000], loss: 2.2686
# Train Accuracy:17675/45438
# Test accuracy:2539/15142
#
# Epoch [260/1000], step[500], loss: 2.5257
# Epoch [260/1000], step[1000], loss: 2.7395
# Train Accuracy:17588/45438
# Test accuracy:2530/15142
#
# Epoch [261/1000], step[500], loss: 2.8925
# Epoch [261/1000], step[1000], loss: 2.6713
# Train Accuracy:17692/45438
# Test accuracy:2598/15142
#
# Epoch [262/1000], step[500], loss: 2.1328
# Epoch [262/1000], step[1000], loss: 2.2867
# Train Accuracy:17738/45438
# Test accuracy:2647/15142
#
# Epoch [263/1000], step[500], loss: 2.2972
# Epoch [263/1000], step[1000], loss: 2.8275
# Train Accuracy:17769/45438
# Test accuracy:2543/15142
#
# Epoch [264/1000], step[500], loss: 2.0163
# Epoch [264/1000], step[1000], loss: 2.0525
# Train Accuracy:17843/45438
# Test accuracy:2536/15142
#
# Epoch [265/1000], step[500], loss: 2.1297
# Epoch [265/1000], step[1000], loss: 2.2031
# Train Accuracy:17957/45438
# Test accuracy:2514/15142
#
# Epoch [266/1000], step[500], loss: 2.2560
# Epoch [266/1000], step[1000], loss: 2.3911
# Train Accuracy:17981/45438
# Test accuracy:2532/15142
#
# Epoch [267/1000], step[500], loss: 2.8378
# Epoch [267/1000], step[1000], loss: 2.4428
# Train Accuracy:18167/45438
# Test accuracy:2567/15142
#
# Epoch [268/1000], step[500], loss: 2.7612
# Epoch [268/1000], step[1000], loss: 2.7947
# Train Accuracy:18176/45438
# Test accuracy:2556/15142
#
# Epoch [269/1000], step[500], loss: 2.4362
# Epoch [269/1000], step[1000], loss: 2.5933
# Train Accuracy:18100/45438
# Test accuracy:2548/15142
#
# Epoch [270/1000], step[500], loss: 2.4830
# Epoch [270/1000], step[1000], loss: 2.3492
# Train Accuracy:18313/45438
# Test accuracy:2601/15142
#
# Epoch [271/1000], step[500], loss: 2.4899
# Epoch [271/1000], step[1000], loss: 3.1851
# Train Accuracy:18145/45438
# Test accuracy:2624/15142
#
# Epoch [272/1000], step[500], loss: 1.9514
# Epoch [272/1000], step[1000], loss: 2.5582
# Train Accuracy:18274/45438
# Test accuracy:2597/15142
#
# Epoch [273/1000], step[500], loss: 2.5580
# Epoch [273/1000], step[1000], loss: 2.5110
# Train Accuracy:18351/45438
# Test accuracy:2559/15142
#
# Epoch [274/1000], step[500], loss: 2.6840
# Epoch [274/1000], step[1000], loss: 2.2514
# Train Accuracy:18274/45438
# Test accuracy:2519/15142
#
# Epoch [275/1000], step[500], loss: 2.3718
# Epoch [275/1000], step[1000], loss: 2.3802
# Train Accuracy:18361/45438
# Test accuracy:2573/15142
#
# Epoch [276/1000], step[500], loss: 2.5625
# Epoch [276/1000], step[1000], loss: 2.1034
# Train Accuracy:18583/45438
# Test accuracy:2543/15142
#
# Epoch [277/1000], step[500], loss: 2.9938
# Epoch [277/1000], step[1000], loss: 2.5397
# Train Accuracy:18398/45438
# Test accuracy:2554/15142
#
# Epoch [278/1000], step[500], loss: 3.2150
# Epoch [278/1000], step[1000], loss: 2.6071
# Train Accuracy:18549/45438
# Test accuracy:2602/15142
#
# Epoch [279/1000], step[500], loss: 2.1652
# Epoch [279/1000], step[1000], loss: 2.1182
# Train Accuracy:18603/45438
# Test accuracy:2564/15142
#
# Epoch [280/1000], step[500], loss: 2.1870
# Epoch [280/1000], step[1000], loss: 2.8744
# Train Accuracy:18567/45438
# Test accuracy:2544/15142
#
# Epoch [281/1000], step[500], loss: 2.3150
# Epoch [281/1000], step[1000], loss: 2.7913
# Train Accuracy:18859/45438
# Test accuracy:2585/15142
#
# Epoch [282/1000], step[500], loss: 2.5134
# Epoch [282/1000], step[1000], loss: 2.6811
# Train Accuracy:18632/45438
# Test accuracy:2579/15142
#
# Epoch [283/1000], step[500], loss: 2.3139
# Epoch [283/1000], step[1000], loss: 2.3607
# Train Accuracy:18790/45438
# Test accuracy:2550/15142
#
# Epoch [284/1000], step[500], loss: 1.9584
# Epoch [284/1000], step[1000], loss: 2.4320
# Train Accuracy:18826/45438
# Test accuracy:2601/15142
#
# Epoch [285/1000], step[500], loss: 2.3546
# Epoch [285/1000], step[1000], loss: 2.6714
# Train Accuracy:18970/45438
# Test accuracy:2640/15142
#
# Epoch [286/1000], step[500], loss: 1.9071
# Epoch [286/1000], step[1000], loss: 2.6808
# Train Accuracy:18856/45438
# Test accuracy:2559/15142
#
# Epoch [287/1000], step[500], loss: 2.9075
# Epoch [287/1000], step[1000], loss: 2.2349
# Train Accuracy:19027/45438
# Test accuracy:2578/15142
#
# Epoch [288/1000], step[500], loss: 1.8497
# Epoch [288/1000], step[1000], loss: 2.2722
# Train Accuracy:19212/45438
# Test accuracy:2595/15142
#
# Epoch [289/1000], step[500], loss: 2.1245
# Epoch [289/1000], step[1000], loss: 2.5638
# Train Accuracy:19019/45438
# Test accuracy:2566/15142
#
# Epoch [290/1000], step[500], loss: 2.3635
# Epoch [290/1000], step[1000], loss: 2.9399
# Train Accuracy:19294/45438
# Test accuracy:2570/15142
#
# Epoch [291/1000], step[500], loss: 3.0650
# Epoch [291/1000], step[1000], loss: 2.7407
# Train Accuracy:19094/45438
# Test accuracy:2637/15142
#
# Epoch [292/1000], step[500], loss: 2.2269
# Epoch [292/1000], step[1000], loss: 2.2541
# Train Accuracy:19233/45438
# Test accuracy:2585/15142
#
# Epoch [293/1000], step[500], loss: 2.0087
# Epoch [293/1000], step[1000], loss: 2.3478
# Train Accuracy:19357/45438
# Test accuracy:2580/15142
#
# Epoch [294/1000], step[500], loss: 2.1575
# Epoch [294/1000], step[1000], loss: 2.1241
# Train Accuracy:19395/45438
# Test accuracy:2539/15142
#
# Epoch [295/1000], step[500], loss: 2.2815
# Epoch [295/1000], step[1000], loss: 3.2331
# Train Accuracy:19358/45438
# Test accuracy:2592/15142
#
# Epoch [296/1000], step[500], loss: 2.0977
# Epoch [296/1000], step[1000], loss: 2.5282
# Train Accuracy:19371/45438
# Test accuracy:2610/15142
#
# Epoch [297/1000], step[500], loss: 2.3713
# Epoch [297/1000], step[1000], loss: 2.5165
# Train Accuracy:19505/45438
# Test accuracy:2614/15142
#
# Epoch [298/1000], step[500], loss: 2.0117
# Epoch [298/1000], step[1000], loss: 2.4837
# Train Accuracy:19482/45438
# Test accuracy:2621/15142
#
# Epoch [299/1000], step[500], loss: 2.2212
# Epoch [299/1000], step[1000], loss: 2.8570
# Train Accuracy:19496/45438
# Test accuracy:2617/15142
#
# Epoch [300/1000], step[500], loss: 2.3286
# Epoch [300/1000], step[1000], loss: 1.9038
# Train Accuracy:19522/45438
# Test accuracy:2592/15142
#
# Epoch [301/1000], step[500], loss: 2.3389
# Epoch [301/1000], step[1000], loss: 2.4581
# Train Accuracy:19506/45438
# Test accuracy:2583/15142
#
# Epoch [302/1000], step[500], loss: 2.5501
# Epoch [302/1000], step[1000], loss: 2.3052
# Train Accuracy:19602/45438
# Test accuracy:2629/15142
#
# Epoch [303/1000], step[500], loss: 2.6134
# Epoch [303/1000], step[1000], loss: 2.4193
# Train Accuracy:19619/45438
# Test accuracy:2598/15142
#
# Epoch [304/1000], step[500], loss: 1.7929
# Epoch [304/1000], step[1000], loss: 2.4120
# Train Accuracy:19926/45438
# Test accuracy:2602/15142
#
# Epoch [305/1000], step[500], loss: 2.5500
# Epoch [305/1000], step[1000], loss: 1.8814
# Train Accuracy:19745/45438
# Test accuracy:2630/15142
#
# Epoch [306/1000], step[500], loss: 1.9901
# Epoch [306/1000], step[1000], loss: 2.2620
# Train Accuracy:20072/45438
# Test accuracy:2595/15142
#
# Epoch [307/1000], step[500], loss: 2.0653
# Epoch [307/1000], step[1000], loss: 2.3236
# Train Accuracy:19968/45438
# Test accuracy:2601/15142
#
# Epoch [308/1000], step[500], loss: 2.4217
# Epoch [308/1000], step[1000], loss: 2.3825
# Train Accuracy:19787/45438
# Test accuracy:2617/15142
#
# Epoch [309/1000], step[500], loss: 2.2110
# Epoch [309/1000], step[1000], loss: 2.1083
# Train Accuracy:19964/45438
# Test accuracy:2612/15142
#
# Epoch [310/1000], step[500], loss: 2.2912
# Epoch [310/1000], step[1000], loss: 2.5372
# Train Accuracy:20106/45438
# Test accuracy:2638/15142
#
# Epoch [311/1000], step[500], loss: 2.4852
# Epoch [311/1000], step[1000], loss: 2.2297
# Train Accuracy:19998/45438
# Test accuracy:2557/15142
#
# Epoch [312/1000], step[500], loss: 2.7108
# Epoch [312/1000], step[1000], loss: 2.7065
# Train Accuracy:20085/45438
# Test accuracy:2635/15142
#
# Epoch [313/1000], step[500], loss: 2.0352
# Epoch [313/1000], step[1000], loss: 1.9549
# Train Accuracy:20024/45438
# Test accuracy:2642/15142
#
# Epoch [314/1000], step[500], loss: 2.2331
# Epoch [314/1000], step[1000], loss: 1.7823
# Train Accuracy:20117/45438
# Test accuracy:2645/15142
#
# Epoch [315/1000], step[500], loss: 2.3430
# Epoch [315/1000], step[1000], loss: 2.1515
# Train Accuracy:20134/45438
# Test accuracy:2605/15142
#
# Epoch [316/1000], step[500], loss: 2.6107
# Epoch [316/1000], step[1000], loss: 2.0459
# Train Accuracy:20188/45438
# Test accuracy:2603/15142
#
# Epoch [317/1000], step[500], loss: 2.6711
# Epoch [317/1000], step[1000], loss: 1.9758
# Train Accuracy:20340/45438
# Test accuracy:2571/15142
#
# Epoch [318/1000], step[500], loss: 2.1347
# Epoch [318/1000], step[1000], loss: 1.9785
# Train Accuracy:20345/45438
# Test accuracy:2613/15142
#
# Epoch [319/1000], step[500], loss: 2.3383
# Epoch [319/1000], step[1000], loss: 2.5029
# Train Accuracy:20351/45438
# Test accuracy:2635/15142
#
# Epoch [320/1000], step[500], loss: 1.6612
# Epoch [320/1000], step[1000], loss: 2.0485
# Train Accuracy:20345/45438
# Test accuracy:2620/15142
#
# Epoch [321/1000], step[500], loss: 2.7396
# Epoch [321/1000], step[1000], loss: 2.7330
# Train Accuracy:20417/45438
# Test accuracy:2627/15142
#
# Epoch [322/1000], step[500], loss: 1.5240
# Epoch [322/1000], step[1000], loss: 2.5870
# Train Accuracy:20464/45438
# Test accuracy:2608/15142
#
# Epoch [323/1000], step[500], loss: 1.9366
# Epoch [323/1000], step[1000], loss: 2.4654
# Train Accuracy:20489/45438
# Test accuracy:2599/15142
#
# Epoch [324/1000], step[500], loss: 2.0012
# Epoch [324/1000], step[1000], loss: 2.1251
# Train Accuracy:20583/45438
# Test accuracy:2642/15142
#
# Epoch [325/1000], step[500], loss: 1.7523
# Epoch [325/1000], step[1000], loss: 2.0622
# Train Accuracy:20428/45438
# Test accuracy:2626/15142
#
# Epoch [326/1000], step[500], loss: 2.3545
# Epoch [326/1000], step[1000], loss: 1.8805
# Train Accuracy:20489/45438
# Test accuracy:2609/15142
#
# Epoch [327/1000], step[500], loss: 2.3396
# Epoch [327/1000], step[1000], loss: 1.6855
# Train Accuracy:20864/45438
# Test accuracy:2582/15142
#
# Epoch [328/1000], step[500], loss: 2.6870
# Epoch [328/1000], step[1000], loss: 2.4024
# Train Accuracy:20832/45438
# Test accuracy:2654/15142
#
# Epoch [329/1000], step[500], loss: 2.2541
# Epoch [329/1000], step[1000], loss: 1.8773
# Train Accuracy:20900/45438
# Test accuracy:2671/15142
#
# Epoch [330/1000], step[500], loss: 2.4632
# Epoch [330/1000], step[1000], loss: 1.7343
# Train Accuracy:20904/45438
# Test accuracy:2606/15142
#
# Epoch [331/1000], step[500], loss: 2.6908
# Epoch [331/1000], step[1000], loss: 2.1806
# Train Accuracy:20786/45438
# Test accuracy:2584/15142
#
# Epoch [332/1000], step[500], loss: 1.8278
# Epoch [332/1000], step[1000], loss: 2.0054
# Train Accuracy:20893/45438
# Test accuracy:2595/15142
#
# Epoch [333/1000], step[500], loss: 2.4829
# Epoch [333/1000], step[1000], loss: 2.0612
# Train Accuracy:20786/45438
# Test accuracy:2648/15142
#
# Epoch [334/1000], step[500], loss: 2.2886
# Epoch [334/1000], step[1000], loss: 2.0230
# Train Accuracy:21024/45438
# Test accuracy:2629/15142
#
# Epoch [335/1000], step[500], loss: 1.3990
# Epoch [335/1000], step[1000], loss: 1.3686
# Train Accuracy:20925/45438
# Test accuracy:2614/15142
#
# Epoch [336/1000], step[500], loss: 2.1956
# Epoch [336/1000], step[1000], loss: 1.5905
# Train Accuracy:21079/45438
# Test accuracy:2625/15142
#
# Epoch [337/1000], step[500], loss: 2.1144
# Epoch [337/1000], step[1000], loss: 1.8108
# Train Accuracy:21318/45438
# Test accuracy:2677/15142
#
# Epoch [338/1000], step[500], loss: 1.9502
# Epoch [338/1000], step[1000], loss: 1.9624
# Train Accuracy:21104/45438
# Test accuracy:2616/15142
#
# Epoch [339/1000], step[500], loss: 2.0473
# Epoch [339/1000], step[1000], loss: 2.7331
# Train Accuracy:21084/45438
# Test accuracy:2656/15142
#
# Epoch [340/1000], step[500], loss: 2.1994
# Epoch [340/1000], step[1000], loss: 1.7430
# Train Accuracy:21057/45438
# Test accuracy:2618/15142
#
# Epoch [341/1000], step[500], loss: 1.9895
# Epoch [341/1000], step[1000], loss: 2.0420
# Train Accuracy:21247/45438
# Test accuracy:2586/15142
#
# Epoch [342/1000], step[500], loss: 2.3758
# Epoch [342/1000], step[1000], loss: 2.0234
# Train Accuracy:21267/45438
# Test accuracy:2658/15142
#
# Epoch [343/1000], step[500], loss: 2.1993
# Epoch [343/1000], step[1000], loss: 1.9177
# Train Accuracy:21251/45438
# Test accuracy:2664/15142
#
# Epoch [344/1000], step[500], loss: 1.9447
# Epoch [344/1000], step[1000], loss: 2.1756
# Train Accuracy:21290/45438
# Test accuracy:2618/15142
#
# Epoch [345/1000], step[500], loss: 2.1177
# Epoch [345/1000], step[1000], loss: 1.8933
# Train Accuracy:21296/45438
# Test accuracy:2596/15142
#
# Epoch [346/1000], step[500], loss: 2.6544
# Epoch [346/1000], step[1000], loss: 2.3580
# Train Accuracy:21445/45438
# Test accuracy:2653/15142
#
# Epoch [347/1000], step[500], loss: 1.9963
# Epoch [347/1000], step[1000], loss: 2.0707
# Train Accuracy:21647/45438
# Test accuracy:2631/15142
#
# Epoch [348/1000], step[500], loss: 1.4319
# Epoch [348/1000], step[1000], loss: 2.5660
# Train Accuracy:21408/45438
# Test accuracy:2638/15142
#
# Epoch [349/1000], step[500], loss: 1.9667
# Epoch [349/1000], step[1000], loss: 2.1138
# Train Accuracy:21498/45438
# Test accuracy:2589/15142
#
# Epoch [350/1000], step[500], loss: 2.7469
# Epoch [350/1000], step[1000], loss: 2.5751
# Train Accuracy:21626/45438
# Test accuracy:2641/15142
#
# Epoch [351/1000], step[500], loss: 1.4497
# Epoch [351/1000], step[1000], loss: 2.1479
# Train Accuracy:21599/45438
# Test accuracy:2687/15142
#
# Epoch [352/1000], step[500], loss: 2.0324
# ...
# Epoch [885/1000], step[1000], loss: 0.8726
# Train Accuracy:31738/45438
# Test accuracy:2796/15142
#
# Epoch [886/1000], step[500], loss: 0.9578
# Epoch [886/1000], step[1000], loss: 0.8791
# Train Accuracy:31658/45438
# Test accuracy:2815/15142
#
# Epoch [887/1000], step[500], loss: 0.8218
# Epoch [887/1000], step[1000], loss: 1.0265
# Train Accuracy:31671/45438
# Test accuracy:2792/15142
#
# Epoch [888/1000], step[500], loss: 0.6015
# Epoch [888/1000], step[1000], loss: 1.3890
# Train Accuracy:31735/45438
# Test accuracy:2813/15142
#
# Epoch [889/1000], step[500], loss: 0.7323
# Epoch [889/1000], step[1000], loss: 1.3281
# Train Accuracy:31828/45438
# Test accuracy:2784/15142
#
# Epoch [890/1000], step[500], loss: 0.8970
# Epoch [890/1000], step[1000], loss: 1.4044
# Train Accuracy:31835/45438
# Test accuracy:2773/15142
#
# Epoch [891/1000], step[500], loss: 0.9825
# Epoch [891/1000], step[1000], loss: 0.7974
# Train Accuracy:31898/45438
# Test accuracy:2831/15142
#
# Epoch [892/1000], step[500], loss: 1.1362
# Epoch [892/1000], step[1000], loss: 1.1566
# Train Accuracy:31571/45438
# Test accuracy:2750/15142
#
# Epoch [893/1000], step[500], loss: 1.1316
# Epoch [893/1000], step[1000], loss: 0.9481
# Train Accuracy:31758/45438
# Test accuracy:2801/15142
#
# Epoch [894/1000], step[500], loss: 0.8570
# Epoch [894/1000], step[1000], loss: 1.2025
# Train Accuracy:31927/45438
# Test accuracy:2858/15142
#
# Epoch [895/1000], step[500], loss: 0.9097
# Epoch [895/1000], step[1000], loss: 1.2393
# Train Accuracy:32006/45438
# Test accuracy:2808/15142
#
# Epoch [896/1000], step[500], loss: 0.7697
# Epoch [896/1000], step[1000], loss: 0.9767
# Train Accuracy:31712/45438
# Test accuracy:2758/15142
#
# Epoch [897/1000], step[500], loss: 1.0301
# Epoch [897/1000], step[1000], loss: 0.9477
# Train Accuracy:31723/45438
# Test accuracy:2788/15142
#
# Epoch [898/1000], step[500], loss: 1.2768
# Epoch [898/1000], step[1000], loss: 1.5969
# Train Accuracy:31763/45438
# Test accuracy:2830/15142
#
# Epoch [899/1000], step[500], loss: 0.8240
# Epoch [899/1000], step[1000], loss: 1.0005
# Train Accuracy:31864/45438
# Test accuracy:2805/15142
#
# Epoch [900/1000], step[500], loss: 1.1616
# Epoch [900/1000], step[1000], loss: 1.1049
# Train Accuracy:31847/45438
# Test accuracy:2764/15142
#
# Epoch [901/1000], step[500], loss: 1.2667
# Epoch [901/1000], step[1000], loss: 1.0588
# Train Accuracy:31850/45438
# Test accuracy:2795/15142
#
# Epoch [902/1000], step[500], loss: 1.4359
# Epoch [902/1000], step[1000], loss: 0.8811
# Train Accuracy:31840/45438
# Test accuracy:2814/15142
#
# Epoch [903/1000], step[500], loss: 1.1179
# Epoch [903/1000], step[1000], loss: 1.0383
# Train Accuracy:31847/45438
# Test accuracy:2797/15142
#
# Epoch [904/1000], step[500], loss: 0.9872
# Epoch [904/1000], step[1000], loss: 0.8279
# Train Accuracy:31917/45438
# Test accuracy:2791/15142
#
# Epoch [905/1000], step[500], loss: 0.8570
# Epoch [905/1000], step[1000], loss: 0.9045
# Train Accuracy:31960/45438
# Test accuracy:2810/15142
#
# Epoch [906/1000], step[500], loss: 1.0931
# Epoch [906/1000], step[1000], loss: 0.9810
# Train Accuracy:31884/45438
# Test accuracy:2855/15142
#
# Epoch [907/1000], step[500], loss: 1.0226
# Epoch [907/1000], step[1000], loss: 0.8712
# Train Accuracy:31898/45438
# Test accuracy:2820/15142
#
# Epoch [908/1000], step[500], loss: 1.0359
# Epoch [908/1000], step[1000], loss: 1.1897
# Train Accuracy:31928/45438
# Test accuracy:2822/15142
#
# Epoch [909/1000], step[500], loss: 0.6472
# Epoch [909/1000], step[1000], loss: 1.9656
# Train Accuracy:31864/45438
# Test accuracy:2818/15142
#
# Epoch [910/1000], step[500], loss: 1.1738
# Epoch [910/1000], step[1000], loss: 1.0427
# Train Accuracy:32059/45438
# Test accuracy:2738/15142
#
# Epoch [911/1000], step[500], loss: 1.5773
# Epoch [911/1000], step[1000], loss: 1.1164
# Train Accuracy:32045/45438
# Test accuracy:2791/15142
#
# Epoch [912/1000], step[500], loss: 0.6956
# Epoch [912/1000], step[1000], loss: 1.5065
# Train Accuracy:31896/45438
# Test accuracy:2785/15142
#
# Epoch [913/1000], step[500], loss: 1.4602
# Epoch [913/1000], step[1000], loss: 1.5350
# Train Accuracy:31885/45438
# Test accuracy:2835/15142
#
# Epoch [914/1000], step[500], loss: 1.6637
# Epoch [914/1000], step[1000], loss: 1.2245
# Train Accuracy:32017/45438
# Test accuracy:2825/15142
#
# Epoch [915/1000], step[500], loss: 1.3366
# Epoch [915/1000], step[1000], loss: 0.9934
# Train Accuracy:32011/45438
# Test accuracy:2779/15142
#
# Epoch [916/1000], step[500], loss: 1.2683
# Epoch [916/1000], step[1000], loss: 1.3009
# Train Accuracy:32045/45438
# Test accuracy:2821/15142
#
# Epoch [917/1000], step[500], loss: 0.8030
# Epoch [917/1000], step[1000], loss: 0.8736
# Train Accuracy:32031/45438
# Test accuracy:2817/15142
#
# Epoch [918/1000], step[500], loss: 0.9212
# Epoch [918/1000], step[1000], loss: 0.6332
# Train Accuracy:32147/45438
# Test accuracy:2786/15142
#
# Epoch [919/1000], step[500], loss: 0.9503
# Epoch [919/1000], step[1000], loss: 1.1113
# Train Accuracy:31949/45438
# Test accuracy:2781/15142
#
# Epoch [920/1000], step[500], loss: 1.8867
# Epoch [920/1000], step[1000], loss: 1.0989
# Train Accuracy:32135/45438
# Test accuracy:2802/15142
#
# Epoch [921/1000], step[500], loss: 0.9081
# Epoch [921/1000], step[1000], loss: 0.8725
# Train Accuracy:32144/45438
# Test accuracy:2767/15142
#
# Epoch [922/1000], step[500], loss: 1.2765
# Epoch [922/1000], step[1000], loss: 0.5921
# Train Accuracy:31966/45438
# Test accuracy:2784/15142
#
# Epoch [923/1000], step[500], loss: 1.1715
# Epoch [923/1000], step[1000], loss: 1.1994
# Train Accuracy:32105/45438
# Test accuracy:2772/15142
#
# Epoch [924/1000], step[500], loss: 0.9689
# Epoch [924/1000], step[1000], loss: 1.1838
# Train Accuracy:32147/45438
# Test accuracy:2808/15142
#
# Epoch [925/1000], step[500], loss: 1.4706
# Epoch [925/1000], step[1000], loss: 1.3282
# Train Accuracy:32078/45438
# Test accuracy:2775/15142
#
# Epoch [926/1000], step[500], loss: 0.6957
# Epoch [926/1000], step[1000], loss: 0.7277
# Train Accuracy:32084/45438
# Test accuracy:2816/15142
#
# Epoch [927/1000], step[500], loss: 1.0764
# Epoch [927/1000], step[1000], loss: 1.3934
# Train Accuracy:32320/45438
# Test accuracy:2826/15142
#
# Epoch [928/1000], step[500], loss: 0.8358
# Epoch [928/1000], step[1000], loss: 0.7395
# Train Accuracy:31983/45438
# Test accuracy:2775/15142
#
# Epoch [929/1000], step[500], loss: 1.3424
# Epoch [929/1000], step[1000], loss: 0.6529
# Train Accuracy:32191/45438
# Test accuracy:2796/15142
#
# Epoch [930/1000], step[500], loss: 0.7371
# Epoch [930/1000], step[1000], loss: 1.4249
# Train Accuracy:32166/45438
# Test accuracy:2778/15142
#
# Epoch [931/1000], step[500], loss: 1.5099
# Epoch [931/1000], step[1000], loss: 1.4652
# Train Accuracy:32097/45438
# Test accuracy:2788/15142
#
# Epoch [932/1000], step[500], loss: 0.6639
# Epoch [932/1000], step[1000], loss: 1.2646
# Train Accuracy:32228/45438
# Test accuracy:2845/15142
#
# Epoch [933/1000], step[500], loss: 0.7220
# Epoch [933/1000], step[1000], loss: 1.1518
# Train Accuracy:32212/45438
# Test accuracy:2774/15142
#
# Epoch [934/1000], step[500], loss: 0.7951
# Epoch [934/1000], step[1000], loss: 0.6376
# Train Accuracy:32142/45438
# Test accuracy:2769/15142
#
# Epoch [935/1000], step[500], loss: 1.2059
# Epoch [935/1000], step[1000], loss: 0.9341
# Train Accuracy:32273/45438
# Test accuracy:2735/15142
#
# Epoch [936/1000], step[500], loss: 0.7156
# Epoch [936/1000], step[1000], loss: 0.6241
# Train Accuracy:32103/45438
# Test accuracy:2790/15142
#
# Epoch [937/1000], step[500], loss: 1.1524
# Epoch [937/1000], step[1000], loss: 0.8513
# Train Accuracy:32327/45438
# Test accuracy:2798/15142
#
# Epoch [938/1000], step[500], loss: 0.5146
# Epoch [938/1000], step[1000], loss: 0.6512
# Train Accuracy:32279/45438
# Test accuracy:2828/15142
#
# Epoch [939/1000], step[500], loss: 0.9145
# Epoch [939/1000], step[1000], loss: 0.8870
# Train Accuracy:32319/45438
# Test accuracy:2782/15142
#
# Epoch [940/1000], step[500], loss: 1.4131
# Epoch [940/1000], step[1000], loss: 1.2486
# Train Accuracy:32210/45438
# Test accuracy:2760/15142
#
# Epoch [941/1000], step[500], loss: 1.1678
# Epoch [941/1000], step[1000], loss: 0.8832
# Train Accuracy:32326/45438
# Test accuracy:2830/15142
#
# Epoch [942/1000], step[500], loss: 1.1971
# Epoch [942/1000], step[1000], loss: 0.4785
# Train Accuracy:32196/45438
# Test accuracy:2799/15142
#
# Epoch [943/1000], step[500], loss: 1.1170
# Epoch [943/1000], step[1000], loss: 0.8417
# Train Accuracy:32337/45438
# Test accuracy:2767/15142
#
# Epoch [944/1000], step[500], loss: 0.9792
# Epoch [944/1000], step[1000], loss: 0.8740
# Train Accuracy:32083/45438
# Test accuracy:2781/15142
#
# Epoch [945/1000], step[500], loss: 1.0056
# Epoch [945/1000], step[1000], loss: 0.9975
# Train Accuracy:32503/45438
# Test accuracy:2780/15142
#
# Epoch [946/1000], step[500], loss: 0.8929
# Epoch [946/1000], step[1000], loss: 0.9667
# Train Accuracy:32199/45438
# Test accuracy:2840/15142
#
# Epoch [947/1000], step[500], loss: 0.7465
# Epoch [947/1000], step[1000], loss: 0.5775
# Train Accuracy:32377/45438
# Test accuracy:2795/15142
#
# Epoch [948/1000], step[500], loss: 1.0773
# Epoch [948/1000], step[1000], loss: 0.8548
# Train Accuracy:32355/45438
# Test accuracy:2808/15142
#
# Epoch [949/1000], step[500], loss: 1.2639
# Epoch [949/1000], step[1000], loss: 1.1436
# Train Accuracy:32088/45438
# Test accuracy:2820/15142
#
# Epoch [950/1000], step[500], loss: 1.2231
# Epoch [950/1000], step[1000], loss: 0.6226
# Train Accuracy:32300/45438
# Test accuracy:2746/15142
#
# Epoch [951/1000], step[500], loss: 0.9479
# Epoch [951/1000], step[1000], loss: 1.1180
# Train Accuracy:32313/45438
# Test accuracy:2819/15142
#
# Epoch [952/1000], step[500], loss: 0.7934
# Epoch [952/1000], step[1000], loss: 0.9932
# Train Accuracy:32343/45438
# Test accuracy:2801/15142
#
# Epoch [953/1000], step[500], loss: 0.6537
# Epoch [953/1000], step[1000], loss: 1.0313
# Train Accuracy:32591/45438
# Test accuracy:2835/15142
#
# Epoch [954/1000], step[500], loss: 1.1473
# Epoch [954/1000], step[1000], loss: 0.9777
# Train Accuracy:32244/45438
# Test accuracy:2808/15142
#
# Epoch [955/1000], step[500], loss: 1.0494
# Epoch [955/1000], step[1000], loss: 1.3260
# Train Accuracy:32385/45438
# Test accuracy:2838/15142
#
# Epoch [956/1000], step[500], loss: 1.0617
# Epoch [956/1000], step[1000], loss: 1.0662
# Train Accuracy:32322/45438
# Test accuracy:2801/15142
#
# Epoch [957/1000], step[500], loss: 1.1518
# Epoch [957/1000], step[1000], loss: 0.9595
# Train Accuracy:32457/45438
# Test accuracy:2790/15142
#
# Epoch [958/1000], step[500], loss: 0.8030
# Epoch [958/1000], step[1000], loss: 0.6147
# Train Accuracy:32526/45438
# Test accuracy:2860/15142
#
# Epoch [959/1000], step[500], loss: 0.7979
# Epoch [959/1000], step[1000], loss: 1.1512
# Train Accuracy:32535/45438
# Test accuracy:2806/15142
#
# Epoch [960/1000], step[500], loss: 1.1838
# Epoch [960/1000], step[1000], loss: 1.0573
# Train Accuracy:32266/45438
# Test accuracy:2788/15142
#
# Epoch [961/1000], step[500], loss: 0.9142
# Epoch [961/1000], step[1000], loss: 0.9907
# Train Accuracy:32418/45438
# Test accuracy:2785/15142
#
# Epoch [962/1000], step[500], loss: 0.8342
# Epoch [962/1000], step[1000], loss: 1.0825
# Train Accuracy:32389/45438
# Test accuracy:2831/15142
#
# Epoch [963/1000], step[500], loss: 0.8690
# Epoch [963/1000], step[1000], loss: 0.8359
# Train Accuracy:32486/45438
# Test accuracy:2818/15142
#
# Epoch [964/1000], step[500], loss: 0.7615
# Epoch [964/1000], step[1000], loss: 0.7252
# Train Accuracy:32273/45438
# Test accuracy:2838/15142
#
# Epoch [965/1000], step[500], loss: 0.8350
# Epoch [965/1000], step[1000], loss: 0.7411
# Train Accuracy:32623/45438
# Test accuracy:2814/15142
#
# Epoch [966/1000], step[500], loss: 1.1832
# Epoch [966/1000], step[1000], loss: 0.9439
# Train Accuracy:32511/45438
# Test accuracy:2800/15142
#
# Epoch [967/1000], step[500], loss: 0.6191
# Epoch [967/1000], step[1000], loss: 1.0842
# Train Accuracy:32482/45438
# Test accuracy:2812/15142
#
# Epoch [968/1000], step[500], loss: 0.7122
# Epoch [968/1000], step[1000], loss: 0.5705
# Train Accuracy:32648/45438
# Test accuracy:2740/15142
#
# Epoch [969/1000], step[500], loss: 0.9554
# Epoch [969/1000], step[1000], loss: 0.9123
# Train Accuracy:32594/45438
# Test accuracy:2812/15142
#
# Epoch [970/1000], step[500], loss: 1.2413
# Epoch [970/1000], step[1000], loss: 0.8975
# Train Accuracy:32524/45438
# Test accuracy:2764/15142
#
# Epoch [971/1000], step[500], loss: 0.6329
# Epoch [971/1000], step[1000], loss: 0.6149
# Train Accuracy:32310/45438
# Test accuracy:2827/15142
#
# Epoch [972/1000], step[500], loss: 1.0292
# Epoch [972/1000], step[1000], loss: 1.1203
# Train Accuracy:32332/45438
# Test accuracy:2804/15142
#
# Epoch [973/1000], step[500], loss: 1.0679
# Epoch [973/1000], step[1000], loss: 0.7660
# Train Accuracy:32407/45438
# Test accuracy:2808/15142
#
# Epoch [974/1000], step[500], loss: 1.0037
# Epoch [974/1000], step[1000], loss: 0.8771
# Train Accuracy:32500/45438
# Test accuracy:2836/15142
#
# Epoch [975/1000], step[500], loss: 1.1062
# Epoch [975/1000], step[1000], loss: 1.1820
# Train Accuracy:32568/45438
# Test accuracy:2734/15142
#
# Epoch [976/1000], step[500], loss: 0.9070
# Epoch [976/1000], step[1000], loss: 1.2731
# Train Accuracy:32552/45438
# Test accuracy:2826/15142
#
# Epoch [977/1000], step[500], loss: 0.8364
# Epoch [977/1000], step[1000], loss: 0.4770
# Train Accuracy:32580/45438
# Test accuracy:2809/15142
#
# Epoch [978/1000], step[500], loss: 0.6923
# Epoch [978/1000], step[1000], loss: 0.9026
# Train Accuracy:32626/45438
# Test accuracy:2771/15142
#
# Epoch [979/1000], step[500], loss: 0.5075
# Epoch [979/1000], step[1000], loss: 1.2848
# Train Accuracy:32292/45438
# Test accuracy:2810/15142
#
# Epoch [980/1000], step[500], loss: 0.7749
# Epoch [980/1000], step[1000], loss: 1.0795
# Train Accuracy:32520/45438
# Test accuracy:2810/15142
#
# Epoch [981/1000], step[500], loss: 0.7710
# Epoch [981/1000], step[1000], loss: 0.8734
# Train Accuracy:32422/45438
# Test accuracy:2801/15142
#
# Epoch [982/1000], step[500], loss: 0.9196
# Epoch [982/1000], step[1000], loss: 1.1413
# Train Accuracy:32421/45438
# Test accuracy:2765/15142
#
# Epoch [983/1000], step[500], loss: 0.9351
# Epoch [983/1000], step[1000], loss: 1.1022
# Train Accuracy:32544/45438
# Test accuracy:2854/15142
#
# Epoch [984/1000], step[500], loss: 0.6333
# Epoch [984/1000], step[1000], loss: 1.1247
# Train Accuracy:32518/45438
# Test accuracy:2822/15142
#
# Epoch [985/1000], step[500], loss: 1.1382
# Epoch [985/1000], step[1000], loss: 0.8292
# Train Accuracy:32774/45438
# Test accuracy:2780/15142
#
# Epoch [986/1000], step[500], loss: 0.7811
# Epoch [986/1000], step[1000], loss: 0.8717
# Train Accuracy:32619/45438
# Test accuracy:2798/15142
#
# Epoch [987/1000], step[500], loss: 0.9338
# Epoch [987/1000], step[1000], loss: 1.0516
# Train Accuracy:32635/45438
# Test accuracy:2802/15142
#
# Epoch [988/1000], step[500], loss: 1.1580
# Epoch [988/1000], step[1000], loss: 0.8059
# Train Accuracy:32591/45438
# Test accuracy:2792/15142
#
# Epoch [989/1000], step[500], loss: 1.0030
# Epoch [989/1000], step[1000], loss: 0.9567
# Train Accuracy:32483/45438
# Test accuracy:2797/15142
#
# Epoch [990/1000], step[500], loss: 0.6874
# Epoch [990/1000], step[1000], loss: 1.1393
# Train Accuracy:32633/45438
# Test accuracy:2817/15142
#
# Epoch [991/1000], step[500], loss: 1.1628
# Epoch [991/1000], step[1000], loss: 0.6264
# Train Accuracy:32620/45438
# Test accuracy:2766/15142
#
# Epoch [992/1000], step[500], loss: 1.1546
# Epoch [992/1000], step[1000], loss: 0.7747
# Train Accuracy:32639/45438
# Test accuracy:2812/15142
#
# Epoch [993/1000], step[500], loss: 1.2547
# Epoch [993/1000], step[1000], loss: 1.1373
# Train Accuracy:32741/45438
# Test accuracy:2799/15142
#
# Epoch [994/1000], step[500], loss: 1.0421
# Epoch [994/1000], step[1000], loss: 0.9614
# Train Accuracy:32688/45438
# Test accuracy:2864/15142
#
# Epoch [995/1000], step[500], loss: 0.9544
# Epoch [995/1000], step[1000], loss: 1.4487
# Train Accuracy:32634/45438
# Test accuracy:2827/15142
#
# Epoch [996/1000], step[500], loss: 1.1649
# Epoch [996/1000], step[1000], loss: 0.8478
# Train Accuracy:32631/45438
# Test accuracy:2781/15142
#
# Epoch [997/1000], step[500], loss: 0.6591
# Epoch [997/1000], step[1000], loss: 1.3814
# Train Accuracy:32882/45438
# Test accuracy:2787/15142
#
# Epoch [998/1000], step[500], loss: 0.5834
# Epoch [998/1000], step[1000], loss: 1.3707
# Train Accuracy:32667/45438
# Test accuracy:2838/15142
#
# Epoch [999/1000], step[500], loss: 1.1058
# Epoch [999/1000], step[1000], loss: 1.2585
# Train Accuracy:32768/45438
# Test accuracy:2763/15142
#
# Epoch [1000/1000], step[500], loss: 1.2810
# Epoch [1000/1000], step[1000], loss: 1.2957
# Train Accuracy:32616/45438
# Test accuracy:2756/15142
